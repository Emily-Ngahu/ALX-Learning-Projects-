# %% [markdown]
# # Common Table Expressions (CTEs) vs. subqueries
# © ExploreAI Academy

# %% [markdown]
# This notebook will compare and contrast Common Table Expressions (CTEs) and subqueries in SQL. We will explore their similarities, differences, use cases, and when to choose one over the other.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# - Understand the differences between CTEs and subqueries.
# - Learn how to optimise SQL queries using CTEs.
# - Write complex SQL queries using CTEs and subqueries.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore Common Table Expressions (CTEs) and subqueries in SQL. These are powerful tools that can help us simplify complex queries, enhance readability, and improve the performance of our SQL operations.
#
# We will examine these concepts in the context of a real-world problem: *Identifying Sub-Saharan African countries with underdeveloped economies that might struggle to gain access to water.*
#
# We will start by writing SQL queries using subqueries and then delve into the optimisation of these queries using CTEs.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name.

# %sql mysql+pymysql://root:Emily99@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %%
# %%sql
# SELECT
#     *
# FROM
#     united_nations.Access_to_Basic_Services
# limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, Decimal('94.67'), Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, Decimal('94.67'), Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, Decimal('95.00'), Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, Decimal('95.00'), Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %% [markdown]
# ## Exercise
#
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their access to basic services, and their estimated GDP.
#
# The tasks will involve writing and optimising SQL queries to identify Sub-Saharan African countries with an estimated GDP below the regional average and less than 60% access to managed drinking water services in 2020.

# %% [markdown]
# ### Task 1: Calculate the average GDP for each region
#
# Start by calculating the average GDP for each country’s region for 2020 using the `AVG(Est_gdp_in_billions) OVER(PARTITION BY Region)` window function.

# %%
# %%sql
# SELECT
#     Region,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Country_name,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER (PARTITION BY Region) AS avg_gdp
# FROM
#     Access_to_Basic_Services
# WHERE
#     Time_period =2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Central and Southern Asia', Decimal('95.00'), Decimal('98.00'), 'Kazakhstan', Decimal('171.08'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('92.67'), Decimal('97.67'), 'Kyrgyzstan', None, Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('85.00'), Decimal('96.33'), 'Tajikistan', Decimal('8.13'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('100.00'), Decimal('99.33'), 'Turkmenistan', None, Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('98.00'), Decimal('100.00'), 'Uzbekistan', Decimal('59.89'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('80.33'), Decimal('54.00'), 'Afghanistan', Decimal('20.14'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('97.67'), Decimal('54.00'), 'Bangladesh', Decimal('373.90'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('97.33'), Decimal('76.67'), 'Bhutan', Decimal('2.33'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('91.00'), Decimal('72.33'), 'India', Decimal('2667.69'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('96.67'), Decimal('88.33'), 'Iran (Islamic Republic of)', None, Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('99.67'), Decimal('99.33'), 'Maldives', Decimal('3.75'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('90.00'), Decimal('76.67'), 'Nepal', Decimal('33.43'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('90.67'), Decimal('70.00'), 'Pakistan', Decimal('300.43'), Decimal('338.738182')),
#  ('Central and Southern Asia', Decimal('94.33'), Decimal('93.67'), 'Sri Lanka', Decimal('85.35'), Decimal('338.738182')),
#  ('Eastern and South-Eastern Asia', Decimal('93.67'), Decimal('91.67'), 'China', Decimal('14687.67'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('93.33'), Decimal('83.33'), "Democratic People's Republic of Korea", None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('99.00'), Decimal('100.00'), 'Japan', Decimal('5040.11'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('81.00'), Decimal('65.00'), 'Mongolia', Decimal('13.31'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('100.00'), 'Republic of Korea', None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), None, 'Brunei Darussalam', Decimal('12.01'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('75.33'), Decimal('74.33'), 'Cambodia', Decimal('25.87'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('92.00'), Decimal('86.00'), 'Indonesia', Decimal('1058.69'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('86.67'), Decimal('82.00'), "Lao People's Democratic Republic", None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('95.33'), Decimal('100.00'), 'Malaysia', Decimal('337.34'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('85.67'), Decimal('74.67'), 'Myanmar', Decimal('78.93'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('94.00'), Decimal('82.00'), 'Philippines', Decimal('361.75'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('100.00'), 'Singapore', Decimal('345.30'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('100.00'), Decimal('98.67'), 'Thailand', Decimal('499.68'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('87.00'), Decimal('60.00'), 'Timor-Leste', Decimal('2.16'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', Decimal('97.33'), Decimal('90.00'), 'Viet Nam', None, Decimal('1871.901667')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('100.00'), 'Bermuda', Decimal('6.89'), Decimal('551.796667')),
#  ('Europe and Northern America', Decimal('99.00'), Decimal('99.00'), 'Canada', Decimal('1645.42'), Decimal('551.796667')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('100.00'), 'Greenland', Decimal('3.08'), Decimal('551.796667')),
#  ('Europe and Northern America', Decimal('91.00'), Decimal('100.00'), 'Saint Pierre and Miquelon', None, Decimal('551.796667')),
#  ('Europe and Northern America', Decimal('100.00'), Decimal('99.67'), 'United States of America', None, Decimal('551.796667')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('98.00'), 'Barbados', Decimal('4.67'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), None, 'British Virgin Islands', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('96.33'), Decimal('90.00'), 'Cuba', Decimal('107.35'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('95.00'), Decimal('84.33'), 'Dominican Republic', Decimal('78.84'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('100.00'), 'Guadeloupe', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('65.00'), Decimal('36.00'), 'Haiti', Decimal('14.51'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('87.00'), 'Jamaica', Decimal('13.81'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('100.00'), 'Martinique', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('89.00'), 'Montserrat', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('100.00'), 'Puerto Rico', Decimal('103.02'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('100.00'), 'Saint Barthélemy', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('82.00'), 'Saint Lucia', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('100.00'), 'Saint Martin (French Part)', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('94.00'), 'Trinidad and Tobago', Decimal('21.06'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('99.00'), Decimal('99.00'), 'United States Virgin Islands', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('88.67'), 'Belize', Decimal('2.08'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('97.67'), 'Costa Rica', Decimal('62.16'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('97.00'), Decimal('79.67'), 'El Salvador', Decimal('24.56'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('67.67'), 'Guatemala', Decimal('77.63'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('95.33'), Decimal('83.33'), 'Honduras', Decimal('23.83'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('99.33'), Decimal('90.67'), 'Mexico', Decimal('1090.52'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('79.33'), Decimal('71.67'), 'Nicaragua', Decimal('12.59'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('92.67'), Decimal('81.00'), 'Panama', Decimal('53.98'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('99.00'), 'Argentina', Decimal('385.54'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('90.67'), Decimal('61.67'), 'Bolivia (Plurinational State of)', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('98.33'), Decimal('82.33'), 'Brazil', Decimal('1448.56'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('100.00'), Decimal('100.00'), 'Chile', Decimal('252.73'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('94.67'), Decimal('91.33'), 'Colombia', Decimal('270.30'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('91.33'), 'Ecuador', Decimal('99.29'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('91.00'), Decimal('100.00'), 'Falkland Islands (Malvinas)', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('92.00'), 'French Guiana', None, Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('96.67'), Decimal('87.33'), 'Guyana', Decimal('5.47'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('99.67'), Decimal('92.00'), 'Paraguay', Decimal('35.43'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('90.33'), Decimal('74.33'), 'Peru', Decimal('201.71'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('88.67'), 'Suriname', Decimal('2.91'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('98.00'), Decimal('98.33'), 'Uruguay', Decimal('53.56'), Decimal('177.844400')),
#  ('Latin America and the Caribbean', Decimal('94.00'), Decimal('96.00'), 'Venezuela (Bolivarian Republic of)', None, Decimal('177.844400')),
#  ('Northern Africa and Western Asia', Decimal('93.33'), Decimal('84.33'), 'Algeria', Decimal('145.01'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('99.33'), Decimal('97.67'), 'Egypt', None, Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('92.00'), 'Libya', Decimal('50.36'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('88.33'), Decimal('84.67'), 'Morocco', Decimal('121.35'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('62.33'), Decimal('40.33'), 'Sudan', Decimal('27.03'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('97.00'), Decimal('97.33'), 'Tunisia', Decimal('42.54'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('92.33'), 'Armenia', Decimal('12.64'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('95.67'), Decimal('96.00'), 'Azerbaijan', Decimal('42.69'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('100.00'), 'Bahrain', Decimal('34.72'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('99.33'), 'Cyprus', Decimal('25.01'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('84.33'), 'Georgia', Decimal('15.84'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('97.67'), Decimal('100.00'), 'Iraq', Decimal('184.37'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('99.67'), 'Israel', Decimal('413.27'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('96.33'), 'Jordan', Decimal('44.18'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('100.00'), 'Kuwait', Decimal('105.96'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('93.00'), Decimal('99.00'), 'Lebanon', Decimal('31.71'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('87.67'), Decimal('99.00'), 'Oman', Decimal('75.91'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('100.00'), 'Qatar', Decimal('144.41'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('100.00'), 'Saudi Arabia', Decimal('703.37'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('98.33'), Decimal('98.67'), 'State of Palestine', None, Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('93.67'), Decimal('90.00'), 'Syrian Arab Republic', Decimal('11.08'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('96.67'), Decimal('98.67'), 'Türkiye', None, Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('100.00'), Decimal('99.00'), 'United Arab Emirates', Decimal('349.47'), Decimal('129.046000')),
#  ('Northern Africa and Western Asia', Decimal('63.00'), Decimal('57.33'), 'Yemen', None, Decimal('129.046000')),
#  ('Oceania', Decimal('100.00'), Decimal('100.00'), 'Australia', Decimal('1326.90'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('100.00'), 'New Zealand', Decimal('211.73'), Decimal('93.726471')),
#  ('Oceania', Decimal('93.67'), Decimal('99.00'), 'Fiji', Decimal('4.48'), Decimal('93.726471')),
#  ('Oceania', Decimal('99.00'), Decimal('100.00'), 'New Caledonia', Decimal('9.44'), Decimal('93.726471')),
#  ('Oceania', Decimal('56.67'), Decimal('27.67'), 'Papua New Guinea', Decimal('23.85'), Decimal('93.726471')),
#  ('Oceania', Decimal('72.33'), Decimal('44.67'), 'Solomon Islands', Decimal('1.54'), Decimal('93.726471')),
#  ('Oceania', Decimal('93.00'), Decimal('55.67'), 'Vanuatu', Decimal('0.90'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), None, 'Guam', Decimal('5.89'), Decimal('93.726471')),
#  ('Oceania', Decimal('77.00'), Decimal('45.33'), 'Kiribati', Decimal('0.18'), Decimal('93.726471')),
#  ('Oceania', Decimal('90.00'), Decimal('78.00'), 'Marshall Islands', Decimal('0.24'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), None, 'Nauru', Decimal('0.11'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('79.00'), 'Northern Mariana Islands', None, Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('99.67'), 'Palau', Decimal('0.25'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('54.00'), 'American Samoa', Decimal('0.72'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('99.00'), 'Cook Islands', None, Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('97.00'), 'French Polynesia', Decimal('5.71'), Decimal('93.726471')),
#  ('Oceania', Decimal('97.00'), Decimal('96.00'), 'Niue', None, Decimal('93.726471')),
#  ('Oceania', Decimal('92.00'), Decimal('96.33'), 'Samoa', Decimal('0.87'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), Decimal('97.00'), 'Tokelau', None, Decimal('93.726471')),
#  ('Oceania', Decimal('99.00'), Decimal('93.33'), 'Tonga', Decimal('0.48'), Decimal('93.726471')),
#  ('Oceania', Decimal('100.00'), None, 'Tuvalu', Decimal('0.06'), Decimal('93.726471')),
#  ('Oceania', Decimal('99.00'), Decimal('93.00'), 'Wallis and Futuna Islands', None, Decimal('93.726471')),
#  ('Sub-Saharan Africa', Decimal('70.33'), Decimal('44.33'), 'Burundi', Decimal('2.65'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('56.00'), 'Djibouti', Decimal('3.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('58.00'), Decimal('11.67'), 'Ethiopia', Decimal('107.66'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('67.00'), Decimal('33.67'), 'Kenya', Decimal('100.67'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('56.33'), Decimal('13.00'), 'Madagascar', Decimal('13.05'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('74.33'), Decimal('28.67'), 'Malawi', Decimal('12.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('96.00'), 'Mauritius', Decimal('11.40'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('96.00'), Decimal('100.00'), 'Mayotte', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('66.67'), Decimal('40.33'), 'Mozambique', Decimal('14.03'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('66.33'), Decimal('64.00'), 'Rwanda', Decimal('10.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('100.00'), Decimal('100.00'), 'Réunion', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('57.33'), Decimal('40.00'), 'Somalia', Decimal('6.88'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('48.33'), Decimal('22.33'), 'South Sudan', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('61.00'), Decimal('21.67'), 'Uganda', Decimal('37.60'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('65.00'), Decimal('34.00'), 'United Republic of Tanzania', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('66.67'), Decimal('32.67'), 'Zambia', Decimal('18.11'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('68.00'), Decimal('36.33'), 'Zimbabwe', Decimal('21.51'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('52.33'), Decimal('47.00'), 'Angola', Decimal('53.62'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('64.00'), Decimal('43.00'), 'Cameroon', Decimal('40.77'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('38.33'), Decimal('15.00'), 'Central African Republic', Decimal('2.33'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('52.67'), Decimal('18.67'), 'Chad', Decimal('10.72'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('69.00'), Decimal('17.67'), 'Congo', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('47.67'), Decimal('15.33'), 'Democratic Republic of the Congo', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('73.33'), Decimal('47.00'), 'Gabon', Decimal('15.31'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('77.33'), Decimal('46.00'), 'Sao Tome and Principe', Decimal('0.47'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('89.67'), Decimal('74.33'), 'Botswana', Decimal('14.93'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('76.67'), Decimal('61.33'), 'Eswatini', Decimal('3.98'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('76.33'), Decimal('49.67'), 'Lesotho', Decimal('2.23'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('83.67'), Decimal('35.00'), 'Namibia', Decimal('10.58'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('92.00'), Decimal('78.67'), 'South Africa', Decimal('337.62'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('65.33'), Decimal('17.33'), 'Benin', Decimal('15.65'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('53.33'), Decimal('25.00'), 'Burkina Faso', Decimal('17.93'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('87.33'), Decimal('78.00'), 'Cabo Verde', Decimal('1.70'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('70.67'), Decimal('34.67'), "Côte d'Ivoire", None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('79.33'), Decimal('44.33'), 'Gambia', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('84.67'), Decimal('23.00'), 'Ghana', Decimal('70.04'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('67.33'), Decimal('32.33'), 'Guinea', Decimal('14.18'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('60.00'), Decimal('19.33'), 'Guinea-Bissau', Decimal('1.43'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('75.00'), Decimal('17.67'), 'Liberia', Decimal('3.04'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('83.67'), Decimal('46.00'), 'Mali', Decimal('17.47'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('70.33'), Decimal('48.00'), 'Mauritania', Decimal('8.41'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('57.33'), Decimal('24.67'), 'Niger', Decimal('13.74'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('77.33'), Decimal('42.67'), 'Nigeria', Decimal('432.20'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('99.00'), Decimal('100.00'), 'Saint Helena', None, Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('85.00'), Decimal('57.00'), 'Senegal', Decimal('24.49'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('65.00'), Decimal('17.33'), 'Sierra Leone', Decimal('4.06'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('70.67'), Decimal('20.00'), 'Togo', Decimal('7.57'), Decimal('39.041316'))]

# %% [markdown]
# ### Task 2: Filter the data
#
# Next, let’s filter the data to focus only on the Sub-Saharan African countries with underdeveloped economies and also limited access to managed drinking water services in 2020.

# %%
# %%sql
# SELECT
#     Region,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Country_name,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER (PARTITION BY Region) AS avg_gdp
# FROM
#     Access_to_Basic_Services
# WHERE
#     Time_period =2020
#     AND Region ='Sub-Saharan African';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# Note that you get an error message:
#
# Unknown column `Avg_gdp_for_region` in `where clause`...
#
# This is because we cannot calculate *and* reference that result in the same query.

# %% [markdown]
# ### Task 3: Implement the solution using subqueries
#
# We can fix the error by using a subquery to calculate the average regional GDP, and then use those results in the main query.

# %%
# %%sql
# SELECT
#     *
# FROM(
#     SELECT
#         Region,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Country_name,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER (PARTITION BY Region) AS avg_gdp
#     FROM
#         Access_to_Basic_Services
# WHERE
#     Time_period =2020) AS regional_gdp
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < avg_gdp;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 6 rows affected.
# [('Sub-Saharan Africa', Decimal('56.33'), Decimal('13.00'), 'Madagascar', Decimal('13.05'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('57.33'), Decimal('40.00'), 'Somalia', Decimal('6.88'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('38.33'), Decimal('15.00'), 'Central African Republic', Decimal('2.33'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('52.67'), Decimal('18.67'), 'Chad', Decimal('10.72'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('53.33'), Decimal('25.00'), 'Burkina Faso', Decimal('17.93'), Decimal('39.041316')),
#  ('Sub-Saharan Africa', Decimal('57.33'), Decimal('24.67'), 'Niger', Decimal('13.74'), Decimal('39.041316'))]

# %% [markdown]
# ### Task 4: Implement the solution using Common Table Expressions (CTEs)
#
# Now, let's attempt the same problem using Common Table Expressions (CTEs).

# %%
# %%sql
# WITH Avg_world_gdp_2020 AS (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
# )
# SELECT
#    *
# FROM
#     Avg_world_gdp_2020
# WHERE
#     Region='Sub Saharan African'
#     AND Est_gdp_in_billions<Avg_gdp_region
#     AND Pct_managed_drinking_water_services < 60;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1: Calculate the average GDP for each region

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 122 rows affected.
# [('Central and Southern Asia', 'Kazakhstan', Decimal('95.00'), Decimal('98.00'), Decimal('171.08'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Kyrgyzstan', Decimal('92.67'), Decimal('97.67'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('85.00'), Decimal('96.33'), Decimal('8.13'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Turkmenistan', Decimal('100.00'), Decimal('99.33'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Uzbekistan', Decimal('98.00'), Decimal('100.00'), Decimal('59.89'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('80.33'), Decimal('54.00'), Decimal('20.14'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('97.67'), Decimal('54.00'), Decimal('373.90'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('97.33'), Decimal('76.67'), Decimal('2.33'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'India', Decimal('91.00'), Decimal('72.33'), Decimal('2667.69'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', Decimal('96.67'), Decimal('88.33'), None, Decimal('338.738182')),
#  ('Central and Southern Asia', 'Maldives', Decimal('99.67'), Decimal('99.33'), Decimal('3.75'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Nepal', Decimal('90.00'), Decimal('76.67'), Decimal('33.43'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Pakistan', Decimal('90.67'), Decimal('70.00'), Decimal('300.43'), Decimal('338.738182')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('94.33'), Decimal('93.67'), Decimal('85.35'), Decimal('338.738182')),
#  ('Eastern and South-Eastern Asia', 'China', Decimal('93.67'), Decimal('91.67'), Decimal('14687.67'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", Decimal('93.33'), Decimal('83.33'), None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('99.00'), Decimal('100.00'), Decimal('5040.11'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('81.00'), Decimal('65.00'), Decimal('13.31'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', Decimal('100.00'), Decimal('100.00'), None, Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('100.00'), None, Decimal('12.01'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Cambodia', Decimal('75.33'), Decimal('74.33'), Decimal('25.87'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('92.00'), Decimal('86.00'), Decimal('1058.69'), Decimal('1871.901667')),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic
#  ('Oceania', 'American Samoa', Decimal('100.00'), Decimal('54.00'), Decimal('0.72'), Decimal('93.726471')),
#  ('Oceania', 'Cook Islands', Decimal('100.00'), Decimal('99.00'), None, Decimal('93.726471')),
#  ('Oceania', 'French Polynesia', Decimal('100.00'), Decimal('97.00'), Decimal('5.71'), Decimal('93.726471')),
#  ('Oceania', 'Niue', Decimal('97.00'), Decimal('96.00'), None, Decimal('93.726471')),
#  ('Oceania', 'Samoa', Decimal('92.00'), Decimal('96.33'), Decimal('0.87'), Decimal('93.726471')),
#  ('Oceania', 'Tokelau', Decimal('100.00'), Decimal('97.00'), None, Decimal('93.726471')),
#  ('Oceania', 'Tonga', Decimal('99.00'), Decimal('93.33'), Decimal('0.48'), Decimal('93.726471')),
#  ('Oceania', 'Tuvalu', Decimal('100.00'), None, Decimal('0.06'), Decimal('93.726471')),
#  ('Oceania', 'Wallis and Futuna Islands', Decimal('99.00'), Decimal('93.00'), None, Decimal('93.726471')),
#  ('Sub-Saharan Africa', 'Burundi', Decimal('70.33'), Decimal('44.33'), Decimal('2.65'), Decimal('53.540000')),
#  ('Sub-Saharan Africa', 'Djibouti', Decimal('69.00'), Decimal('56.00'), Decimal('3.18'), Decimal('53.540000')),
#  ('Sub-Saharan Africa', 'Ethiopia', Decimal('58.00'), Decimal('11.67'), Decimal('107.66'), Decimal('53.540000')),
#  ('Sub-Saharan Africa', 'Kenya', Decimal('67.00'), Decimal('33.67'), Decimal('100.67'), Decimal('53.540000'))]

# %% [markdown]
# ### Task 2: Filter the data

# %%
# %%sql
# SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# (pymysql.err.OperationalError) (1054, "Unknown column 'Avg_gdp_for_region' in 'where clause'")
# [SQL: SELECT
#     Region,
#     Country_name,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
# FROM
#     united_nations.Access_to_Basic_Services
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Time_period = 2020
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Task 3: Implement the solution using subqueries

# %%
# %%sql
# SELECT
#     Country_name,
#     Region,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Avg_gdp_for_region
# FROM (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
#     ) AS Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 4: Implement the solution using Common Table Expressions (CTEs)

# %%
# %%sql
# -- This CTE calculates the average regional GDP for each country, for the year 2020.
# WITH Avg_world_GDP_2020 AS (
#     SELECT
#         Region,
#         Country_name,
#         Pct_managed_drinking_water_services,
#         Pct_managed_sanitation_services,
#         Est_gdp_in_billions,
#         AVG(Est_gdp_in_billions) OVER(PARTITION BY Region) AS Avg_gdp_for_region
#     FROM
#         united_nations.Access_to_Basic_Services
#     WHERE
#         Time_period = 2020
# )
#
# /*
# This query filters the Avg_world_GDP_2020 CTE for
# countries that have below-average GDP, in the
# Sub-Saharan Africa region, and struggling with water access.
# */
#
# SELECT
#     Country_name
# FROM
#     Avg_world_GDP_2020
# WHERE
#     Region = 'Sub-Saharan Africa'
#     AND Pct_managed_drinking_water_services < 60
#     AND Est_gdp_in_billions < Avg_gdp_for_region;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# Note how much easier the CTE is to read compared to the query using a subquery.

# %% [markdown]
# ## Summary
#
# In our exercises, we have seen how subqueries and Common Table Expressions (CTEs) can be used to break down complex queries into manageable parts. This not only enhances readability but also improves performance by enabling the database to process the query more efficiently.
#
# For instance, when identifying Sub-Saharan African countries with underdeveloped economies struggling to access drinking water services, we first used subqueries to combine conditions and evaluate the GDP criteria before assessing water access. We then applied the concept of Common Table Expressions as another optimised alternative, which allowed us to calculate the regional average GDP separately. This created a reusable block of code that could be referenced in the final query.
#
# By comparing the two implementations, we saw how CTEs could simplify complex queries and eliminate the need for saving intermediary tables and taking up more space in the database or using multiple subqueries.
#
# The use of CTEs and subqueries empowers us to optimise SQL queries effectively, making our data analysis more efficient and organised.
#
# Remember, the choice between subqueries and CTEs often depends on the specific requirements of your task and the complexity of your SQL queries. It's always a good idea to test different implementations and choose the one that best meets your needs.

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
