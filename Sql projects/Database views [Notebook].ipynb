# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Database views
# © ExploreAI Academy

# %% [markdown]
# A view is a virtual table that represents data derived from one or more base tables. It does not store data. It is basically a saved query that can be used as a table. Views allow you to simplify complex queries, abstract the underlying data structure, and provide some security by allowing access to specific columns or rows of data.
#
# In this lesson, we will construct a complex query and then create a view of that query.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# By the end of this lesson, you should know:
# - What a view is and why it's needed.
# - How to create a view.
# - How to join tables using views.
# - How to impute Null values using views.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in the `united_nations` database that we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace `password` with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Emily99@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then add the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     united_nations.Economic_Indicators
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Afghanistan', 2015, Decimal('20.00'), Decimal('33.753499'), None),
#  ('Afghanistan', 2016, Decimal('18.02'), Decimal('34.636207'), None),
#  ('Afghanistan', 2017, Decimal('18.90'), Decimal('35.643418'), Decimal('11.18')),
#  ('Afghanistan', 2018, Decimal('18.42'), Decimal('36.686784'), None),
#  ('Afghanistan', 2019, Decimal('18.90'), Decimal('37.769499'), None)]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We have decomposed the `united_nations.Access_to_Basic_Services` table into three tables. The `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and the `united_nations.Geographic_Locations` table. In this tutorial, we will be constructing a complex query to view the unemployment rate in Sub-Saharan Africa. We will then save that query as a VIEW.

# %% [markdown]
# ### Task 1
# To view the unemployment rate per region we will have to first join the `Economic_Indicators` table to the `Geographic_Locations` table.

# %%
# %%sql
# SELECT
#     location.Region,
#     location.Country_name,
#     economic.Pct_unemployment
# FROM
#     Geographic_Location AS location
# LEFT JOIN
#     Economic_Indicators As economic
# ON location.Country_name=economic.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Central and Southern Asia', 'Afghanistan', None),
#  ('Central and Southern Asia', 'Afghanistan', None),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('11.18')),
#  ('Central and Southern Asia', 'Afghanistan', None),
#  ('Central and Southern Asia', 'Afghanistan', None),
#  ('Central and Southern Asia', 'Afghanistan', Decimal('11.71')),
#  ('Northern Africa and Western Asia', 'Algeria', Decimal('11.21')),
#  ('Northern Africa and Western Asia', 'Algeria', Decimal('10.20')),
#  ('Northern Africa and Western Asia', 'Algeria', Decimal('12.00')),
#  ('Northern Africa and Western Asia', 'Algeria', None),
#  ('Northern Africa and Western Asia', 'Algeria', None),
#  ('Northern Africa and Western Asia', 'Algeria', None),
#  ('Oceania', 'American Samoa', None),
#  ('Oceania', 'American Samoa', None),
#  ('Oceania', 'American Samoa', None),
#  ('Oceania', 'American Samoa', None),
#  ('Oceania', 'American Samoa', None),
#  ('Oceania', 'American Samoa', None),
#  ('Sub-Saharan Africa', 'Angola', None),
#  ('Sub-Saharan Africa', 'Angola', None),
#  ('Sub-Saharan Africa', 'Angola', None),
#  ('Sub-Saharan Africa', 'Angola', None),
#  ('Sub-Saharan Africa', 'Angola', Decimal('16.50')),
#  ('Sub-Saharan Africa', 'Angola', None),
#  ('Latin America and the Caribbean', 'Anguilla', None),
#  ('Latin America and the Caribbean', 'Anguilla', None),
#  ('Latin America and the Caribbean', 'Anguilla', None),
#  ('Latin America and the Caribbean', 'Antigua and Barbuda', None),
#  ('Latin America and the Caribbean', 'Antigua and Barbuda', None),
#  ('Latin America and the Caribbean', 'Antigua and Barbuda', None),
#  ('Latin America and the Caribbean', 'Argentina', None),
#  ('Latin America and the Caribbean', 'Argentina', None),
#  ('Latin America and the Caribbean', 'Argentina', Decimal('8.35')),
#  ('Latin America and the Caribbean', 'Argentina', Decimal('9.22')),
#  ('Latin America and the Caribbean', 'Argentina', Decimal('9.84')),
#  ('Latin America and the Caribbean', 'Argentina', Decimal('11.46')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('18.26')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('17.62')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('17.70')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('13.21')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('12.20')),
#  ('Northern Africa and Western Asia', 'Armenia', Decimal('12.18')),
#  ('Latin America and the Caribbean', 'Aruba', None),
#  ('Latin America and the Caribbean', 'Aruba', None),
#  ('Oceania', 'Australia', Decimal('6.06')),
#  ('Oceania', 'Australia', Decimal('5.71')),
#  ('Oceania', 'Australia', Decimal('5.59')),
#  ('Oceania', 'Australia', Decimal('5.30')),
#  ('Oceania', 'Australia', Decimal('5.16')),
#  ('Oceania', 'Australia', Decimal('6.46')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('4.96')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('5.00')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('4.96')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('4.94')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('4.85')),
#  ('Northern Africa and Western Asia', 'Azerbaijan', Decimal('7.16')),
#  ('Latin America and the Caribbean', 'Bahamas', None),
#  ('Latin America and the Caribbean', 'Bahamas', None),
#  ('Latin America and the Caribbean', 'Bahamas', None),
#  ('Latin America and the Caribbean', 'Bahamas', None),
#  ('Latin America and the Caribbean', 'Bahamas', None),
#  ('Northern Africa and Western Asia', 'Bahrain', None),
#  ('Northern Africa and Western Asia', 'Bahrain', None),
#  ('Northern Africa and Western Asia', 'Bahrain', None),
#  ('Northern Africa and Western Asia', 'Bahrain', None),
#  ('Northern Africa and Western Asia', 'Bahrain', None),
#  ('Northern Africa and Western Asia', 'Bahrain', None),
#  ('Central and Southern Asia', 'Bangladesh', None),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('4.35')),
#  ('Central and Southern Asia', 'Bangladesh', Decimal('4.37')),
#  ('Central and Southern Asia', 'Bangladesh', None),
#  ('Central and Southern Asia', 'Bangladesh', None),
#  ('Central and Southern Asia', 'Bangladesh', None),
#  ('Latin America and the Caribbean', 'Barbados', Decimal('9.80')),
#  ('Latin America and the Caribbean', 'Barbados', Decimal('8.25')),
#  ('Latin America and the Caribbean', 'Barbados', Decimal('8.62')),
#  ('Latin America and the Caribbean', 'Barbados', Decimal('8.32')),
#  ('Latin America and the Caribbean', 'Barbados', Decimal('8.41')),
#  ('Latin America and the Caribbean', 'Barbados', None),
#  ('Latin America and the Caribbean', 'Belize', Decimal('7.58')),
#  ('Latin America and the Caribbean', 'Belize', Decimal('7.00')),
#  ('Latin America and the Caribbean', 'Belize', Decimal('6.60')),
#  ('Latin America and the Caribbean', 'Belize', None),
#  ('Latin America and the Caribbean', 'Belize', Decimal('9.05')),
#  ('Latin America and the Caribbean', 'Belize', None),
#  ('Sub-Saharan Africa', 'Benin', None),
#  ('Sub-Saharan Africa', 'Benin', None),
#  ('Sub-Saharan Africa', 'Benin', None),
#  ('Sub-Saharan Africa', 'Benin', Decimal('1.47')),
#  ('Sub-Saharan Africa', 'Benin', None),
#  ('Sub-Saharan Africa', 'Benin', None),
#  ('Europe and Northern America', 'Bermuda', None),
#  ('Europe and Northern America', 'Bermuda', None),
#  ('Europe and Northern America', 'Bermuda', None),
#  ('Europe and Northern America', 'Bermuda', None),
#  ('Europe and Northern America', 'Bermuda', None),
#  ('Europe and Northern America', 'Bermuda', None),
#  ('Central and Southern Asia', 'Bhutan', Decimal('2.45')),
#  ('Central and Southern Asia', 'Bhutan', None),
#  ('Central and Southern Asia', 'Bhutan', None),
#  ('Central and Southern Asia', 'Bhutan', Decimal('3.35')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('2.72')),
#  ('Central and Southern Asia', 'Bhutan', Decimal('5.03')),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', None),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', None),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', None),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', None),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', None),
#  ('Latin America and the Caribbean', 'Bolivia (Plurinational State of)', None),
#  ('Sub-Saharan Africa', 'Botswana', None),
#  ('Sub-Saharan Africa', 'Botswana', None),
#  ('Sub-Saharan Africa', 'Botswana', None),
#  ('Sub-Saharan Africa', 'Botswana', None),
#  ('Sub-Saharan Africa', 'Botswana', Decimal('20.09')),
#  ('Sub-Saharan Africa', 'Botswana', Decimal('21.02')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('8.54')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('11.58')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('12.79')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('12.33')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('11.94')),
#  ('Latin America and the Caribbean', 'Brazil', Decimal('13.70')),
#  ('Latin America and the Caribbean', 'British Virgin Islands', None),
#  ('Latin America and the Caribbean', 'British Virgin Islands', None),
#  ('Latin America and the Caribbean', 'British Virgin Islands', None),
#  ('Latin America and the Caribbean', 'British Virgin Islands', None),
#  ('Latin America and the Caribbean', 'British Virgin Islands', None),
#  ('Latin America and the Caribbean', 'British Virgin Islands', None),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', None),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', None),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('9.32')),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('8.70')),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('6.60')),
#  ('Eastern and South-Eastern Asia', 'Brunei Darussalam', Decimal('7.41')),
#  ('Sub-Saharan Africa', 'Burkina Faso', None),
#  ('Sub-Saharan Africa', 'Burkina Faso', None),
#  ('Sub-Saharan Africa', 'Burkina Faso', None),
#  ('Sub-Saharan Africa', 'Burkina Faso', Decimal('4.69')),
#  ('Sub-Saharan Africa', 'Burkina Faso', None),
#  ('Sub-Saharan Africa', 'Burkina Faso', None),
#  ('Sub-Saharan Africa', 'Burundi', None),
#  ('Sub-Saharan Africa', 'Burundi', None),
#  ('Sub-Saharan Africa', 'Burundi', None),
#  ('Sub-Saharan Africa', 'Burundi', None),
#  ('Sub-Saharan Africa', 'Burundi', None),
#  ('Sub-Saharan Africa', 'Burundi', Decimal('1.03')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('31.31')),
#  ('Sub-Saharan Africa', 'Cabo Verde', None),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('12.24')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('12.17')),
#  ('Sub-Saharan Africa', 'Cabo Verde', Decimal('11.29')),
#  ('Sub-Saharan Africa', 'Cabo Verde', None),
#  ('Eastern and South-Eastern Asia', 'Cambodia', Decimal('0.39')),
#  ('Eastern and South-Eastern Asia', 'Cambodia', Decimal('0.72')),
#  ('Eastern and South-Eastern Asia', 'Cambodia', Decimal('0.14')),
#  ('Eastern and South-Eastern Asia', 'Cambodia', None),
#  ('Eastern and South-Eastern Asia', 'Cambodia', Decimal('0.50')),
#  ('Eastern and South-Eastern Asia', 'Cambodia', None),
#  ('Sub-Saharan Africa', 'Cameroon', None),
#  ('Sub-Saharan Africa', 'Cameroon', None),
#  ('Sub-Saharan Africa', 'Cameroon', None),
#  ('Sub-Saharan Africa', 'Cameroon', None),
#  ('Sub-Saharan Africa', 'Cameroon', None),
#  ('Sub-Saharan Africa', 'Cameroon', None),
#  ('Europe and Northern America', 'Canada', Decimal('6.91')),
#  ('Europe and Northern America', 'Canada', Decimal('7.00')),
#  ('Europe and Northern America', 'Canada', Decimal('6.34')),
#  ('Europe and Northern America', 'Canada', Decimal('5.83')),
#  ('Europe and Northern America', 'Canada', Decimal('5.66')),
#  ('Europe and Northern America', 'Canada', Decimal('9.46')),
#  ('Latin America and the Caribbean', 'Cayman Islands', Decimal('4.24')),
#  ('Latin America and the Caribbean', 'Cayman Islands', None),
#  ('Sub-Saharan Africa', 'Central African Republic', None),
#  ('Sub-Saharan Africa', 'Central African Republic', None),
#  ('Sub-Saharan Africa', 'Central African Republic', None),
#  ('Sub-Saharan Africa', 'Central African Republic', None),
#  ('Sub-Saharan Africa', 'Central African Republic', None),
#  ('Sub-Saharan Africa', 'Central African Republic', None),
#  ('Sub-Saharan Africa', 'Chad', None),
#  ('Sub-Saharan Africa', 'Chad', None),
#  ('Sub-Saharan Africa', 'Chad', None),
#  ('Sub-Saharan Africa', 'Chad', Decimal('1.13')),
#  ('Sub-Saharan Africa', 'Chad', None),
#  ('Sub-Saharan Africa', 'Chad', None),
#  ('Latin America and the Caribbean', 'Chile', Decimal('6.49')),
#  ('Latin America and the Caribbean', 'Chile', Decimal('6.73')),
#  ('Latin America and the Caribbean', 'Chile', Decimal('6.95')),
#  ('Latin America and the Caribbean', 'Chile', Decimal('7.21')),
#  ('Latin America and the Caribbean', 'Chile', Decimal('7.27')),
#  ('Latin America and the Caribbean', 'Chile', Decimal('10.94')),
#  ('Eastern and South-Eastern Asia', 'China', None),
#  ('Eastern and South-Eastern Asia', 'China', None),
#  ('Eastern and South-Eastern Asia', 'China', Decimal('3.90')),
#  ('Eastern and South-Eastern Asia', 'China', Decimal('4.93')),
#  ('Eastern and South-Eastern Asia', 'China', Decimal('5.15')),
#  ('Eastern and South-Eastern Asia', 'China', Decimal('5.61')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('8.57')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('8.92')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('9.09')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('9.36')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('10.28')),
#  ('Latin America and the Caribbean', 'Colombia', Decimal('15.98')),
#  ('Sub-Saharan Africa', 'Comoros', None),
#  ('Sub-Saharan Africa', 'Comoros', None),
#  ('Sub-Saharan Africa', 'Comoros', None),
#  ('Sub-Saharan Africa', 'Comoros', None),
#  ('Sub-Saharan Africa', 'Comoros', None),
#  ('Sub-Saharan Africa', 'Congo', None),
#  ('Sub-Saharan Africa', 'Congo', None),
#  ('Sub-Saharan Africa', 'Congo', None),
#  ('Sub-Saharan Africa', 'Congo', None),
#  ('Sub-Saharan Africa', 'Congo', None),
#  ('Sub-Saharan Africa', 'Congo', None),
#  ('Oceania', 'Cook Islands', None),
#  ('Oceania', 'Cook Islands', None),
#  ('Oceania', 'Cook Islands', None),
#  ('Oceania', 'Cook Islands', None),
#  ('Oceania', 'Cook Islands', None),
#  ('Oceania', 'Cook Islands', None),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('8.42')),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('8.09')),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('7.73')),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('9.01')),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('10.81')),
#  ('Latin America and the Caribbean', 'Costa Rica', Decimal('16.43')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", None),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", None),
#  ('Latin America and the Caribbean', 'Cuba', Decimal('2.40')),
#  ('Latin America and the Caribbean', 'Cuba', Decimal('2.00')),
#  ('Latin America and the Caribbean', 'Cuba', Decimal('1.70')),
#  ('Latin America and the Caribbean', 'Cuba', Decimal('1.70')),
#  ('Latin America and the Caribbean', 'Cuba', None),
#  ('Latin America and the Caribbean', 'Cuba', None),
#  ('Latin America and the Caribbean', 'Curaçao', None),
#  ('Latin America and the Caribbean', 'Curaçao', None),
#  ('Latin America and the Caribbean', 'Curaçao', None),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('15.03')),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('13.01')),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('11.16')),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('8.50')),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('7.15')),
#  ('Northern Africa and Western Asia', 'Cyprus', Decimal('7.76')),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", None),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", None),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", None),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", None),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", None),
#  ('Eastern and South-Eastern Asia', "Democratic People's Republic of Korea", None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', None),
#  ('Sub-Saharan Africa', 'Djibouti', None),
#  ('Sub-Saharan Africa', 'Djibouti', None),
#  ('Sub-Saharan Africa', 'Djibouti', Decimal('26.06')),
#  ('Sub-Saharan Africa', 'Djibouti', None),
#  ('Sub-Saharan Africa', 'Djibouti', None),
#  ('Sub-Saharan Africa', 'Djibouti', None),
#  ('Latin America and the Caribbean', 'Dominica', None),
#  ('Latin America and the Caribbean', 'Dominica', None),
#  ('Latin America and the Caribbean', 'Dominica', None),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('7.61')),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('7.28')),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('5.83')),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('5.86')),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('6.18')),
#  ('Latin America and the Caribbean', 'Dominican Republic', Decimal('6.13')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('3.62')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('4.60')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('3.84')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('3.53')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('3.81')),
#  ('Latin America and the Caribbean', 'Ecuador', Decimal('6.11')),
#  ('Northern Africa and Western Asia', 'Egypt', None),
#  ('Northern Africa and Western Asia', 'Egypt', None),
#  ('Northern Africa and Western Asia', 'Egypt', None),
#  ('Northern Africa and Western Asia', 'Egypt', None),
#  ('Northern Africa and Western Asia', 'Egypt', None),
#  ('Northern Africa and Western Asia', 'Egypt', None),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('4.00')),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('4.42')),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('4.39')),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('4.01')),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('4.17')),
#  ('Latin America and the Caribbean', 'El Salvador', Decimal('5.01')),
#  ('Sub-Saharan Africa', 'Equatorial Guinea', None),
#  ('Sub-Saharan Africa', 'Equatorial Guinea', None),
#  ('Sub-Saharan Africa', 'Equatorial Guinea', None),
#  ('Sub-Saharan Africa', 'Eritrea', None),
#  ('Sub-Saharan Africa', 'Eritrea', None),
#  ('Sub-Saharan Africa', 'Eswatini', None),
#  ('Sub-Saharan Africa', 'Eswatini', Decimal('22.72')),
#  ('Sub-Saharan Africa', 'Eswatini', None),
#  ('Sub-Saharan Africa', 'Eswatini', None),
#  ('Sub-Saharan Africa', 'Eswatini', None),
#  ('Sub-Saharan Africa', 'Eswatini', None),
#  ('Sub-Saharan Africa', 'Ethiopia', None),
#  ('Sub-Saharan Africa', 'Ethiopia', None),
#  ('Sub-Saharan Africa', 'Ethiopia', None),
#  ('Sub-Saharan Africa', 'Ethiopia', None),
#  ('Sub-Saharan Africa', 'Ethiopia', None),
#  ('Sub-Saharan Africa', 'Ethiopia', None),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', None),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', None),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', None),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', None),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', None),
#  ('Latin America and the Caribbean', 'Falkland Islands (Malvinas)', None),
#  ('Oceania', 'Fiji', None),
#  ('Oceania', 'Fiji', Decimal('4.32')),
#  ('Oceania', 'Fiji', None),
#  ('Oceania', 'Fiji', None),
#  ('Oceania', 'Fiji', None),
#  ('Oceania', 'Fiji', None),
#  ('Latin America and the Caribbean', 'French Guiana', None),
#  ('Latin America and the Caribbean', 'French Guiana', None),
#  ('Latin America and the Caribbean', 'French Guiana', None),
#  ('Latin America and the Caribbean', 'French Guiana', None),
#  ('Latin America and the Caribbean', 'French Guiana', None),
#  ('Latin America and the Caribbean', 'French Guiana', None),
#  ('Oceania', 'French Polynesia', None),
#  ('Oceania', 'French Polynesia', None),
#  ('Oceania', 'French Polynesia', None),
#  ('Oceania', 'French Polynesia', None),
#  ('Oceania', 'French Polynesia', None),
#  ('Oceania', 'French Polynesia', None),
#  ('Sub-Saharan Africa', 'Gabon', None),
#  ('Sub-Saharan Africa', 'Gabon', None),
#  ('Sub-Saharan Africa', 'Gabon', None),
#  ('Sub-Saharan Africa', 'Gabon', None),
#  ('Sub-Saharan Africa', 'Gabon', None),
#  ('Sub-Saharan Africa', 'Gabon', None),
#  ('Sub-Saharan Africa', 'Gambia', None),
#  ('Sub-Saharan Africa', 'Gambia', None),
#  ('Sub-Saharan Africa', 'Gambia', None),
#  ('Sub-Saharan Africa', 'Gambia', None),
#  ('Sub-Saharan Africa', 'Gambia', None),
#  ('Sub-Saharan Africa', 'Gambia', None),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('16.51')),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('16.60')),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('13.94')),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('12.67')),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('11.57')),
#  ('Northern Africa and Western Asia', 'Georgia', Decimal('11.73')),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('6.81')),
#  ('Sub-Saharan Africa', 'Ghana', None),
#  ('Sub-Saharan Africa', 'Ghana', Decimal('3.37')),
#  ('Sub-Saharan Africa', 'Ghana', None),
#  ('Sub-Saharan Africa', 'Ghana', None),
#  ('Sub-Saharan Africa', 'Ghana', None),
#  ('Europe and Northern America', 'Greenland', Decimal('9.10')),
#  ('Europe and Northern America', 'Greenland', None),
#  ('Europe and Northern America', 'Greenland', None),
#  ('Europe and Northern America', 'Greenland', None),
#  ('Europe and Northern America', 'Greenland', None),
#  ('Europe and Northern America', 'Greenland', None),
#  ('Latin America and the Caribbean', 'Grenada', Decimal('22.90')),
#  ('Latin America and the Caribbean', 'Grenada', None),
#  ('Latin America and the Caribbean', 'Grenada', None),
#  ('Latin America and the Caribbean', 'Guadeloupe', None),
#  ('Latin America and the Caribbean', 'Guadeloupe', None),
#  ('Latin America and the Caribbean', 'Guadeloupe', None),
#  ('Latin America and the Caribbean', 'Guadeloupe', None),
#  ('Latin America and the Caribbean', 'Guadeloupe', None),
#  ('Latin America and the Caribbean', 'Guadeloupe', None),
#  ('Oceania', 'Guam', Decimal('6.90')),
#  ('Oceania', 'Guam', Decimal('5.40')),
#  ('Oceania', 'Guam', None),
#  ('Oceania', 'Guam', None),
#  ('Oceania', 'Guam', None),
#  ('Oceania', 'Guam', None),
#  ('Latin America and the Caribbean', 'Guatemala', Decimal('2.51')),
#  ('Latin America and the Caribbean', 'Guatemala', Decimal('2.58')),
#  ('Latin America and the Caribbean', 'Guatemala', Decimal('2.46')),
#  ('Latin America and the Caribbean', 'Guatemala', Decimal('2.28')),
#  ('Latin America and the Caribbean', 'Guatemala', Decimal('2.19')),
#  ('Latin America and the Caribbean', 'Guatemala', None),
#  ('Sub-Saharan Africa', 'Guinea', None),
#  ('Sub-Saharan Africa', 'Guinea', None),
#  ('Sub-Saharan Africa', 'Guinea', None),
#  ('Sub-Saharan Africa', 'Guinea', None),
#  ('Sub-Saharan Africa', 'Guinea', Decimal('5.02')),
#  ('Sub-Saharan Africa', 'Guinea', None),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', None),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', None),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', None),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', Decimal('3.20')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', None),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', None),
#  ('Latin America and the Caribbean', 'Guyana', None),
#  ('Latin America and the Caribbean', 'Guyana', None),
#  ('Latin America and the Caribbean', 'Guyana', None),
#  ('Latin America and the Caribbean', 'Guyana', Decimal('14.02')),
#  ('Latin America and the Caribbean', 'Guyana', Decimal('13.52')),
#  ('Latin America and the Caribbean', 'Guyana', None),
#  ('Latin America and the Caribbean', 'Haiti', None),
#  ('Latin America and the Caribbean', 'Haiti', None),
#  ('Latin America and the Caribbean', 'Haiti', None),
#  ('Latin America and the Caribbean', 'Haiti', None),
#  ('Latin America and the Caribbean', 'Haiti', None),
#  ('Latin America and the Caribbean', 'Haiti', None),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('6.15')),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('6.73')),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('5.53')),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('5.62')),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('5.55')),
#  ('Latin America and the Caribbean', 'Honduras', Decimal('10.68')),
#  ('Central and Southern Asia', 'India', None),
#  ('Central and Southern Asia', 'India', None),
#  ('Central and Southern Asia', 'India', None),
#  ('Central and Southern Asia', 'India', Decimal('7.65')),
#  ('Central and Southern Asia', 'India', Decimal('6.51')),
#  ('Central and Southern Asia', 'India', Decimal('7.86')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('4.51')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('4.30')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('3.78')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('4.39')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('3.59')),
#  ('Eastern and South-Eastern Asia', 'Indonesia', Decimal('4.25')),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', None),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', None),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', None),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', None),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', None),
#  ('Central and Southern Asia', 'Iran (Islamic Republic of)', None),
#  ('Northern Africa and Western Asia', 'Iraq', None),
#  ('Northern Africa and Western Asia', 'Iraq', Decimal('10.82')),
#  ('Northern Africa and Western Asia', 'Iraq', Decimal('13.02')),
#  ('Northern Africa and Western Asia', 'Iraq', None),
#  ('Northern Africa and Western Asia', 'Iraq', None),
#  ('Northern Africa and Western Asia', 'Iraq', None),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('5.18')),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('4.72')),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('4.14')),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('3.92')),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('3.73')),
#  ('Northern Africa and Western Asia', 'Israel', Decimal('4.17')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('13.51')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('8.63')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('7.40')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('5.47')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('4.99')),
#  ('Latin America and the Caribbean', 'Jamaica', Decimal('6.50')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('3.39')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('3.13')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('2.82')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('2.47')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('2.35')),
#  ('Eastern and South-Eastern Asia', 'Japan', Decimal('2.81')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('13.08')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('15.28')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('18.12')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('18.26')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('16.80')),
#  ('Northern Africa and Western Asia', 'Jordan', Decimal('19.21')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('4.93')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('4.96')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('4.90')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('4.85')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('4.80')),
#  ('Central and Southern Asia', 'Kazakhstan', Decimal('4.89')),
#  ('Sub-Saharan Africa', 'Kenya', None),
#  ('Sub-Saharan Africa', 'Kenya', Decimal('2.76')),
#  ('Sub-Saharan Africa', 'Kenya', None),
#  ('Sub-Saharan Africa', 'Kenya', None),
#  ('Sub-Saharan Africa', 'Kenya', Decimal('5.01')),
#  ('Sub-Saharan Africa', 'Kenya', None),
#  ('Oceania', 'Kiribati', Decimal('9.33')),
#  ('Oceania', 'Kiribati', None),
#  ('Oceania', 'Kiribati', None),
#  ('Oceania', 'Kiribati', None),
#  ('Oceania', 'Kiribati', Decimal('8.56')),
#  ('Oceania', 'Kiribati', Decimal('10.97')),
#  ('Northern Africa and Western Asia', 'Kuwait', Decimal('2.20')),
#  ('Northern Africa and Western Asia', 'Kuwait', Decimal('2.16')),
#  ('Northern Africa and Western Asia', 'Kuwait', None),
#  ('Northern Africa and Western Asia', 'Kuwait', None),
#  ('Northern Africa and Western Asia', 'Kuwait', None),
#  ('Northern Africa and Western Asia', 'Kuwait', None),
#  ('Central and Southern Asia', 'Kyrgyzstan', None),
#  ('Central and Southern Asia', 'Kyrgyzstan', None),
#  ('Central and Southern Asia', 'Kyrgyzstan', None),
#  ('Central and Southern Asia', 'Kyrgyzstan', None),
#  ('Central and Southern Asia', 'Kyrgyzstan', None),
#  ('Central and Southern Asia', 'Kyrgyzstan', None),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", None),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", None),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", None),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", None),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", None),
#  ('Eastern and South-Eastern Asia', "Lao People's Democratic Republic", None),
#  ('Northern Africa and Western Asia', 'Lebanon', None),
#  ('Northern Africa and Western Asia', 'Lebanon', None),
#  ('Northern Africa and Western Asia', 'Lebanon', None),
#  ('Northern Africa and Western Asia', 'Lebanon', None),
#  ('Northern Africa and Western Asia', 'Lebanon', Decimal('11.30')),
#  ('Northern Africa and Western Asia', 'Lebanon', None),
#  ('Sub-Saharan Africa', 'Lesotho', None),
#  ('Sub-Saharan Africa', 'Lesotho', None),
#  ('Sub-Saharan Africa', 'Lesotho', None),
#  ('Sub-Saharan Africa', 'Lesotho', None),
#  ('Sub-Saharan Africa', 'Lesotho', Decimal('16.88')),
#  ('Sub-Saharan Africa', 'Lesotho', None),
#  ('Sub-Saharan Africa', 'Liberia', None),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('3.08')),
#  ('Sub-Saharan Africa', 'Liberia', Decimal('5.95')),
#  ('Sub-Saharan Africa', 'Liberia', None),
#  ('Sub-Saharan Africa', 'Liberia', None),
#  ('Sub-Saharan Africa', 'Liberia', None),
#  ('Northern Africa and Western Asia', 'Libya', None),
#  ('Northern Africa and Western Asia', 'Libya', None),
#  ('Northern Africa and Western Asia', 'Libya', None),
#  ('Northern Africa and Western Asia', 'Libya', None),
#  ('Northern Africa and Western Asia', 'Libya', None),
#  ('Northern Africa and Western Asia', 'Libya', None),
#  ('Sub-Saharan Africa', 'Madagascar', Decimal('1.79')),
#  ('Sub-Saharan Africa', 'Madagascar', None),
#  ('Sub-Saharan Africa', 'Madagascar', None),
#  ('Sub-Saharan Africa', 'Madagascar', None),
#  ('Sub-Saharan Africa', 'Madagascar', None),
#  ('Sub-Saharan Africa', 'Madagascar', None),
#  ('Sub-Saharan Africa', 'Malawi', None),
#  ('Sub-Saharan Africa', 'Malawi', None),
#  ('Sub-Saharan Africa', 'Malawi', Decimal('3.54')),
#  ('Sub-Saharan Africa', 'Malawi', None),
#  ('Sub-Saharan Africa', 'Malawi', None),
#  ('Sub-Saharan Africa', 'Malawi', Decimal('0.91')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('3.10')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('3.44')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('3.41')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('3.30')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('3.26')),
#  ('Eastern and South-Eastern Asia', 'Malaysia', Decimal('4.54')),
#  ('Central and Southern Asia', 'Maldives', None),
#  ('Central and Southern Asia', 'Maldives', Decimal('5.77')),
#  ('Central and Southern Asia', 'Maldives', None),
#  ('Central and Southern Asia', 'Maldives', None),
#  ('Central and Southern Asia', 'Maldives', Decimal('4.56')),
#  ('Central and Southern Asia', 'Maldives', None),
#  ('Sub-Saharan Africa', 'Mali', Decimal('7.73')),
#  ('Sub-Saharan Africa', 'Mali', Decimal('1.37')),
#  ('Sub-Saharan Africa', 'Mali', Decimal('7.41')),
#  ('Sub-Saharan Africa', 'Mali', Decimal('1.62')),
#  ('Sub-Saharan Africa', 'Mali', None),
#  ('Sub-Saharan Africa', 'Mali', Decimal('3.53')),
#  ('Oceania', 'Marshall Islands', None),
#  ('Oceania', 'Marshall Islands', None),
#  ('Oceania', 'Marshall Islands', None),
#  ('Oceania', 'Marshall Islands', None),
#  ('Oceania', 'Marshall Islands', Decimal('6.34')),
#  ('Oceania', 'Marshall Islands', None),
#  ('Latin America and the Caribbean', 'Martinique', None),
#  ('Latin America and the Caribbean', 'Martinique', None),
#  ('Latin America and the Caribbean', 'Martinique', None),
#  ('Latin America and the Caribbean', 'Martinique', None),
#  ('Latin America and the Caribbean', 'Martinique', None),
#  ('Latin America and the Caribbean', 'Martinique', None),
#  ('Sub-Saharan Africa', 'Mauritania', None),
#  ('Sub-Saharan Africa', 'Mauritania', None),
#  ('Sub-Saharan Africa', 'Mauritania', Decimal('10.34')),
#  ('Sub-Saharan Africa', 'Mauritania', None),
#  ('Sub-Saharan Africa', 'Mauritania', Decimal('10.42')),
#  ('Sub-Saharan Africa', 'Mauritania', None),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('7.41')),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('6.81')),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('6.75')),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('6.43')),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('6.33')),
#  ('Sub-Saharan Africa', 'Mauritius', Decimal('8.63')),
#  ('Sub-Saharan Africa', 'Mayotte', None),
#  ('Sub-Saharan Africa', 'Mayotte', None),
#  ('Sub-Saharan Africa', 'Mayotte', None),
#  ('Sub-Saharan Africa', 'Mayotte', None),
#  ('Sub-Saharan Africa', 'Mayotte', None),
#  ('Sub-Saharan Africa', 'Mayotte', None),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('4.31')),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('3.85')),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('3.42')),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('3.27')),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('3.48')),
#  ('Latin America and the Caribbean', 'Mexico', Decimal('4.44')),
#  ('Oceania', 'Micronesia (Federated States of)', None),
#  ('Oceania', 'Micronesia (Federated States of)', None),
#  ('Oceania', 'Micronesia (Federated States of)', None),
#  ('Oceania', 'Micronesia (Federated States of)', None),
#  ('Oceania', 'Micronesia (Federated States of)', None),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('4.86')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('7.24')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('6.36')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('5.38')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('9.27')),
#  ('Eastern and South-Eastern Asia', 'Mongolia', Decimal('6.59')),
#  ('Latin America and the Caribbean', 'Montserrat', None),
#  ('Latin America and the Caribbean', 'Montserrat', None),
#  ('Latin America and the Caribbean', 'Montserrat', None),
#  ('Latin America and the Caribbean', 'Montserrat', None),
#  ('Latin America and the Caribbean', 'Montserrat', None),
#  ('Latin America and the Caribbean', 'Montserrat', None),
#  ('Northern Africa and Western Asia', 'Morocco', Decimal('9.46')),
#  ('Northern Africa and Western Asia', 'Morocco', Decimal('9.30')),
#  ('Northern Africa and Western Asia', 'Morocco', None),
#  ('Northern Africa and Western Asia', 'Morocco', None),
#  ('Northern Africa and Western Asia', 'Morocco', None),
#  ('Northern Africa and Western Asia', 'Morocco', None),
#  ('Sub-Saharan Africa', 'Mozambique', Decimal('3.43')),
#  ('Sub-Saharan Africa', 'Mozambique', None),
#  ('Sub-Saharan Africa', 'Mozambique', None),
#  ('Sub-Saharan Africa', 'Mozambique', None),
#  ('Sub-Saharan Africa', 'Mozambique', None),
#  ('Sub-Saharan Africa', 'Mozambique', None),
#  ('Eastern and South-Eastern Asia', 'Myanmar', Decimal('0.77')),
#  ('Eastern and South-Eastern Asia', 'Myanmar', None),
#  ('Eastern and South-Eastern Asia', 'Myanmar', Decimal('1.36')),
#  ('Eastern and South-Eastern Asia', 'Myanmar', Decimal('0.77')),
#  ('Eastern and South-Eastern Asia', 'Myanmar', Decimal('0.41')),
#  ('Eastern and South-Eastern Asia', 'Myanmar', Decimal('1.48')),
#  ('Sub-Saharan Africa', 'Namibia', None),
#  ('Sub-Saharan Africa', 'Namibia', Decimal('23.35')),
#  ('Sub-Saharan Africa', 'Namibia', None),
#  ('Sub-Saharan Africa', 'Namibia', Decimal('19.88')),
#  ('Sub-Saharan Africa', 'Namibia', None),
#  ('Sub-Saharan Africa', 'Namibia', None),
#  ('Oceania', 'Nauru', None),
#  ('Oceania', 'Nauru', None),
#  ('Oceania', 'Nauru', None),
#  ('Oceania', 'Nauru', None),
#  ('Oceania', 'Nauru', None),
#  ('Oceania', 'Nauru', None),
#  ('Central and Southern Asia', 'Nepal', Decimal('3.10')),
#  ('Central and Southern Asia', 'Nepal', None),
#  ('Central and Southern Asia', 'Nepal', Decimal('10.66')),
#  ('Central and Southern Asia', 'Nepal', None),
#  ('Central and Southern Asia', 'Nepal', None),
#  ('Central and Southern Asia', 'Nepal', None),
#  ('Oceania', 'New Caledonia', None),
#  ('Oceania', 'New Caledonia', None),
#  ('Oceania', 'New Caledonia', Decimal('11.68')),
#  ('Oceania', 'New Caledonia', Decimal('11.70')),
#  ('Oceania', 'New Caledonia', Decimal('10.88')),
#  ('Oceania', 'New Caledonia', Decimal('13.56')),
#  ('Oceania', 'New Zealand', Decimal('5.42')),
#  ('Oceania', 'New Zealand', Decimal('5.15')),
#  ('Oceania', 'New Zealand', Decimal('4.74')),
#  ('Oceania', 'New Zealand', Decimal('4.34')),
#  ('Oceania', 'New Zealand', Decimal('4.11')),
#  ('Oceania', 'New Zealand', Decimal('4.60')),
#  ('Latin America and the Caribbean', 'Nicaragua', Decimal('4.70')),
#  ('Latin America and the Caribbean', 'Nicaragua', Decimal('3.90')),
#  ('Latin America and the Caribbean', 'Nicaragua', Decimal('3.30')),
#  ('Latin America and the Caribbean', 'Nicaragua', Decimal('5.20')),
#  ('Latin America and the Caribbean', 'Nicaragua', None),
#  ('Latin America and the Caribbean', 'Nicaragua', None),
#  ('Sub-Saharan Africa', 'Niger', None),
#  ('Sub-Saharan Africa', 'Niger', None),
#  ('Sub-Saharan Africa', 'Niger', Decimal('7.77')),
#  ('Sub-Saharan Africa', 'Niger', None),
#  ('Sub-Saharan Africa', 'Niger', None),
#  ('Sub-Saharan Africa', 'Niger', None),
#  ('Sub-Saharan Africa', 'Nigeria', Decimal('4.31')),
#  ('Sub-Saharan Africa', 'Nigeria', Decimal('7.06')),
#  ('Sub-Saharan Africa', 'Nigeria', Decimal('8.39')),
#  ('Sub-Saharan Africa', 'Nigeria', None),
#  ('Sub-Saharan Africa', 'Nigeria', Decimal('10.70')),
#  ('Sub-Saharan Africa', 'Nigeria', None),
#  ('Oceania', 'Niue', None),
#  ('Oceania', 'Niue', None),
#  ('Oceania', 'Niue', None),
#  ('Oceania', 'Niue', None),
#  ('Oceania', 'Niue', None),
#  ('Oceania', 'Niue', None),
#  ('Oceania', 'Northern Mariana Islands', None),
#  ('Oceania', 'Northern Mariana Islands', None),
#  ('Oceania', 'Northern Mariana Islands', None),
#  ('Oceania', 'Northern Mariana Islands', None),
#  ('Oceania', 'Northern Mariana Islands', None),
#  ('Oceania', 'Northern Mariana Islands', None),
#  ('Northern Africa and Western Asia', 'Oman', None),
#  ('Northern Africa and Western Asia', 'Oman', Decimal('3.27')),
#  ('Northern Africa and Western Asia', 'Oman', None),
#  ('Northern Africa and Western Asia', 'Oman', Decimal('1.80')),
#  ('Northern Africa and Western Asia', 'Oman', None),
#  ('Northern Africa and Western Asia', 'Oman', Decimal('2.94')),
#  ('Central and Southern Asia', 'Pakistan', Decimal('3.57')),
#  ('Central and Southern Asia', 'Pakistan', None),
#  ('Central and Southern Asia', 'Pakistan', None),
#  ('Central and Southern Asia', 'Pakistan', Decimal('4.08')),
#  ('Central and Southern Asia', 'Pakistan', Decimal('4.83')),
#  ('Central and Southern Asia', 'Pakistan', None),
#  ('Oceania', 'Palau', None),
#  ('Oceania', 'Palau', None),
#  ('Oceania', 'Palau', None),
#  ('Oceania', 'Palau', None),
#  ('Oceania', 'Palau', None),
#  ('Oceania', 'Palau', Decimal('0.77')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('4.40')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('4.84')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('5.46')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('5.31')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('6.41')),
#  ('Latin America and the Caribbean', 'Panama', Decimal('18.55')),
#  ('Oceania', 'Papua New Guinea', None),
#  ('Oceania', 'Papua New Guinea', None),
#  ('Oceania', 'Papua New Guinea', None),
#  ('Oceania', 'Papua New Guinea', None),
#  ('Oceania', 'Papua New Guinea', None),
#  ('Oceania', 'Papua New Guinea', None),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('4.56')),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('5.25')),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('4.61')),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('6.22')),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('6.59')),
#  ('Latin America and the Caribbean', 'Paraguay', Decimal('7.55')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('3.27')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('3.74')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('3.69')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('3.49')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('3.38')),
#  ('Latin America and the Caribbean', 'Peru', Decimal('7.18')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('3.07')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('2.70')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('2.55')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('2.34')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('2.24')),
#  ('Eastern and South-Eastern Asia', 'Philippines', Decimal('2.52')),
#  ('Latin America and the Caribbean', 'Puerto Rico', Decimal('12.00')),
#  ('Latin America and the Caribbean', 'Puerto Rico', Decimal('11.80')),
#  ('Latin America and the Caribbean', 'Puerto Rico', Decimal('10.80')),
#  ('Latin America and the Caribbean', 'Puerto Rico', Decimal('9.20')),
#  ('Latin America and the Caribbean', 'Puerto Rico', Decimal('8.30')),
#  ('Latin America and the Caribbean', 'Puerto Rico', None),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('0.17')),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('0.15')),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('0.14')),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('0.11')),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('0.10')),
#  ('Northern Africa and Western Asia', 'Qatar', Decimal('0.14')),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', None),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', None),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', None),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', None),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', None),
#  ('Eastern and South-Eastern Asia', 'Republic of Korea', None),
#  ('Sub-Saharan Africa', 'Réunion', None),
#  ('Sub-Saharan Africa', 'Réunion', None),
#  ('Sub-Saharan Africa', 'Réunion', None),
#  ('Sub-Saharan Africa', 'Réunion', None),
#  ('Sub-Saharan Africa', 'Réunion', None),
#  ('Sub-Saharan Africa', 'Réunion', None),
#  ('Sub-Saharan Africa', 'Rwanda', None),
#  ('Sub-Saharan Africa', 'Rwanda', None),
#  ('Sub-Saharan Africa', 'Rwanda', Decimal('11.88')),
#  ('Sub-Saharan Africa', 'Rwanda', Decimal('10.76')),
#  ('Sub-Saharan Africa', 'Rwanda', Decimal('11.24')),
#  ('Sub-Saharan Africa', 'Rwanda', Decimal('11.83')),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', None),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', None),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', None),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', None),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', None),
#  ('Latin America and the Caribbean', 'Saint Barthélemy', None),
#  ('Sub-Saharan Africa', 'Saint Helena', None),
#  ('Sub-Saharan Africa', 'Saint Helena', None),
#  ('Sub-Saharan Africa', 'Saint Helena', None),
#  ('Sub-Saharan Africa', 'Saint Helena', None),
#  ('Sub-Saharan Africa', 'Saint Helena', None),
#  ('Sub-Saharan Africa', 'Saint Helena', None),
#  ('Latin America and the Caribbean', 'Saint Kitts and Nevis', None),
#  ('Latin America and the Caribbean', 'Saint Kitts and Nevis', None),
#  ('Latin America and the Caribbean', 'Saint Kitts and Nevis', None),
#  ('Latin America and the Caribbean', 'Saint Lucia', None),
#  ('Latin America and the Caribbean', 'Saint Lucia', None),
#  ('Latin America and the Caribbean', 'Saint Lucia', None),
#  ('Latin America and the Caribbean', 'Saint Lucia', None),
#  ('Latin America and the Caribbean', 'Saint Lucia', None),
#  ('Latin America and the Caribbean', 'Saint Lucia', None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', None),
#  ('Latin America and the Caribbean', 'Saint Martin (French Part)', None),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', None),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', None),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', None),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', None),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', None),
#  ('Europe and Northern America', 'Saint Pierre and Miquelon', None),
#  ('Latin America and the Caribbean', 'Saint Vincent and the Grenadines', None),
#  ('Latin America and the Caribbean', 'Saint Vincent and the Grenadines', None),
#  ('Latin America and the Caribbean', 'Saint Vincent and the Grenadines', None),
#  ('Latin America and the Caribbean', 'Saint Vincent and the Grenadines', None),
#  ('Oceania', 'Samoa', None),
#  ('Oceania', 'Samoa', None),
#  ('Oceania', 'Samoa', Decimal('9.40')),
#  ('Oceania', 'Samoa', None),
#  ('Oceania', 'Samoa', None),
#  ('Oceania', 'Samoa', None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', None),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', None),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('5.60')),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('5.60')),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('5.89')),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('6.03')),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('5.64')),
#  ('Northern Africa and Western Asia', 'Saudi Arabia', Decimal('7.66')),
#  ('Sub-Saharan Africa', 'Senegal', Decimal('6.76')),
#  ('Sub-Saharan Africa', 'Senegal', Decimal('4.46')),
#  ('Sub-Saharan Africa', 'Senegal', Decimal('4.08')),
#  ('Sub-Saharan Africa', 'Senegal', Decimal('3.57')),
#  ('Sub-Saharan Africa', 'Senegal', Decimal('2.86')),
#  ('Sub-Saharan Africa', 'Senegal', None),
#  ('Sub-Saharan Africa', 'Seychelles', Decimal('4.15')),
#  ('Sub-Saharan Africa', 'Seychelles', Decimal('3.96')),
#  ('Sub-Saharan Africa', 'Seychelles', Decimal('3.71')),
#  ('Sub-Saharan Africa', 'Seychelles', Decimal('3.53')),
#  ('Sub-Saharan Africa', 'Seychelles', Decimal('2.97')),
#  ('Sub-Saharan Africa', 'Sierra Leone', None),
#  ('Sub-Saharan Africa', 'Sierra Leone', None),
#  ('Sub-Saharan Africa', 'Sierra Leone', None),
#  ('Sub-Saharan Africa', 'Sierra Leone', Decimal('3.19')),
#  ('Sub-Saharan Africa', 'Sierra Leone', None),
#  ('Sub-Saharan Africa', 'Sierra Leone', None),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('3.79')),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('4.08')),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('4.20')),
#  ('Eastern and South-Eastern Asia', 'Singapore', None),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('3.10')),
#  ('Eastern and South-Eastern Asia', 'Singapore', Decimal('4.10')),
#  ('Latin America and the Caribbean', 'Sint Maarten (Dutch part)', None),
#  ('Latin America and the Caribbean', 'Sint Maarten (Dutch part)', None),
#  ('Latin America and the Caribbean', 'Sint Maarten (Dutch part)', None),
#  ('Oceania', 'Solomon Islands', None),
#  ('Oceania', 'Solomon Islands', None),
#  ('Oceania', 'Solomon Islands', None),
#  ('Oceania', 'Solomon Islands', None),
#  ('Oceania', 'Solomon Islands', None),
#  ('Oceania', 'Solomon Islands', None),
#  ('Sub-Saharan Africa', 'Somalia', None),
#  ('Sub-Saharan Africa', 'Somalia', None),
#  ('Sub-Saharan Africa', 'Somalia', None),
#  ('Sub-Saharan Africa', 'Somalia', None),
#  ('Sub-Saharan Africa', 'Somalia', Decimal('18.83')),
#  ('Sub-Saharan Africa', 'Somalia', None),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('22.87')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('24.02')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('23.99')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('24.22')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('25.54')),
#  ('Sub-Saharan Africa', 'South Africa', Decimal('24.34')),
#  ('Sub-Saharan Africa', 'South Sudan', None),
#  ('Sub-Saharan Africa', 'South Sudan', None),
#  ('Sub-Saharan Africa', 'South Sudan', None),
#  ('Sub-Saharan Africa', 'South Sudan', None),
#  ('Sub-Saharan Africa', 'South Sudan', None),
#  ('Sub-Saharan Africa', 'South Sudan', None),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('4.52')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('4.24')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('4.05')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('4.32')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('4.67')),
#  ('Central and Southern Asia', 'Sri Lanka', Decimal('5.36')),
#  ('Northern Africa and Western Asia', 'State of Palestine', None),
#  ('Northern Africa and Western Asia', 'State of Palestine', None),
#  ('Northern Africa and Western Asia', 'State of Palestine', None),
#  ('Northern Africa and Western Asia', 'State of Palestine', None),
#  ('Northern Africa and Western Asia', 'State of Palestine', None),
#  ('Northern Africa and Western Asia', 'State of Palestine', None),
#  ('Northern Africa and Western Asia', 'Sudan', None),
#  ('Northern Africa and Western Asia', 'Sudan', None),
#  ('Northern Africa and Western Asia', 'Sudan', None),
#  ('Northern Africa and Western Asia', 'Sudan', None),
#  ('Northern Africa and Western Asia', 'Sudan', None),
#  ('Northern Africa and Western Asia', 'Sudan', None),
#  ('Latin America and the Caribbean', 'Suriname', Decimal('7.22')),
#  ('Latin America and the Caribbean', 'Suriname', Decimal('7.92')),
#  ('Latin America and the Caribbean', 'Suriname', None),
#  ('Latin America and the Caribbean', 'Suriname', None),
#  ('Latin America and the Caribbean', 'Suriname', None),
#  ('Latin America and the Caribbean', 'Suriname', None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', None),
#  ('Northern Africa and Western Asia', 'Syrian Arab Republic', None),
#  ('Central and Southern Asia', 'Tajikistan', None),
#  ('Central and Southern Asia', 'Tajikistan', Decimal('6.90')),
#  ('Central and Southern Asia', 'Tajikistan', None),
#  ('Central and Southern Asia', 'Tajikistan', None),
#  ('Central and Southern Asia', 'Tajikistan', None),
#  ('Central and Southern Asia', 'Tajikistan', None),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('0.60')),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('0.69')),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('0.83')),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('0.77')),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('0.72')),
#  ('Eastern and South-Eastern Asia', 'Thailand', Decimal('1.10')),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', None),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', Decimal('4.66')),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', None),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', None),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', None),
#  ('Eastern and South-Eastern Asia', 'Timor-Leste', None),
#  ('Sub-Saharan Africa', 'Togo', Decimal('2.20')),
#  ('Sub-Saharan Africa', 'Togo', None),
#  ('Sub-Saharan Africa', 'Togo', Decimal('3.74')),
#  ('Sub-Saharan Africa', 'Togo', None),
#  ('Sub-Saharan Africa', 'Togo', None),
#  ('Sub-Saharan Africa', 'Togo', None),
#  ('Oceania', 'Tokelau', None),
#  ('Oceania', 'Tokelau', None),
#  ('Oceania', 'Tokelau', None),
#  ('Oceania', 'Tokelau', None),
#  ('Oceania', 'Tokelau', None),
#  ('Oceania', 'Tokelau', None),
#  ('Oceania', 'Tonga', None),
#  ('Oceania', 'Tonga', None),
#  ('Oceania', 'Tonga', None),
#  ('Oceania', 'Tonga', Decimal('2.25')),
#  ('Oceania', 'Tonga', None),
#  ('Oceania', 'Tonga', None),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', Decimal('2.43')),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', Decimal('3.21')),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', None),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', None),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', Decimal('3.52')),
#  ('Latin America and the Caribbean', 'Trinidad and Tobago', Decimal('4.21')),
#  ('Northern Africa and Western Asia', 'Tunisia', Decimal('15.16')),
#  ('Northern Africa and Western Asia', 'Tunisia', Decimal('15.56')),
#  ('Northern Africa and Western Asia', 'Tunisia', Decimal('15.33')),
#  ('Northern Africa and Western Asia', 'Tunisia', Decimal('15.46')),
#  ('Northern Africa and Western Asia', 'Tunisia', Decimal('15.13')),
#  ('Northern Africa and Western Asia', 'Tunisia', None),
#  ('Northern Africa and Western Asia', 'Türkiye', None),
#  ('Northern Africa and Western Asia', 'Türkiye', None),
#  ('Northern Africa and Western Asia', 'Türkiye', None),
#  ('Northern Africa and Western Asia', 'Türkiye', None),
#  ('Northern Africa and Western Asia', 'Türkiye', None),
#  ('Northern Africa and Western Asia', 'Türkiye', None),
#  ('Central and Southern Asia', 'Turkmenistan', None),
#  ('Central and Southern Asia', 'Turkmenistan', None),
#  ('Central and Southern Asia', 'Turkmenistan', None),
#  ('Central and Southern Asia', 'Turkmenistan', None),
#  ('Central and Southern Asia', 'Turkmenistan', None),
#  ('Central and Southern Asia', 'Turkmenistan', None),
#  ('Latin America and the Caribbean', 'Turks and Caicos Islands', None),
#  ('Latin America and the Caribbean', 'Turks and Caicos Islands', None),
#  ('Latin America and the Caribbean', 'Turks and Caicos Islands', None),
#  ('Latin America and the Caribbean', 'Turks and Caicos Islands', None),
#  ('Oceania', 'Tuvalu', None),
#  ('Oceania', 'Tuvalu', Decimal('8.49')),
#  ('Oceania', 'Tuvalu', Decimal('26.55')),
#  ('Oceania', 'Tuvalu', None),
#  ('Oceania', 'Tuvalu', None),
#  ('Oceania', 'Tuvalu', None),
#  ('Sub-Saharan Africa', 'Uganda', None),
#  ('Sub-Saharan Africa', 'Uganda', None),
#  ('Sub-Saharan Africa', 'Uganda', Decimal('3.64')),
#  ('Sub-Saharan Africa', 'Uganda', None),
#  ('Sub-Saharan Africa', 'Uganda', None),
#  ('Sub-Saharan Africa', 'Uganda', None),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', None),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', Decimal('1.64')),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', Decimal('2.46')),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', Decimal('2.24')),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', Decimal('2.33')),
#  ('Northern Africa and Western Asia', 'United Arab Emirates', Decimal('4.29')),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', None),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', None),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', None),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', None),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', None),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', None),
#  ('Europe and Northern America', 'United States of America', None),
#  ('Europe and Northern America', 'United States of America', None),
#  ('Europe and Northern America', 'United States of America', None),
#  ('Europe and Northern America', 'United States of America', None),
#  ('Europe and Northern America', 'United States of America', None),
#  ('Europe and Northern America', 'United States of America', None),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', None),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', None),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', None),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', None),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', None),
#  ('Latin America and the Caribbean', 'United States Virgin Islands', None),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('7.49')),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('7.84')),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('7.89')),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('8.34')),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('8.73')),
#  ('Latin America and the Caribbean', 'Uruguay', Decimal('10.33')),
#  ...]

# %% [markdown]
# ### Task 2
#
# After joining our tables, the query  now returns a table with the unemployment rate, country, and region. This allows us to filter for countries in Sub-Saharan Africa. So let's filter this table ensuring that we include Sub Sub-Saharan Africa only. Use the `WHERE` clause to filter our results for `Sub-Saharan Africa`. The table should include the following columns: `Country_name`, `Time_period`, and `Pct_unemployment`.

# %%
# %%sql
# SELECT
#     location.Country_name,
#     economic.Time_period,
#     economic.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as location
# LEFT JOIN
#     united_nations.Economic_Indicators as economic
# ON
#     economic.Country_name = location.Country_name
# WHERE
#     REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, None),
#  ('Angola', 2016, None),
#  ('Angola', 2017, None),
#  ('Angola', 2018, None),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, None),
#  ('Benin', 2015, None),
#  ('Benin', 2016, None),
#  ('Benin', 2017, None),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, None),
#  ('Benin', 2020, None),
#  ('Botswana', 2015, None),
#  ('Botswana', 2016, None),
#  ('Botswana', 2017, None),
#  ('Botswana', 2018, None),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Burkina Faso', 2015, None),
#  ('Burkina Faso', 2016, None),
#  ('Burkina Faso', 2017, None),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, None),
#  ('Burkina Faso', 2020, None),
#  ('Burundi', 2015, None),
#  ('Burundi', 2016, None),
#  ('Burundi', 2017, None),
#  ('Burundi', 2018, None),
#  ('Burundi', 2019, None),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, None),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, None),
#  ('Cameroon', 2015, None),
#  ('Cameroon', 2016, None),
#  ('Cameroon', 2017, None),
#  ('Cameroon', 2018, None),
#  ('Cameroon', 2019, None),
#  ('Cameroon', 2020, None),
#  ('Central African Republic', 2015, None),
#  ('Central African Republic', 2016, None),
#  ('Central African Republic', 2017, None),
#  ('Central African Republic', 2018, None),
#  ('Central African Republic', 2019, None),
#  ('Central African Republic', 2020, None),
#  ('Chad', 2015, None),
#  ('Chad', 2016, None),
#  ('Chad', 2017, None),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, None),
#  ('Chad', 2020, None),
#  ('Comoros', 2015, None),
#  ('Comoros', 2016, None),
#  ('Comoros', 2017, None),
#  ('Comoros', 2018, None),
#  ('Comoros', 2019, None),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ("Côte d'Ivoire", 2015, None),
#  ("Côte d'Ivoire", 2016, None),
#  ("Côte d'Ivoire", 2017, None),
#  ("Côte d'Ivoire", 2018, None),
#  ("Côte d'Ivoire", 2019, None),
#  ("Côte d'Ivoire", 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Djibouti', 2015, None),
#  ('Djibouti', 2016, None),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, None),
#  ('Djibouti', 2019, None),
#  ('Djibouti', 2020, None),
#  ('Equatorial Guinea', 2015, None),
#  ('Equatorial Guinea', 2016, None),
#  ('Equatorial Guinea', 2017, None),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Eswatini', 2015, None),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, None),
#  ('Eswatini', 2018, None),
#  ('Eswatini', 2019, None),
#  ('Eswatini', 2020, None),
#  ('Ethiopia', 2015, None),
#  ('Ethiopia', 2016, None),
#  ('Ethiopia', 2017, None),
#  ('Ethiopia', 2018, None),
#  ('Ethiopia', 2019, None),
#  ('Ethiopia', 2020, None),
#  ('Gabon', 2015, None),
#  ('Gabon', 2016, None),
#  ('Gabon', 2017, None),
#  ('Gabon', 2018, None),
#  ('Gabon', 2019, None),
#  ('Gabon', 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, None),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, None),
#  ('Ghana', 2019, None),
#  ('Ghana', 2020, None),
#  ('Guinea', 2015, None),
#  ('Guinea', 2016, None),
#  ('Guinea', 2017, None),
#  ('Guinea', 2018, None),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, None),
#  ('Guinea-Bissau', 2015, None),
#  ('Guinea-Bissau', 2016, None),
#  ('Guinea-Bissau', 2017, None),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, None),
#  ('Guinea-Bissau', 2020, None),
#  ('Kenya', 2015, None),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, None),
#  ('Kenya', 2018, None),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, None),
#  ('Lesotho', 2015, None),
#  ('Lesotho', 2016, None),
#  ('Lesotho', 2017, None),
#  ('Lesotho', 2018, None),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, None),
#  ('Liberia', 2015, None),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, None),
#  ('Liberia', 2019, None),
#  ('Liberia', 2020, None),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, None),
#  ('Madagascar', 2017, None),
#  ('Madagascar', 2018, None),
#  ('Madagascar', 2019, None),
#  ('Madagascar', 2020, None),
#  ('Malawi', 2015, None),
#  ('Malawi', 2016, None),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, None),
#  ('Malawi', 2019, None),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, None),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, None),
#  ('Mauritania', 2016, None),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, None),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, None),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, None),
#  ('Mozambique', 2017, None),
#  ('Mozambique', 2018, None),
#  ('Mozambique', 2019, None),
#  ('Mozambique', 2020, None),
#  ('Namibia', 2015, None),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, None),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, None),
#  ('Namibia', 2020, None),
#  ('Niger', 2015, None),
#  ('Niger', 2016, None),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, None),
#  ('Niger', 2019, None),
#  ('Niger', 2020, None),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, None),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, None),
#  ('Réunion', 2015, None),
#  ('Réunion', 2016, None),
#  ('Réunion', 2017, None),
#  ('Réunion', 2018, None),
#  ('Réunion', 2019, None),
#  ('Réunion', 2020, None),
#  ('Rwanda', 2015, None),
#  ('Rwanda', 2016, None),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Saint Helena', 2015, None),
#  ('Saint Helena', 2016, None),
#  ('Saint Helena', 2017, None),
#  ('Saint Helena', 2018, None),
#  ('Saint Helena', 2019, None),
#  ('Saint Helena', 2020, None),
#  ('Sao Tome and Principe', 2015, None),
#  ('Sao Tome and Principe', 2016, None),
#  ('Sao Tome and Principe', 2017, None),
#  ('Sao Tome and Principe', 2018, None),
#  ('Sao Tome and Principe', 2019, None),
#  ('Sao Tome and Principe', 2020, None),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, None),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Sierra Leone', 2015, None),
#  ('Sierra Leone', 2016, None),
#  ('Sierra Leone', 2017, None),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, None),
#  ('Sierra Leone', 2020, None),
#  ('Somalia', 2015, None),
#  ('Somalia', 2016, None),
#  ('Somalia', 2017, None),
#  ('Somalia', 2018, None),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, None),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('South Sudan', 2015, None),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, None),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, None),
#  ('Togo', 2019, None),
#  ('Togo', 2020, None),
#  ('Uganda', 2015, None),
#  ('Uganda', 2016, None),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, None),
#  ('Uganda', 2019, None),
#  ('Uganda', 2020, None),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, None),
#  ('Zambia', 2016, None),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, None),
#  ('Zimbabwe', 2016, None),
#  ('Zimbabwe', 2017, None),
#  ('Zimbabwe', 2018, None),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, None)]

# %% [markdown]
# ### Task 3
#
# After filtering, we will notice that there are Null values in the `Pct_unemployment` column. Fill in the Null values with 33.65. Rename the imputed column, `Pct_unemployment_imputed`.

# %%
# %%sql
# SELECT
#     location.Country_name,
#     economic.Time_period,
#     IFNULL(economic.Pct_unemployment,33.65) AS imputed_pct_unemployment
# FROM
#     united_nations.Geographic_Location as location
# LEFT JOIN
#     united_nations.Economic_Indicators as economic
# ON
#     economic.Country_name = location.Country_name
# WHERE
#     REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, Decimal('33.65')),
#  ('Angola', 2016, Decimal('33.65')),
#  ('Angola', 2017, Decimal('33.65')),
#  ('Angola', 2018, Decimal('33.65')),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, Decimal('33.65')),
#  ('Benin', 2015, Decimal('33.65')),
#  ('Benin', 2016, Decimal('33.65')),
#  ('Benin', 2017, Decimal('33.65')),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, Decimal('33.65')),
#  ('Benin', 2020, Decimal('33.65')),
#  ('Botswana', 2015, Decimal('33.65')),
#  ('Botswana', 2016, Decimal('33.65')),
#  ('Botswana', 2017, Decimal('33.65')),
#  ('Botswana', 2018, Decimal('33.65')),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Burkina Faso', 2015, Decimal('33.65')),
#  ('Burkina Faso', 2016, Decimal('33.65')),
#  ('Burkina Faso', 2017, Decimal('33.65')),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, Decimal('33.65')),
#  ('Burkina Faso', 2020, Decimal('33.65')),
#  ('Burundi', 2015, Decimal('33.65')),
#  ('Burundi', 2016, Decimal('33.65')),
#  ('Burundi', 2017, Decimal('33.65')),
#  ('Burundi', 2018, Decimal('33.65')),
#  ('Burundi', 2019, Decimal('33.65')),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, Decimal('33.65')),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, Decimal('33.65')),
#  ('Cameroon', 2015, Decimal('33.65')),
#  ('Cameroon', 2016, Decimal('33.65')),
#  ('Cameroon', 2017, Decimal('33.65')),
#  ('Cameroon', 2018, Decimal('33.65')),
#  ('Cameroon', 2019, Decimal('33.65')),
#  ('Cameroon', 2020, Decimal('33.65')),
#  ('Central African Republic', 2015, Decimal('33.65')),
#  ('Central African Republic', 2016, Decimal('33.65')),
#  ('Central African Republic', 2017, Decimal('33.65')),
#  ('Central African Republic', 2018, Decimal('33.65')),
#  ('Central African Republic', 2019, Decimal('33.65')),
#  ('Central African Republic', 2020, Decimal('33.65')),
#  ('Chad', 2015, Decimal('33.65')),
#  ('Chad', 2016, Decimal('33.65')),
#  ('Chad', 2017, Decimal('33.65')),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, Decimal('33.65')),
#  ('Chad', 2020, Decimal('33.65')),
#  ('Comoros', 2015, Decimal('33.65')),
#  ('Comoros', 2016, Decimal('33.65')),
#  ('Comoros', 2017, Decimal('33.65')),
#  ('Comoros', 2018, Decimal('33.65')),
#  ('Comoros', 2019, Decimal('33.65')),
#  ('Congo', 2015, Decimal('33.65')),
#  ('Congo', 2016, Decimal('33.65')),
#  ('Congo', 2017, Decimal('33.65')),
#  ('Congo', 2018, Decimal('33.65')),
#  ('Congo', 2019, Decimal('33.65')),
#  ('Congo', 2020, Decimal('33.65')),
#  ("Côte d'Ivoire", 2015, Decimal('33.65')),
#  ("Côte d'Ivoire", 2016, Decimal('33.65')),
#  ("Côte d'Ivoire", 2017, Decimal('33.65')),
#  ("Côte d'Ivoire", 2018, Decimal('33.65')),
#  ("Côte d'Ivoire", 2019, Decimal('33.65')),
#  ("Côte d'Ivoire", 2020, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2015, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2016, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2017, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2018, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2019, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2020, Decimal('33.65')),
#  ('Djibouti', 2015, Decimal('33.65')),
#  ('Djibouti', 2016, Decimal('33.65')),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, Decimal('33.65')),
#  ('Djibouti', 2019, Decimal('33.65')),
#  ('Djibouti', 2020, Decimal('33.65')),
#  ('Equatorial Guinea', 2015, Decimal('33.65')),
#  ('Equatorial Guinea', 2016, Decimal('33.65')),
#  ('Equatorial Guinea', 2017, Decimal('33.65')),
#  ('Eritrea', 2015, Decimal('33.65')),
#  ('Eritrea', 2016, Decimal('33.65')),
#  ('Eswatini', 2015, Decimal('33.65')),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, Decimal('33.65')),
#  ('Eswatini', 2018, Decimal('33.65')),
#  ('Eswatini', 2019, Decimal('33.65')),
#  ('Eswatini', 2020, Decimal('33.65')),
#  ('Ethiopia', 2015, Decimal('33.65')),
#  ('Ethiopia', 2016, Decimal('33.65')),
#  ('Ethiopia', 2017, Decimal('33.65')),
#  ('Ethiopia', 2018, Decimal('33.65')),
#  ('Ethiopia', 2019, Decimal('33.65')),
#  ('Ethiopia', 2020, Decimal('33.65')),
#  ('Gabon', 2015, Decimal('33.65')),
#  ('Gabon', 2016, Decimal('33.65')),
#  ('Gabon', 2017, Decimal('33.65')),
#  ('Gabon', 2018, Decimal('33.65')),
#  ('Gabon', 2019, Decimal('33.65')),
#  ('Gabon', 2020, Decimal('33.65')),
#  ('Gambia', 2015, Decimal('33.65')),
#  ('Gambia', 2016, Decimal('33.65')),
#  ('Gambia', 2017, Decimal('33.65')),
#  ('Gambia', 2018, Decimal('33.65')),
#  ('Gambia', 2019, Decimal('33.65')),
#  ('Gambia', 2020, Decimal('33.65')),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, Decimal('33.65')),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, Decimal('33.65')),
#  ('Ghana', 2019, Decimal('33.65')),
#  ('Ghana', 2020, Decimal('33.65')),
#  ('Guinea', 2015, Decimal('33.65')),
#  ('Guinea', 2016, Decimal('33.65')),
#  ('Guinea', 2017, Decimal('33.65')),
#  ('Guinea', 2018, Decimal('33.65')),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, Decimal('33.65')),
#  ('Guinea-Bissau', 2015, Decimal('33.65')),
#  ('Guinea-Bissau', 2016, Decimal('33.65')),
#  ('Guinea-Bissau', 2017, Decimal('33.65')),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, Decimal('33.65')),
#  ('Guinea-Bissau', 2020, Decimal('33.65')),
#  ('Kenya', 2015, Decimal('33.65')),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, Decimal('33.65')),
#  ('Kenya', 2018, Decimal('33.65')),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, Decimal('33.65')),
#  ('Lesotho', 2015, Decimal('33.65')),
#  ('Lesotho', 2016, Decimal('33.65')),
#  ('Lesotho', 2017, Decimal('33.65')),
#  ('Lesotho', 2018, Decimal('33.65')),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, Decimal('33.65')),
#  ('Liberia', 2015, Decimal('33.65')),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, Decimal('33.65')),
#  ('Liberia', 2019, Decimal('33.65')),
#  ('Liberia', 2020, Decimal('33.65')),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, Decimal('33.65')),
#  ('Madagascar', 2017, Decimal('33.65')),
#  ('Madagascar', 2018, Decimal('33.65')),
#  ('Madagascar', 2019, Decimal('33.65')),
#  ('Madagascar', 2020, Decimal('33.65')),
#  ('Malawi', 2015, Decimal('33.65')),
#  ('Malawi', 2016, Decimal('33.65')),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, Decimal('33.65')),
#  ('Malawi', 2019, Decimal('33.65')),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, Decimal('33.65')),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, Decimal('33.65')),
#  ('Mauritania', 2016, Decimal('33.65')),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, Decimal('33.65')),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, Decimal('33.65')),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, Decimal('33.65')),
#  ('Mayotte', 2016, Decimal('33.65')),
#  ('Mayotte', 2017, Decimal('33.65')),
#  ('Mayotte', 2018, Decimal('33.65')),
#  ('Mayotte', 2019, Decimal('33.65')),
#  ('Mayotte', 2020, Decimal('33.65')),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, Decimal('33.65')),
#  ('Mozambique', 2017, Decimal('33.65')),
#  ('Mozambique', 2018, Decimal('33.65')),
#  ('Mozambique', 2019, Decimal('33.65')),
#  ('Mozambique', 2020, Decimal('33.65')),
#  ('Namibia', 2015, Decimal('33.65')),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, Decimal('33.65')),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, Decimal('33.65')),
#  ('Namibia', 2020, Decimal('33.65')),
#  ('Niger', 2015, Decimal('33.65')),
#  ('Niger', 2016, Decimal('33.65')),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, Decimal('33.65')),
#  ('Niger', 2019, Decimal('33.65')),
#  ('Niger', 2020, Decimal('33.65')),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, Decimal('33.65')),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, Decimal('33.65')),
#  ('Réunion', 2015, Decimal('33.65')),
#  ('Réunion', 2016, Decimal('33.65')),
#  ('Réunion', 2017, Decimal('33.65')),
#  ('Réunion', 2018, Decimal('33.65')),
#  ('Réunion', 2019, Decimal('33.65')),
#  ('Réunion', 2020, Decimal('33.65')),
#  ('Rwanda', 2015, Decimal('33.65')),
#  ('Rwanda', 2016, Decimal('33.65')),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Saint Helena', 2015, Decimal('33.65')),
#  ('Saint Helena', 2016, Decimal('33.65')),
#  ('Saint Helena', 2017, Decimal('33.65')),
#  ('Saint Helena', 2018, Decimal('33.65')),
#  ('Saint Helena', 2019, Decimal('33.65')),
#  ('Saint Helena', 2020, Decimal('33.65')),
#  ('Sao Tome and Principe', 2015, Decimal('33.65')),
#  ('Sao Tome and Principe', 2016, Decimal('33.65')),
#  ('Sao Tome and Principe', 2017, Decimal('33.65')),
#  ('Sao Tome and Principe', 2018, Decimal('33.65')),
#  ('Sao Tome and Principe', 2019, Decimal('33.65')),
#  ('Sao Tome and Principe', 2020, Decimal('33.65')),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, Decimal('33.65')),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Sierra Leone', 2015, Decimal('33.65')),
#  ('Sierra Leone', 2016, Decimal('33.65')),
#  ('Sierra Leone', 2017, Decimal('33.65')),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, Decimal('33.65')),
#  ('Sierra Leone', 2020, Decimal('33.65')),
#  ('Somalia', 2015, Decimal('33.65')),
#  ('Somalia', 2016, Decimal('33.65')),
#  ('Somalia', 2017, Decimal('33.65')),
#  ('Somalia', 2018, Decimal('33.65')),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, Decimal('33.65')),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('South Sudan', 2015, Decimal('33.65')),
#  ('South Sudan', 2016, Decimal('33.65')),
#  ('South Sudan', 2017, Decimal('33.65')),
#  ('South Sudan', 2018, Decimal('33.65')),
#  ('South Sudan', 2019, Decimal('33.65')),
#  ('South Sudan', 2020, Decimal('33.65')),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, Decimal('33.65')),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, Decimal('33.65')),
#  ('Togo', 2019, Decimal('33.65')),
#  ('Togo', 2020, Decimal('33.65')),
#  ('Uganda', 2015, Decimal('33.65')),
#  ('Uganda', 2016, Decimal('33.65')),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, Decimal('33.65')),
#  ('Uganda', 2019, Decimal('33.65')),
#  ('Uganda', 2020, Decimal('33.65')),
#  ('United Republic of Tanzania', 2015, Decimal('33.65')),
#  ('United Republic of Tanzania', 2016, Decimal('33.65')),
#  ('United Republic of Tanzania', 2017, Decimal('33.65')),
#  ('United Republic of Tanzania', 2018, Decimal('33.65')),
#  ('United Republic of Tanzania', 2019, Decimal('33.65')),
#  ('United Republic of Tanzania', 2020, Decimal('33.65')),
#  ('Zambia', 2015, Decimal('33.65')),
#  ('Zambia', 2016, Decimal('33.65')),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, Decimal('33.65')),
#  ('Zimbabwe', 2016, Decimal('33.65')),
#  ('Zimbabwe', 2017, Decimal('33.65')),
#  ('Zimbabwe', 2018, Decimal('33.65')),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, Decimal('33.65'))]

# %% [markdown]
# ### Task 4
#
# Now that we have the query constructed, let's create a VIEW of that query. Name the VIEW, `united_nations.Country_Unemployment_Rate`.

# %%
# %%sql
# CREATE VIEW
#     united_nations.Country_Unemployment_Rate
#     AS
#     SELECT
#         location.Country_name,
#         economic.Time_period,
#         IFNULL(economic.Pct_unemployment,33.65) AS imputed_pct_unemployment
#     FROM
#         united_nations.Geographic_Location as location
#     LEFT JOIN
#         united_nations.Economic_Indicators as economic
#     ON
#         economic.Country_name = location.Country_name
#     WHERE
#         REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 0 rows affected.
# []

# %% [markdown]
# ### Task 5
#
# Finally, let's have a look at the VIEW.

# %%
# %%sql
# SELECT
#     *
# FROM
#     united_nations.Country_Unemployment_Rate ;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, Decimal('33.65')),
#  ('Angola', 2016, Decimal('33.65')),
#  ('Angola', 2017, Decimal('33.65')),
#  ('Angola', 2018, Decimal('33.65')),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, Decimal('33.65')),
#  ('Benin', 2015, Decimal('33.65')),
#  ('Benin', 2016, Decimal('33.65')),
#  ('Benin', 2017, Decimal('33.65')),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, Decimal('33.65')),
#  ('Benin', 2020, Decimal('33.65')),
#  ('Botswana', 2015, Decimal('33.65')),
#  ('Botswana', 2016, Decimal('33.65')),
#  ('Botswana', 2017, Decimal('33.65')),
#  ('Botswana', 2018, Decimal('33.65')),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Burkina Faso', 2015, Decimal('33.65')),
#  ('Burkina Faso', 2016, Decimal('33.65')),
#  ('Burkina Faso', 2017, Decimal('33.65')),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, Decimal('33.65')),
#  ('Burkina Faso', 2020, Decimal('33.65')),
#  ('Burundi', 2015, Decimal('33.65')),
#  ('Burundi', 2016, Decimal('33.65')),
#  ('Burundi', 2017, Decimal('33.65')),
#  ('Burundi', 2018, Decimal('33.65')),
#  ('Burundi', 2019, Decimal('33.65')),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, Decimal('33.65')),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, Decimal('33.65')),
#  ('Cameroon', 2015, Decimal('33.65')),
#  ('Cameroon', 2016, Decimal('33.65')),
#  ('Cameroon', 2017, Decimal('33.65')),
#  ('Cameroon', 2018, Decimal('33.65')),
#  ('Cameroon', 2019, Decimal('33.65')),
#  ('Cameroon', 2020, Decimal('33.65')),
#  ('Central African Republic', 2015, Decimal('33.65')),
#  ('Central African Republic', 2016, Decimal('33.65')),
#  ('Central African Republic', 2017, Decimal('33.65')),
#  ('Central African Republic', 2018, Decimal('33.65')),
#  ('Central African Republic', 2019, Decimal('33.65')),
#  ('Central African Republic', 2020, Decimal('33.65')),
#  ('Chad', 2015, Decimal('33.65')),
#  ('Chad', 2016, Decimal('33.65')),
#  ('Chad', 2017, Decimal('33.65')),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, Decimal('33.65')),
#  ('Chad', 2020, Decimal('33.65')),
#  ('Comoros', 2015, Decimal('33.65')),
#  ('Comoros', 2016, Decimal('33.65')),
#  ('Comoros', 2017, Decimal('33.65')),
#  ('Comoros', 2018, Decimal('33.65')),
#  ('Comoros', 2019, Decimal('33.65')),
#  ('Congo', 2015, Decimal('33.65')),
#  ('Congo', 2016, Decimal('33.65')),
#  ('Congo', 2017, Decimal('33.65')),
#  ('Congo', 2018, Decimal('33.65')),
#  ('Congo', 2019, Decimal('33.65')),
#  ('Congo', 2020, Decimal('33.65')),
#  ("Côte d'Ivoire", 2015, Decimal('33.65')),
#  ("Côte d'Ivoire", 2016, Decimal('33.65')),
#  ("Côte d'Ivoire", 2017, Decimal('33.65')),
#  ("Côte d'Ivoire", 2018, Decimal('33.65')),
#  ("Côte d'Ivoire", 2019, Decimal('33.65')),
#  ("Côte d'Ivoire", 2020, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2015, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2016, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2017, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2018, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2019, Decimal('33.65')),
#  ('Democratic Republic of the Congo', 2020, Decimal('33.65')),
#  ('Djibouti', 2015, Decimal('33.65')),
#  ('Djibouti', 2016, Decimal('33.65')),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, Decimal('33.65')),
#  ('Djibouti', 2019, Decimal('33.65')),
#  ('Djibouti', 2020, Decimal('33.65')),
#  ('Equatorial Guinea', 2015, Decimal('33.65')),
#  ('Equatorial Guinea', 2016, Decimal('33.65')),
#  ('Equatorial Guinea', 2017, Decimal('33.65')),
#  ('Eritrea', 2015, Decimal('33.65')),
#  ('Eritrea', 2016, Decimal('33.65')),
#  ('Eswatini', 2015, Decimal('33.65')),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, Decimal('33.65')),
#  ('Eswatini', 2018, Decimal('33.65')),
#  ('Eswatini', 2019, Decimal('33.65')),
#  ('Eswatini', 2020, Decimal('33.65')),
#  ('Ethiopia', 2015, Decimal('33.65')),
#  ('Ethiopia', 2016, Decimal('33.65')),
#  ('Ethiopia', 2017, Decimal('33.65')),
#  ('Ethiopia', 2018, Decimal('33.65')),
#  ('Ethiopia', 2019, Decimal('33.65')),
#  ('Ethiopia', 2020, Decimal('33.65')),
#  ('Gabon', 2015, Decimal('33.65')),
#  ('Gabon', 2016, Decimal('33.65')),
#  ('Gabon', 2017, Decimal('33.65')),
#  ('Gabon', 2018, Decimal('33.65')),
#  ('Gabon', 2019, Decimal('33.65')),
#  ('Gabon', 2020, Decimal('33.65')),
#  ('Gambia', 2015, Decimal('33.65')),
#  ('Gambia', 2016, Decimal('33.65')),
#  ('Gambia', 2017, Decimal('33.65')),
#  ('Gambia', 2018, Decimal('33.65')),
#  ('Gambia', 2019, Decimal('33.65')),
#  ('Gambia', 2020, Decimal('33.65')),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, Decimal('33.65')),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, Decimal('33.65')),
#  ('Ghana', 2019, Decimal('33.65')),
#  ('Ghana', 2020, Decimal('33.65')),
#  ('Guinea', 2015, Decimal('33.65')),
#  ('Guinea', 2016, Decimal('33.65')),
#  ('Guinea', 2017, Decimal('33.65')),
#  ('Guinea', 2018, Decimal('33.65')),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, Decimal('33.65')),
#  ('Guinea-Bissau', 2015, Decimal('33.65')),
#  ('Guinea-Bissau', 2016, Decimal('33.65')),
#  ('Guinea-Bissau', 2017, Decimal('33.65')),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, Decimal('33.65')),
#  ('Guinea-Bissau', 2020, Decimal('33.65')),
#  ('Kenya', 2015, Decimal('33.65')),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, Decimal('33.65')),
#  ('Kenya', 2018, Decimal('33.65')),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, Decimal('33.65')),
#  ('Lesotho', 2015, Decimal('33.65')),
#  ('Lesotho', 2016, Decimal('33.65')),
#  ('Lesotho', 2017, Decimal('33.65')),
#  ('Lesotho', 2018, Decimal('33.65')),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, Decimal('33.65')),
#  ('Liberia', 2015, Decimal('33.65')),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, Decimal('33.65')),
#  ('Liberia', 2019, Decimal('33.65')),
#  ('Liberia', 2020, Decimal('33.65')),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, Decimal('33.65')),
#  ('Madagascar', 2017, Decimal('33.65')),
#  ('Madagascar', 2018, Decimal('33.65')),
#  ('Madagascar', 2019, Decimal('33.65')),
#  ('Madagascar', 2020, Decimal('33.65')),
#  ('Malawi', 2015, Decimal('33.65')),
#  ('Malawi', 2016, Decimal('33.65')),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, Decimal('33.65')),
#  ('Malawi', 2019, Decimal('33.65')),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, Decimal('33.65')),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, Decimal('33.65')),
#  ('Mauritania', 2016, Decimal('33.65')),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, Decimal('33.65')),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, Decimal('33.65')),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, Decimal('33.65')),
#  ('Mayotte', 2016, Decimal('33.65')),
#  ('Mayotte', 2017, Decimal('33.65')),
#  ('Mayotte', 2018, Decimal('33.65')),
#  ('Mayotte', 2019, Decimal('33.65')),
#  ('Mayotte', 2020, Decimal('33.65')),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, Decimal('33.65')),
#  ('Mozambique', 2017, Decimal('33.65')),
#  ('Mozambique', 2018, Decimal('33.65')),
#  ('Mozambique', 2019, Decimal('33.65')),
#  ('Mozambique', 2020, Decimal('33.65')),
#  ('Namibia', 2015, Decimal('33.65')),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, Decimal('33.65')),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, Decimal('33.65')),
#  ('Namibia', 2020, Decimal('33.65')),
#  ('Niger', 2015, Decimal('33.65')),
#  ('Niger', 2016, Decimal('33.65')),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, Decimal('33.65')),
#  ('Niger', 2019, Decimal('33.65')),
#  ('Niger', 2020, Decimal('33.65')),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, Decimal('33.65')),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, Decimal('33.65')),
#  ('Réunion', 2015, Decimal('33.65')),
#  ('Réunion', 2016, Decimal('33.65')),
#  ('Réunion', 2017, Decimal('33.65')),
#  ('Réunion', 2018, Decimal('33.65')),
#  ('Réunion', 2019, Decimal('33.65')),
#  ('Réunion', 2020, Decimal('33.65')),
#  ('Rwanda', 2015, Decimal('33.65')),
#  ('Rwanda', 2016, Decimal('33.65')),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Saint Helena', 2015, Decimal('33.65')),
#  ('Saint Helena', 2016, Decimal('33.65')),
#  ('Saint Helena', 2017, Decimal('33.65')),
#  ('Saint Helena', 2018, Decimal('33.65')),
#  ('Saint Helena', 2019, Decimal('33.65')),
#  ('Saint Helena', 2020, Decimal('33.65')),
#  ('Sao Tome and Principe', 2015, Decimal('33.65')),
#  ('Sao Tome and Principe', 2016, Decimal('33.65')),
#  ('Sao Tome and Principe', 2017, Decimal('33.65')),
#  ('Sao Tome and Principe', 2018, Decimal('33.65')),
#  ('Sao Tome and Principe', 2019, Decimal('33.65')),
#  ('Sao Tome and Principe', 2020, Decimal('33.65')),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, Decimal('33.65')),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Sierra Leone', 2015, Decimal('33.65')),
#  ('Sierra Leone', 2016, Decimal('33.65')),
#  ('Sierra Leone', 2017, Decimal('33.65')),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, Decimal('33.65')),
#  ('Sierra Leone', 2020, Decimal('33.65')),
#  ('Somalia', 2015, Decimal('33.65')),
#  ('Somalia', 2016, Decimal('33.65')),
#  ('Somalia', 2017, Decimal('33.65')),
#  ('Somalia', 2018, Decimal('33.65')),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, Decimal('33.65')),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('South Sudan', 2015, Decimal('33.65')),
#  ('South Sudan', 2016, Decimal('33.65')),
#  ('South Sudan', 2017, Decimal('33.65')),
#  ('South Sudan', 2018, Decimal('33.65')),
#  ('South Sudan', 2019, Decimal('33.65')),
#  ('South Sudan', 2020, Decimal('33.65')),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, Decimal('33.65')),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, Decimal('33.65')),
#  ('Togo', 2019, Decimal('33.65')),
#  ('Togo', 2020, Decimal('33.65')),
#  ('Uganda', 2015, Decimal('33.65')),
#  ('Uganda', 2016, Decimal('33.65')),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, Decimal('33.65')),
#  ('Uganda', 2019, Decimal('33.65')),
#  ('Uganda', 2020, Decimal('33.65')),
#  ('United Republic of Tanzania', 2015, Decimal('33.65')),
#  ('United Republic of Tanzania', 2016, Decimal('33.65')),
#  ('United Republic of Tanzania', 2017, Decimal('33.65')),
#  ('United Republic of Tanzania', 2018, Decimal('33.65')),
#  ('United Republic of Tanzania', 2019, Decimal('33.65')),
#  ('United Republic of Tanzania', 2020, Decimal('33.65')),
#  ('Zambia', 2015, Decimal('33.65')),
#  ('Zambia', 2016, Decimal('33.65')),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, Decimal('33.65')),
#  ('Zimbabwe', 2016, Decimal('33.65')),
#  ('Zimbabwe', 2017, Decimal('33.65')),
#  ('Zimbabwe', 2018, Decimal('33.65')),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, Decimal('33.65'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name;
#
# # Use LIMIT if you think the results set will be too large
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     eco.Pct_unemployment
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 297 rows affected.
# [('Angola', 2015, None),
#  ('Angola', 2016, None),
#  ('Angola', 2017, None),
#  ('Angola', 2018, None),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, None),
#  ('Benin', 2015, None),
#  ('Benin', 2016, None),
#  ('Benin', 2017, None),
#  ('Benin', 2018, Decimal('1.47')),
#  ('Benin', 2019, None),
#  ('Benin', 2020, None),
#  ('Botswana', 2015, None),
#  ('Botswana', 2016, None),
#  ('Botswana', 2017, None),
#  ('Botswana', 2018, None),
#  ('Botswana', 2019, Decimal('20.09')),
#  ('Botswana', 2020, Decimal('21.02')),
#  ('Burkina Faso', 2015, None),
#  ('Burkina Faso', 2016, None),
#  ('Burkina Faso', 2017, None),
#  ('Burkina Faso', 2018, Decimal('4.69')),
#  ('Burkina Faso', 2019, None),
#  ('Burkina Faso', 2020, None),
#  ('Burundi', 2015, None),
#  ('Burundi', 2016, None),
#  ('Burundi', 2017, None),
#  ('Burundi', 2018, None),
#  ('Burundi', 2019, None),
#  ('Burundi', 2020, Decimal('1.03')),
#  ('Cabo Verde', 2015, Decimal('31.31')),
#  ('Cabo Verde', 2016, None),
#  ('Cabo Verde', 2017, Decimal('12.24')),
#  ('Cabo Verde', 2018, Decimal('12.17')),
#  ('Cabo Verde', 2019, Decimal('11.29')),
#  ('Cabo Verde', 2020, None),
#  ('Cameroon', 2015, None),
#  ('Cameroon', 2016, None),
#  ('Cameroon', 2017, None),
#  ('Cameroon', 2018, None),
#  ('Cameroon', 2019, None),
#  ('Cameroon', 2020, None),
#  ('Central African Republic', 2015, None),
#  ('Central African Republic', 2016, None),
#  ('Central African Republic', 2017, None),
#  ('Central African Republic', 2018, None),
#  ('Central African Republic', 2019, None),
#  ('Central African Republic', 2020, None),
#  ('Chad', 2015, None),
#  ('Chad', 2016, None),
#  ('Chad', 2017, None),
#  ('Chad', 2018, Decimal('1.13')),
#  ('Chad', 2019, None),
#  ('Chad', 2020, None),
#  ('Comoros', 2015, None),
#  ('Comoros', 2016, None),
#  ('Comoros', 2017, None),
#  ('Comoros', 2018, None),
#  ('Comoros', 2019, None),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ("Côte d'Ivoire", 2015, None),
#  ("Côte d'Ivoire", 2016, None),
#  ("Côte d'Ivoire", 2017, None),
#  ("Côte d'Ivoire", 2018, None),
#  ("Côte d'Ivoire", 2019, None),
#  ("Côte d'Ivoire", 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Djibouti', 2015, None),
#  ('Djibouti', 2016, None),
#  ('Djibouti', 2017, Decimal('26.06')),
#  ('Djibouti', 2018, None),
#  ('Djibouti', 2019, None),
#  ('Djibouti', 2020, None),
#  ('Equatorial Guinea', 2015, None),
#  ('Equatorial Guinea', 2016, None),
#  ('Equatorial Guinea', 2017, None),
#  ('Eritrea', 2015, None),
#  ('Eritrea', 2016, None),
#  ('Eswatini', 2015, None),
#  ('Eswatini', 2016, Decimal('22.72')),
#  ('Eswatini', 2017, None),
#  ('Eswatini', 2018, None),
#  ('Eswatini', 2019, None),
#  ('Eswatini', 2020, None),
#  ('Ethiopia', 2015, None),
#  ('Ethiopia', 2016, None),
#  ('Ethiopia', 2017, None),
#  ('Ethiopia', 2018, None),
#  ('Ethiopia', 2019, None),
#  ('Ethiopia', 2020, None),
#  ('Gabon', 2015, None),
#  ('Gabon', 2016, None),
#  ('Gabon', 2017, None),
#  ('Gabon', 2018, None),
#  ('Gabon', 2019, None),
#  ('Gabon', 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, Decimal('6.81')),
#  ('Ghana', 2016, None),
#  ('Ghana', 2017, Decimal('3.37')),
#  ('Ghana', 2018, None),
#  ('Ghana', 2019, None),
#  ('Ghana', 2020, None),
#  ('Guinea', 2015, None),
#  ('Guinea', 2016, None),
#  ('Guinea', 2017, None),
#  ('Guinea', 2018, None),
#  ('Guinea', 2019, Decimal('5.02')),
#  ('Guinea', 2020, None),
#  ('Guinea-Bissau', 2015, None),
#  ('Guinea-Bissau', 2016, None),
#  ('Guinea-Bissau', 2017, None),
#  ('Guinea-Bissau', 2018, Decimal('3.20')),
#  ('Guinea-Bissau', 2019, None),
#  ('Guinea-Bissau', 2020, None),
#  ('Kenya', 2015, None),
#  ('Kenya', 2016, Decimal('2.76')),
#  ('Kenya', 2017, None),
#  ('Kenya', 2018, None),
#  ('Kenya', 2019, Decimal('5.01')),
#  ('Kenya', 2020, None),
#  ('Lesotho', 2015, None),
#  ('Lesotho', 2016, None),
#  ('Lesotho', 2017, None),
#  ('Lesotho', 2018, None),
#  ('Lesotho', 2019, Decimal('16.88')),
#  ('Lesotho', 2020, None),
#  ('Liberia', 2015, None),
#  ('Liberia', 2016, Decimal('3.08')),
#  ('Liberia', 2017, Decimal('5.95')),
#  ('Liberia', 2018, None),
#  ('Liberia', 2019, None),
#  ('Liberia', 2020, None),
#  ('Madagascar', 2015, Decimal('1.79')),
#  ('Madagascar', 2016, None),
#  ('Madagascar', 2017, None),
#  ('Madagascar', 2018, None),
#  ('Madagascar', 2019, None),
#  ('Madagascar', 2020, None),
#  ('Malawi', 2015, None),
#  ('Malawi', 2016, None),
#  ('Malawi', 2017, Decimal('3.54')),
#  ('Malawi', 2018, None),
#  ('Malawi', 2019, None),
#  ('Malawi', 2020, Decimal('0.91')),
#  ('Mali', 2015, Decimal('7.73')),
#  ('Mali', 2016, Decimal('1.37')),
#  ('Mali', 2017, Decimal('7.41')),
#  ('Mali', 2018, Decimal('1.62')),
#  ('Mali', 2019, None),
#  ('Mali', 2020, Decimal('3.53')),
#  ('Mauritania', 2015, None),
#  ('Mauritania', 2016, None),
#  ('Mauritania', 2017, Decimal('10.34')),
#  ('Mauritania', 2018, None),
#  ('Mauritania', 2019, Decimal('10.42')),
#  ('Mauritania', 2020, None),
#  ('Mauritius', 2015, Decimal('7.41')),
#  ('Mauritius', 2016, Decimal('6.81')),
#  ('Mauritius', 2017, Decimal('6.75')),
#  ('Mauritius', 2018, Decimal('6.43')),
#  ('Mauritius', 2019, Decimal('6.33')),
#  ('Mauritius', 2020, Decimal('8.63')),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, Decimal('3.43')),
#  ('Mozambique', 2016, None),
#  ('Mozambique', 2017, None),
#  ('Mozambique', 2018, None),
#  ('Mozambique', 2019, None),
#  ('Mozambique', 2020, None),
#  ('Namibia', 2015, None),
#  ('Namibia', 2016, Decimal('23.35')),
#  ('Namibia', 2017, None),
#  ('Namibia', 2018, Decimal('19.88')),
#  ('Namibia', 2019, None),
#  ('Namibia', 2020, None),
#  ('Niger', 2015, None),
#  ('Niger', 2016, None),
#  ('Niger', 2017, Decimal('7.77')),
#  ('Niger', 2018, None),
#  ('Niger', 2019, None),
#  ('Niger', 2020, None),
#  ('Nigeria', 2015, Decimal('4.31')),
#  ('Nigeria', 2016, Decimal('7.06')),
#  ('Nigeria', 2017, Decimal('8.39')),
#  ('Nigeria', 2018, None),
#  ('Nigeria', 2019, Decimal('10.70')),
#  ('Nigeria', 2020, None),
#  ('Réunion', 2015, None),
#  ('Réunion', 2016, None),
#  ('Réunion', 2017, None),
#  ('Réunion', 2018, None),
#  ('Réunion', 2019, None),
#  ('Réunion', 2020, None),
#  ('Rwanda', 2015, None),
#  ('Rwanda', 2016, None),
#  ('Rwanda', 2017, Decimal('11.88')),
#  ('Rwanda', 2018, Decimal('10.76')),
#  ('Rwanda', 2019, Decimal('11.24')),
#  ('Rwanda', 2020, Decimal('11.83')),
#  ('Saint Helena', 2015, None),
#  ('Saint Helena', 2016, None),
#  ('Saint Helena', 2017, None),
#  ('Saint Helena', 2018, None),
#  ('Saint Helena', 2019, None),
#  ('Saint Helena', 2020, None),
#  ('Sao Tome and Principe', 2015, None),
#  ('Sao Tome and Principe', 2016, None),
#  ('Sao Tome and Principe', 2017, None),
#  ('Sao Tome and Principe', 2018, None),
#  ('Sao Tome and Principe', 2019, None),
#  ('Sao Tome and Principe', 2020, None),
#  ('Senegal', 2015, Decimal('6.76')),
#  ('Senegal', 2016, Decimal('4.46')),
#  ('Senegal', 2017, Decimal('4.08')),
#  ('Senegal', 2018, Decimal('3.57')),
#  ('Senegal', 2019, Decimal('2.86')),
#  ('Senegal', 2020, None),
#  ('Seychelles', 2015, Decimal('4.15')),
#  ('Seychelles', 2016, Decimal('3.96')),
#  ('Seychelles', 2017, Decimal('3.71')),
#  ('Seychelles', 2018, Decimal('3.53')),
#  ('Seychelles', 2019, Decimal('2.97')),
#  ('Sierra Leone', 2015, None),
#  ('Sierra Leone', 2016, None),
#  ('Sierra Leone', 2017, None),
#  ('Sierra Leone', 2018, Decimal('3.19')),
#  ('Sierra Leone', 2019, None),
#  ('Sierra Leone', 2020, None),
#  ('Somalia', 2015, None),
#  ('Somalia', 2016, None),
#  ('Somalia', 2017, None),
#  ('Somalia', 2018, None),
#  ('Somalia', 2019, Decimal('18.83')),
#  ('Somalia', 2020, None),
#  ('South Africa', 2015, Decimal('22.87')),
#  ('South Africa', 2016, Decimal('24.02')),
#  ('South Africa', 2017, Decimal('23.99')),
#  ('South Africa', 2018, Decimal('24.22')),
#  ('South Africa', 2019, Decimal('25.54')),
#  ('South Africa', 2020, Decimal('24.34')),
#  ('South Sudan', 2015, None),
#  ('South Sudan', 2016, None),
#  ('South Sudan', 2017, None),
#  ('South Sudan', 2018, None),
#  ('South Sudan', 2019, None),
#  ('South Sudan', 2020, None),
#  ('Togo', 2015, Decimal('2.20')),
#  ('Togo', 2016, None),
#  ('Togo', 2017, Decimal('3.74')),
#  ('Togo', 2018, None),
#  ('Togo', 2019, None),
#  ('Togo', 2020, None),
#  ('Uganda', 2015, None),
#  ('Uganda', 2016, None),
#  ('Uganda', 2017, Decimal('3.64')),
#  ('Uganda', 2018, None),
#  ('Uganda', 2019, None),
#  ('Uganda', 2020, None),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, None),
#  ('Zambia', 2016, None),
#  ('Zambia', 2017, Decimal('8.52')),
#  ('Zambia', 2018, Decimal('5.03')),
#  ('Zambia', 2019, Decimal('5.54')),
#  ('Zambia', 2020, Decimal('6.03')),
#  ('Zimbabwe', 2015, None),
#  ('Zimbabwe', 2016, None),
#  ('Zimbabwe', 2017, None),
#  ('Zimbabwe', 2018, None),
#  ('Zimbabwe', 2019, Decimal('7.37')),
#  ('Zimbabwe', 2020, None)]

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as Pct_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 4

# %%
# %%sql
#
# CREATE VIEW united_nations.Country_Unemployment_Rate
# AS
#
# SELECT
#     loc.Country_name,
#     eco.Time_period,
#     IFNULL (eco.Pct_unemployment,33.65) as PCT_unemployment_imputed
# FROM
#     united_nations.Geographic_Location as loc
# LEFT JOIN united_nations.Economic_Indicators as eco
# ON eco.Country_name = loc.Country_name
# WHERE REGION = 'Sub-Saharan Africa';

# %% [markdown]
# ### Task 5

# %%
# %%sql
#
# SELECT *
# FROM
#     united_nations.Country_unemployment_Rate
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Angola', 2015, Decimal('33.65')),
#  ('Angola', 2016, Decimal('33.65')),
#  ('Angola', 2017, Decimal('33.65')),
#  ('Angola', 2018, Decimal('33.65')),
#  ('Angola', 2019, Decimal('16.50')),
#  ('Angola', 2020, Decimal('33.65')),
#  ('Benin', 2015, Decimal('33.65')),
#  ('Benin', 2016, Decimal('33.65')),
#  ('Benin', 2017, Decimal('33.65')),
#  ('Benin', 2018, Decimal('1.47'))]

# %% [markdown]
# ## Summary

# %% [markdown]
# In this notebook, we created a join with the `Economic_Indicators` table and the `Geographical_Locations` table. This allowed us to filter our data by `Region`, specifically the `Sub-Saharan African` region. We then imputed the Null values in the `Pct_unemployment` column. Finally, we saved this complex query in a VIEW and named that VIEW `united_nations.Country_unemployment_Rate`.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
