# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/Logo blue_dark.png"  style="width:25px" align="right";/>
# </div>

# %% [markdown]
# # Converting between data types
# © ExploreAI Academy

# %% [markdown]
# In this notebook, we will learn how to convert one data type to another using the `CAST()` function.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to convert from one data type to another using the `CAST()` function.

# %% [markdown]
# ## Overview
#
# All the columns in our database have been assigned a data type during the creation of the database schema. When we query our data using the `SELECT` statement, the retrieved data will be returned in the same data type as specified in the schema.
#
# Suppose we want to retrieve the data in a different data type, we can use the `CAST` function, which allows us to change from one data type to another.

# %% [markdown]
# ## Connecting to our MySQL database
#
# We will use our `Access_to_Basic_Services` table in our `united_nations` database that we created in MySQL Workbench. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Emily99@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# ## Exercise

# %% [markdown]
# We can use the following command to check the data types of all the columns in our table.

# %%
# %%sql
#
# SHOW
#     COLUMNS
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Region', 'varchar(32)', 'YES', '', None, ''),
#  ('Sub_region', 'varchar(25)', 'YES', '', None, ''),
#  ('Country_name', 'varchar(37)', 'NO', '', None, ''),
#  ('Time_period', 'int', 'NO', '', None, ''),
#  ('Pct_managed_drinking_water_services', 'decimal(5,2)', 'YES', '', None, ''),
#  ('Pct_managed_sanitation_services', 'decimal(5,2)', 'YES', '', None, ''),
#  ('Est_population_in_millions', 'decimal(11,6)', 'YES', '', None, ''),
#  ('Est_gdp_in_billions', 'decimal(8,2)', 'YES', '', None, ''),
#  ('Land_area', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Pct_unemployment', 'decimal(5,2)', 'YES', '', None, '')]

# %% [markdown]
# We can see that the column values are in their respective data types, that is, `VARCHAR` for Country_name, `INT` for Time_period, and `DECIMAL` for the estimated population.

# %% [markdown]
# Let us type in the following query which will give us the estimated population for each distinct country, per year.

# %%
# %%sql
#
# SELECT DISTINCT
#     Country_name,
#     Time_period,
#     Est_population_in_millions
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('17.542806')),
#  ('Kazakhstan', 2016, Decimal('17.794055')),
#  ('Kazakhstan', 2017, Decimal('18.037776')),
#  ('Kazakhstan', 2018, Decimal('18.276452')),
#  ('Kazakhstan', 2019, Decimal('18.513673')),
#  ('Kazakhstan', 2020, Decimal('18.755666')),
#  ('Kyrgyzstan', 2015, None),
#  ('Kyrgyzstan', 2016, None),
#  ('Kyrgyzstan', 2017, None),
#  ('Kyrgyzstan', 2018, None),
#  ('Kyrgyzstan', 2019, None),
#  ('Kyrgyzstan', 2020, None),
#  ('Tajikistan', 2015, Decimal('8.524063')),
#  ('Tajikistan', 2016, Decimal('8.725318')),
#  ('Tajikistan', 2017, Decimal('8.925525')),
#  ('Tajikistan', 2018, Decimal('9.128132')),
#  ('Tajikistan', 2019, Decimal('9.337003')),
#  ('Tajikistan', 2020, Decimal('9.543207')),
#  ('Turkmenistan', 2015, Decimal('5.766431')),
#  ('Turkmenistan', 2016, Decimal('5.868561')),
#  ('Turkmenistan', 2017, Decimal('5.968383')),
#  ('Turkmenistan', 2018, Decimal('6.065066')),
#  ('Turkmenistan', 2019, Decimal('6.158420')),
#  ('Turkmenistan', 2020, Decimal('6.250438')),
#  ('Uzbekistan', 2015, Decimal('31.298900')),
#  ('Uzbekistan', 2016, Decimal('31.847900')),
#  ('Uzbekistan', 2017, Decimal('32.388600')),
#  ('Uzbekistan', 2018, Decimal('32.956100')),
#  ('Uzbekistan', 2019, Decimal('33.580350')),
#  ('Uzbekistan', 2020, Decimal('34.232050')),
#  ('Afghanistan', 2015, Decimal('33.753499')),
#  ('Afghanistan', 2016, Decimal('34.636207')),
#  ('Afghanistan', 2017, Decimal('35.643418')),
#  ('Afghanistan', 2018, Decimal('36.686784')),
#  ('Afghanistan', 2019, Decimal('37.769499')),
#  ('Afghanistan', 2020, Decimal('38.972230')),
#  ('Bangladesh', 2015, Decimal('157.830000')),
#  ('Bangladesh', 2016, Decimal('159.784568')),
#  ('Bangladesh', 2017, Decimal('161.793964')),
#  ('Bangladesh', 2018, Decimal('163.683958')),
#  ('Bangladesh', 2019, Decimal('165.516222')),
#  ('Bangladesh', 2020, Decimal('167.420951')),
#  ('Bhutan', 2015, Decimal('0.743274')),
#  ('Bhutan', 2016, Decimal('0.749761')),
#  ('Bhutan', 2017, Decimal('0.756121')),
#  ('Bhutan', 2018, Decimal('0.762096')),
#  ('Bhutan', 2019, Decimal('0.767459')),
#  ('Bhutan', 2020, Decimal('0.772506')),
#  ('India', 2015, Decimal('1322.866505')),
#  ('India', 2016, Decimal('1338.636340')),
#  ('India', 2017, Decimal('1354.195680')),
#  ('India', 2018, Decimal('1369.003306')),
#  ('India', 2019, Decimal('1383.112050')),
#  ('India', 2020, Decimal('1396.387127')),
#  ('Iran (Islamic Republic of)', 2015, None),
#  ('Iran (Islamic Republic of)', 2016, None),
#  ('Iran (Islamic Republic of)', 2017, None),
#  ('Iran (Islamic Republic of)', 2018, None),
#  ('Iran (Islamic Republic of)', 2019, None),
#  ('Iran (Islamic Republic of)', 2020, None),
#  ('Maldives', 2015, Decimal('0.435582')),
#  ('Maldives', 2016, Decimal('0.454252')),
#  ('Maldives', 2017, Decimal('0.472442')),
#  ('Maldives', 2018, Decimal('0.489758')),
#  ('Maldives', 2019, Decimal('0.504508')),
#  ('Maldives', 2020, Decimal('0.514438')),
#  ('Nepal', 2015, Decimal('27.610325')),
#  ('Nepal', 2016, Decimal('27.861186')),
#  ('Nepal', 2017, Decimal('28.183426')),
#  ('Nepal', 2018, Decimal('28.506712')),
#  ('Nepal', 2019, Decimal('28.832496')),
#  ('Nepal', 2020, Decimal('29.348627')),
#  ('Pakistan', 2015, Decimal('210.969298')),
#  ('Pakistan', 2016, Decimal('213.524840')),
#  ('Pakistan', 2017, Decimal('216.379655')),
#  ('Pakistan', 2018, Decimal('219.731479')),
#  ('Pakistan', 2019, Decimal('223.293280')),
#  ('Pakistan', 2020, Decimal('227.196741')),
#  ('Sri Lanka', 2015, Decimal('20.970000')),
#  ('Sri Lanka', 2016, Decimal('21.203000')),
#  ('Sri Lanka', 2017, Decimal('21.444000')),
#  ('Sri Lanka', 2018, Decimal('21.670000')),
#  ('Sri Lanka', 2019, Decimal('21.803000')),
#  ('Sri Lanka', 2020, Decimal('21.919000')),
#  ('China', 2015, Decimal('1379.860000')),
#  ('China', 2016, Decimal('1387.790000')),
#  ('China', 2017, Decimal('1396.215000')),
#  ('China', 2018, Decimal('1402.760000')),
#  ('China', 2019, Decimal('1407.745000')),
#  ('China', 2020, Decimal('1411.100000')),
#  ("Democratic People's Republic of Korea", 2015, None),
#  ("Democratic People's Republic of Korea", 2016, None),
#  ("Democratic People's Republic of Korea", 2017, None),
#  ("Democratic People's Republic of Korea", 2018, None),
#  ("Democratic People's Republic of Korea", 2019, None),
#  ("Democratic People's Republic of Korea", 2020, None),
#  ('Japan', 2015, Decimal('127.141000')),
#  ('Japan', 2016, Decimal('127.076000')),
#  ('Japan', 2017, Decimal('126.972000')),
#  ('Japan', 2018, Decimal('126.811000')),
#  ('Japan', 2019, Decimal('126.633000')),
#  ('Japan', 2020, Decimal('126.261000')),
#  ('Mongolia', 2015, Decimal('2.964749')),
#  ('Mongolia', 2016, Decimal('3.029555')),
#  ('Mongolia', 2017, Decimal('3.096030')),
#  ('Mongolia', 2018, Decimal('3.163991')),
#  ('Mongolia', 2019, Decimal('3.232430')),
#  ('Mongolia', 2020, Decimal('3.294335')),
#  ('Republic of Korea', 2015, None),
#  ('Republic of Korea', 2016, None),
#  ('Republic of Korea', 2017, None),
#  ('Republic of Korea', 2018, None),
#  ('Republic of Korea', 2019, None),
#  ('Republic of Korea', 2020, None),
#  ('Brunei Darussalam', 2015, Decimal('0.421437')),
#  ('Brunei Darussalam', 2016, Decimal('0.425994')),
#  ('Brunei Darussalam', 2017, Decimal('0.430276')),
#  ('Brunei Darussalam', 2018, Decimal('0.434274')),
#  ('Brunei Darussalam', 2019, Decimal('0.438048')),
#  ('Brunei Darussalam', 2020, Decimal('0.441725')),
#  ('Cambodia', 2015, Decimal('15.417523')),
#  ('Cambodia', 2016, Decimal('15.624584')),
#  ('Cambodia', 2017, Decimal('15.830689')),
#  ('Cambodia', 2018, Decimal('16.025238')),
#  ('Cambodia', 2019, Decimal('16.207746')),
#  ('Cambodia', 2020, Decimal('16.396860')),
#  ('Indonesia', 2015, Decimal('259.091970')),
#  ('Indonesia', 2016, Decimal('261.850182')),
#  ('Indonesia', 2017, Decimal('264.498852')),
#  ('Indonesia', 2018, Decimal('267.066843')),
#  ('Indonesia', 2019, Decimal('269.582878')),
#  ('Indonesia', 2020, Decimal('271.857970')),
#  ("Lao People's Democratic Republic", 2015, None),
#  ("Lao People's Democratic Republic", 2016, None),
#  ("Lao People's Democratic Republic", 2017, None),
#  ("Lao People's Democratic Republic", 2018, None),
#  ("Lao People's Democratic Republic", 2019, None),
#  ("Lao People's Democratic Republic", 2020, None),
#  ('Malaysia', 2015, Decimal('31.068833')),
#  ('Malaysia', 2016, Decimal('31.526418')),
#  ('Malaysia', 2017, Decimal('31.975806')),
#  ('Malaysia', 2018, Decimal('32.399271')),
#  ('Malaysia', 2019, Decimal('32.804020')),
#  ('Malaysia', 2020, Decimal('33.199993')),
#  ('Myanmar', 2015, Decimal('51.483949')),
#  ('Myanmar', 2016, Decimal('51.892349')),
#  ('Myanmar', 2017, Decimal('52.288341')),
#  ('Myanmar', 2018, Decimal('52.666014')),
#  ('Myanmar', 2019, Decimal('53.040212')),
#  ('Myanmar', 2020, Decimal('53.423198')),
#  ('Philippines', 2015, Decimal('103.031365')),
#  ('Philippines', 2016, Decimal('104.875266')),
#  ('Philippines', 2017, Decimal('106.738501')),
#  ('Philippines', 2018, Decimal('108.568836')),
#  ('Philippines', 2019, Decimal('110.380804')),
#  ('Philippines', 2020, Decimal('112.190977')),
#  ('Singapore', 2015, Decimal('5.535002')),
#  ('Singapore', 2016, Decimal('5.607283')),
#  ('Singapore', 2017, Decimal('5.612253')),
#  ('Singapore', 2018, Decimal('5.638676')),
#  ('Singapore', 2019, Decimal('5.703569')),
#  ('Singapore', 2020, Decimal('5.685807')),
#  ('Thailand', 2015, Decimal('70.294397')),
#  ('Thailand', 2016, Decimal('70.607037')),
#  ('Thailand', 2017, Decimal('70.898202')),
#  ('Thailand', 2018, Decimal('71.127802')),
#  ('Thailand', 2019, Decimal('71.307763')),
#  ('Thailand', 2020, Decimal('71.475664')),
#  ('Timor-Leste', 2015, Decimal('1.205813')),
#  ('Timor-Leste', 2016, Decimal('1.224562')),
#  ('Timor-Leste', 2017, Decimal('1.243235')),
#  ('Timor-Leste', 2018, Decimal('1.261845')),
#  ('Timor-Leste', 2019, Decimal('1.280438')),
#  ('Timor-Leste', 2020, Decimal('1.299995')),
#  ('Viet Nam', 2015, None),
#  ('Viet Nam', 2016, None),
#  ('Viet Nam', 2017, None),
#  ('Viet Nam', 2018, None),
#  ('Viet Nam', 2019, None),
#  ('Viet Nam', 2020, None),
#  ('Bermuda', 2015, Decimal('0.065237')),
#  ('Bermuda', 2016, Decimal('0.064554')),
#  ('Bermuda', 2017, Decimal('0.063873')),
#  ('Bermuda', 2018, Decimal('0.063918')),
#  ('Bermuda', 2019, Decimal('0.063911')),
#  ('Bermuda', 2020, Decimal('0.063893')),
#  ('Canada', 2015, Decimal('35.702908')),
#  ('Canada', 2016, Decimal('36.109487')),
#  ('Canada', 2017, Decimal('36.545236')),
#  ('Canada', 2018, Decimal('37.065084')),
#  ('Canada', 2019, Decimal('37.601230')),
#  ('Canada', 2020, Decimal('38.037204')),
#  ('Greenland', 2015, Decimal('0.056114')),
#  ('Greenland', 2016, Decimal('0.056186')),
#  ('Greenland', 2017, Decimal('0.056171')),
#  ('Greenland', 2018, Decimal('0.056023')),
#  ('Greenland', 2019, Decimal('0.056225')),
#  ('Greenland', 2020, Decimal('0.056367')),
#  ('Saint Pierre and Miquelon', 2015, None),
#  ('Saint Pierre and Miquelon', 2016, None),
#  ('Saint Pierre and Miquelon', 2017, None),
#  ('Saint Pierre and Miquelon', 2018, None),
#  ('Saint Pierre and Miquelon', 2019, None),
#  ('Saint Pierre and Miquelon', 2020, None),
#  ('United States of America', 2015, None),
#  ('United States of America', 2016, None),
#  ('United States of America', 2017, None),
#  ('United States of America', 2018, None),
#  ('United States of America', 2019, None),
#  ('United States of America', 2020, None),
#  ('Anguilla', 2015, None),
#  ('Anguilla', 2016, None),
#  ('Anguilla', 2017, None),
#  ('Antigua and Barbuda', 2015, Decimal('0.089941')),
#  ('Antigua and Barbuda', 2016, Decimal('0.090564')),
#  ('Antigua and Barbuda', 2017, Decimal('0.091119')),
#  ('Aruba', 2015, Decimal('0.104257')),
#  ('Aruba', 2016, Decimal('0.104874')),
#  ('Bahamas', 2015, None),
#  ('Bahamas', 2016, None),
#  ('Bahamas', 2017, None),
#  ('Bahamas', 2018, None),
#  ('Bahamas', 2019, None),
#  ('Barbados', 2015, Decimal('0.278083')),
#  ('Barbados', 2016, Decimal('0.278649')),
#  ('Barbados', 2017, Decimal('0.279187')),
#  ('Barbados', 2018, Decimal('0.279688')),
#  ('Barbados', 2019, Decimal('0.280180')),
#  ('Barbados', 2020, Decimal('0.280693')),
#  ('British Virgin Islands', 2015, Decimal('0.029366')),
#  ('British Virgin Islands', 2016, Decimal('0.029739')),
#  ('British Virgin Islands', 2017, Decimal('0.030060')),
#  ('British Virgin Islands', 2018, Decimal('0.030335')),
#  ('British Virgin Islands', 2019, Decimal('0.030610')),
#  ('British Virgin Islands', 2020, Decimal('0.030910')),
#  ('Cayman Islands', 2015, Decimal('0.060911')),
#  ('Cayman Islands', 2016, Decimal('0.062255')),
#  ('Cuba', 2015, Decimal('11.339894')),
#  ('Cuba', 2016, Decimal('11.342012')),
#  ('Cuba', 2017, Decimal('11.336405')),
#  ('Cuba', 2018, Decimal('11.328244')),
#  ('Cuba', 2019, Decimal('11.316697')),
#  ('Cuba', 2020, Decimal('11.300698')),
#  ('Curaçao', 2015, None),
#  ('Curaçao', 2016, None),
#  ('Curaçao', 2017, None),
#  ('Dominica', 2015, Decimal('0.070007')),
#  ('Dominica', 2016, Decimal('0.070075')),
#  ('Dominica', 2017, Decimal('0.070403')),
#  ('Dominican Republic', 2015, Decimal('10.405832')),
#  ('Dominican Republic', 2016, Decimal('10.527592')),
#  ('Dominican Republic', 2017, Decimal('10.647244')),
#  ('Dominican Republic', 2018, Decimal('10.765531')),
#  ('Dominican Republic', 2019, Decimal('10.881882')),
#  ('Dominican Republic', 2020, Decimal('10.999664')),
#  ('Grenada', 2015, Decimal('0.118980')),
#  ('Grenada', 2016, Decimal('0.119966')),
#  ('Grenada', 2017, Decimal('0.120921')),
#  ('Guadeloupe', 2015, None),
#  ('Guadeloupe', 2016, None),
#  ('Guadeloupe', 2017, None),
#  ('Guadeloupe', 2018, None),
#  ('Guadeloupe', 2019, None),
#  ('Guadeloupe', 2020, None),
#  ('Haiti', 2015, Decimal('10.563757')),
#  ('Haiti', 2016, Decimal('10.713849')),
#  ('Haiti', 2017, Decimal('10.863543')),
#  ('Haiti', 2018, Decimal('11.012421')),
#  ('Haiti', 2019, Decimal('11.160438')),
#  ('Haiti', 2020, Decimal('11.306801')),
#  ('Jamaica', 2015, Decimal('2.794445')),
#  ('Jamaica', 2016, Decimal('2.802695')),
#  ('Jamaica', 2017, Decimal('2.808376')),
#  ('Jamaica', 2018, Decimal('2.811835')),
#  ('Jamaica', 2019, Decimal('2.813773')),
#  ('Jamaica', 2020, Decimal('2.820436')),
#  ('Martinique', 2015, None),
#  ('Martinique', 2016, None),
#  ('Martinique', 2017, None),
#  ('Martinique', 2018, None),
#  ('Martinique', 2019, None),
#  ('Martinique', 2020, None),
#  ('Montserrat', 2015, None),
#  ('Montserrat', 2016, None),
#  ('Montserrat', 2017, None),
#  ('Montserrat', 2018, None),
#  ('Montserrat', 2019, None),
#  ('Montserrat', 2020, None),
#  ('Puerto Rico', 2015, Decimal('3.473232')),
#  ('Puerto Rico', 2016, Decimal('3.406672')),
#  ('Puerto Rico', 2017, Decimal('3.325286')),
#  ('Puerto Rico', 2018, Decimal('3.193354')),
#  ('Puerto Rico', 2019, Decimal('3.193694')),
#  ('Puerto Rico', 2020, Decimal('3.281538')),
#  ('Saint Barthélemy', 2015, None),
#  ('Saint Barthélemy', 2016, None),
#  ('Saint Barthélemy', 2017, None),
#  ('Saint Barthélemy', 2018, None),
#  ('Saint Barthélemy', 2019, None),
#  ('Saint Barthélemy', 2020, None),
#  ('Saint Kitts and Nevis', 2015, None),
#  ('Saint Kitts and Nevis', 2016, None),
#  ('Saint Kitts and Nevis', 2017, None),
#  ('Saint Lucia', 2015, None),
#  ('Saint Lucia', 2016, None),
#  ('Saint Lucia', 2017, None),
#  ('Saint Lucia', 2018, None),
#  ('Saint Lucia', 2019, None),
#  ('Saint Lucia', 2020, None),
#  ('Saint Martin (French Part)', 2015, None),
#  ('Saint Martin (French Part)', 2016, None),
#  ('Saint Martin (French Part)', 2017, None),
#  ('Saint Martin (French Part)', 2018, None),
#  ('Saint Martin (French Part)', 2019, None),
#  ('Saint Martin (French Part)', 2020, None),
#  ('Saint Vincent and the Grenadines', 2015, None),
#  ('Saint Vincent and the Grenadines', 2016, None),
#  ('Saint Vincent and the Grenadines', 2017, None),
#  ('Saint Vincent and the Grenadines', 2018, None),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('0.038825')),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('0.039969')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('0.040574')),
#  ('Trinidad and Tobago', 2015, Decimal('1.460177')),
#  ('Trinidad and Tobago', 2016, Decimal('1.469330')),
#  ('Trinidad and Tobago', 2017, Decimal('1.478607')),
#  ('Trinidad and Tobago', 2018, Decimal('1.504709')),
#  ('Trinidad and Tobago', 2019, Decimal('1.519955')),
#  ('Trinidad and Tobago', 2020, Decimal('1.518147')),
#  ('Turks and Caicos Islands', 2015, Decimal('0.036538')),
#  ('Turks and Caicos Islands', 2016, Decimal('0.038246')),
#  ('Turks and Caicos Islands', 2017, Decimal('0.039844')),
#  ('Turks and Caicos Islands', 2018, Decimal('0.041487')),
#  ('United States Virgin Islands', 2015, None),
#  ('United States Virgin Islands', 2016, None),
#  ('United States Virgin Islands', 2017, None),
#  ('United States Virgin Islands', 2018, None),
#  ('United States Virgin Islands', 2019, None),
#  ('United States Virgin Islands', 2020, None),
#  ('Belize', 2015, Decimal('0.359871')),
#  ('Belize', 2016, Decimal('0.367313')),
#  ('Belize', 2017, Decimal('0.374693')),
#  ('Belize', 2018, Decimal('0.382066')),
#  ('Belize', 2019, Decimal('0.389095')),
#  ('Belize', 2020, Decimal('0.394921')),
#  ('Costa Rica', 2015, Decimal('4.895242')),
#  ('Costa Rica', 2016, Decimal('4.945205')),
#  ('Costa Rica', 2017, Decimal('4.993842')),
#  ('Costa Rica', 2018, Decimal('5.040734')),
#  ('Costa Rica', 2019, Decimal('5.084532')),
#  ('Costa Rica', 2020, Decimal('5.123105')),
#  ('El Salvador', 2015, Decimal('6.231066')),
#  ('El Salvador', 2016, Decimal('6.250510')),
#  ('El Salvador', 2017, Decimal('6.266654')),
#  ('El Salvador', 2018, Decimal('6.276342')),
#  ('El Salvador', 2019, Decimal('6.280217')),
#  ('El Salvador', 2020, Decimal('6.292731')),
#  ('Guatemala', 2015, Decimal('15.567419')),
#  ('Guatemala', 2016, Decimal('15.827690')),
#  ('Guatemala', 2017, Decimal('16.087418')),
#  ('Guatemala', 2018, Decimal('16.346950')),
#  ('Guatemala', 2019, Decimal('16.604026')),
#  ('Guatemala', 2020, Decimal('16.858333')),
#  ('Honduras', 2015, Decimal('9.294505')),
#  ('Honduras', 2016, Decimal('9.460798')),
#  ('Honduras', 2017, Decimal('9.626842')),
#  ('Honduras', 2018, Decimal('9.792850')),
#  ('Honduras', 2019, Decimal('9.958829')),
#  ('Honduras', 2020, Decimal('10.121763')),
#  ('Mexico', 2015, Decimal('120.149897')),
#  ('Mexico', 2016, Decimal('121.519221')),
#  ('Mexico', 2017, Decimal('122.839258')),
#  ('Mexico', 2018, Decimal('124.013861')),
#  ('Mexico', 2019, Decimal('125.085311')),
#  ('Mexico', 2020, Decimal('125.998302')),
#  ('Nicaragua', 2015, Decimal('6.298598')),
#  ('Nicaragua', 2016, Decimal('6.389235')),
#  ('Nicaragua', 2017, Decimal('6.480532')),
#  ('Nicaragua', 2018, Decimal('6.572233')),
#  ('Nicaragua', 2019, Decimal('6.663924')),
#  ('Nicaragua', 2020, Decimal('6.755895')),
#  ('Panama', 2015, Decimal('3.957099')),
#  ('Panama', 2016, Decimal('4.026336')),
#  ('Panama', 2017, Decimal('4.096063')),
#  ('Panama', 2018, Decimal('4.165255')),
#  ('Panama', 2019, Decimal('4.232532')),
#  ('Panama', 2020, Decimal('4.294396')),
#  ('Argentina', 2015, Decimal('43.131966')),
#  ('Argentina', 2016, Decimal('43.590368')),
#  ('Argentina', 2017, Decimal('44.044811')),
#  ('Argentina', 2018, Decimal('44.494502')),
#  ('Argentina', 2019, Decimal('44.938712')),
#  ('Argentina', 2020, Decimal('45.376763')),
#  ('Bolivia (Plurinational State of)', 2015, None),
#  ('Bolivia (Plurinational State of)', 2016, None),
#  ('Bolivia (Plurinational State of)', 2017, None),
#  ('Bolivia (Plurinational State of)', 2018, None),
#  ('Bolivia (Plurinational State of)', 2019, None),
#  ('Bolivia (Plurinational State of)', 2020, None),
#  ('Brazil', 2015, Decimal('205.188205')),
#  ('Brazil', 2016, Decimal('206.859578')),
#  ('Brazil', 2017, Decimal('208.504960')),
#  ('Brazil', 2018, Decimal('210.166592')),
#  ('Brazil', 2019, Decimal('211.782878')),
#  ('Brazil', 2020, Decimal('213.196304')),
#  ('Chile', 2015, Decimal('17.870124')),
#  ('Chile', 2016, Decimal('18.083879')),
#  ('Chile', 2017, Decimal('18.368577')),
#  ('Chile', 2018, Decimal('18.701450')),
#  ('Chile', 2019, Decimal('19.039485')),
#  ('Chile', 2020, Decimal('19.300315')),
#  ('Colombia', 2015, Decimal('47.119728')),
#  ('Colombia', 2016, Decimal('47.625955')),
#  ('Colombia', 2017, Decimal('48.351671')),
#  ('Colombia', 2018, Decimal('49.276961')),
#  ('Colombia', 2019, Decimal('50.187406')),
#  ('Colombia', 2020, Decimal('50.930662')),
#  ('Ecuador', 2015, Decimal('16.195902')),
#  ('Ecuador', 2016, Decimal('16.439585')),
#  ('Ecuador', 2017, Decimal('16.696944')),
#  ('Ecuador', 2018, Decimal('17.015672')),
#  ('Ecuador', 2019, Decimal('17.343740')),
#  ('Ecuador', 2020, Decimal('17.588595')),
#  ('Falkland Islands (Malvinas)', 2015, None),
#  ('Falkland Islands (Malvinas)', 2016, None),
#  ('Falkland Islands (Malvinas)', 2017, None),
#  ('Falkland Islands (Malvinas)', 2018, None),
#  ('Falkland Islands (Malvinas)', 2019, None),
#  ('Falkland Islands (Malvinas)', 2020, None),
#  ('French Guiana', 2015, None),
#  ('French Guiana', 2016, None),
#  ('French Guiana', 2017, None),
#  ('French Guiana', 2018, None),
#  ('French Guiana', 2019, None),
#  ('French Guiana', 2020, None),
#  ('Guyana', 2015, Decimal('0.755031')),
#  ('Guyana', 2016, Decimal('0.759087')),
#  ('Guyana', 2017, Decimal('0.763252')),
#  ('Guyana', 2018, Decimal('0.785514')),
#  ('Guyana', 2019, Decimal('0.798753')),
#  ('Guyana', 2020, Decimal('0.797202')),
#  ('Paraguay', 2015, Decimal('6.177950')),
#  ('Paraguay', 2016, Decimal('6.266615')),
#  ('Paraguay', 2017, Decimal('6.355404')),
#  ('Paraguay', 2018, Decimal('6.443328')),
#  ('Paraguay', 2019, Decimal('6.530026')),
#  ('Paraguay', 2020, Decimal('6.618695')),
#  ('Peru', 2015, Decimal('30.711863')),
#  ('Peru', 2016, Decimal('31.132779')),
#  ('Peru', 2017, Decimal('31.605486')),
#  ('Peru', 2018, Decimal('32.203944')),
#  ('Peru', 2019, Decimal('32.824861')),
#  ('Peru', 2020, Decimal('33.304756')),
#  ('Suriname', 2015, Decimal('0.575475')),
#  ('Suriname', 2016, Decimal('0.581453')),
#  ('Suriname', 2017, Decimal('0.587559')),
#  ('Suriname', 2018, Decimal('0.593715')),
#  ('Suriname', 2019, Decimal('0.600301')),
#  ('Suriname', 2020, Decimal('0.607065')),
#  ('Uruguay', 2015, Decimal('3.402818')),
#  ('Uruguay', 2016, Decimal('3.413766')),
#  ('Uruguay', 2017, Decimal('3.422200')),
#  ('Uruguay', 2018, Decimal('3.427042')),
#  ('Uruguay', 2019, Decimal('3.428409')),
#  ('Uruguay', 2020, Decimal('3.429086')),
#  ('Venezuela (Bolivarian Republic of)', 2015, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None),
#  ('Algeria', 2015, Decimal('39.543154')),
#  ('Algeria', 2016, Decimal('40.339329')),
#  ('Algeria', 2017, Decimal('41.136546')),
#  ('Algeria', 2018, Decimal('41.927007')),
#  ('Algeria', 2019, Decimal('42.705368')),
#  ('Algeria', 2020, Decimal('43.451666')),
#  ('Egypt', 2015, None),
#  ('Egypt', 2016, None),
#  ('Egypt', 2017, None),
#  ('Egypt', 2018, None),
#  ('Egypt', 2019, None),
#  ('Egypt', 2020, None),
#  ('Libya', 2015, Decimal('6.192235')),
#  ('Libya', 2016, Decimal('6.282196')),
#  ('Libya', 2017, Decimal('6.378261')),
#  ('Libya', 2018, Decimal('6.477793')),
#  ('Libya', 2019, Decimal('6.569088')),
#  ('Libya', 2020, Decimal('6.653942')),
#  ('Morocco', 2015, Decimal('34.680458')),
#  ('Morocco', 2016, Decimal('35.107264')),
#  ('Morocco', 2017, Decimal('35.528115')),
#  ('Morocco', 2018, Decimal('35.927511')),
#  ('Morocco', 2019, Decimal('36.304408')),
#  ('Morocco', 2020, Decimal('36.688772')),
#  ('Sudan', 2015, Decimal('38.171178')),
#  ('Sudan', 2016, Decimal('39.377169')),
#  ('Sudan', 2017, Decimal('40.679828')),
#  ('Sudan', 2018, Decimal('41.999059')),
#  ('Sudan', 2019, Decimal('43.232093')),
#  ('Sudan', 2020, Decimal('44.440486')),
#  ('Tunisia', 2015, Decimal('11.557779')),
#  ('Tunisia', 2016, Decimal('11.685667')),
#  ('Tunisia', 2017, Decimal('11.811443')),
#  ('Tunisia', 2018, Decimal('11.933041')),
#  ('Tunisia', 2019, Decimal('12.049314')),
#  ('Tunisia', 2020, Decimal('12.161723')),
#  ('Armenia', 2015, Decimal('2.878595')),
#  ('Armenia', 2016, Decimal('2.865835')),
#  ('Armenia', 2017, Decimal('2.851923')),
#  ('Armenia', 2018, Decimal('2.836557')),
#  ('Armenia', 2019, Decimal('2.820602')),
#  ('Armenia', 2020, Decimal('2.805608')),
#  ('Azerbaijan', 2015, Decimal('9.649341')),
#  ('Azerbaijan', 2016, Decimal('9.757812')),
#  ('Azerbaijan', 2017, Decimal('9.854033')),
#  ('Azerbaijan', 2018, Decimal('9.939771')),
#  ('Azerbaijan', 2019, Decimal('10.024283')),
#  ('Azerbaijan', 2020, Decimal('10.093121')),
#  ('Bahrain', 2015, Decimal('1.362142')),
#  ('Bahrain', 2016, Decimal('1.409661')),
#  ('Bahrain', 2017, Decimal('1.456834')),
#  ('Bahrain', 2018, Decimal('1.487340')),
#  ('Bahrain', 2019, Decimal('1.494188')),
#  ('Bahrain', 2020, Decimal('1.477469')),
#  ('Cyprus', 2015, Decimal('1.187280')),
#  ('Cyprus', 2016, Decimal('1.197881')),
#  ('Cyprus', 2017, Decimal('1.208523')),
#  ('Cyprus', 2018, Decimal('1.218831')),
#  ('Cyprus', 2019, Decimal('1.228836')),
#  ('Cyprus', 2020, Decimal('1.237537')),
#  ('Georgia', 2015, Decimal('3.725276')),
#  ('Georgia', 2016, Decimal('3.727505')),
#  ('Georgia', 2017, Decimal('3.728004')),
#  ('Georgia', 2018, Decimal('3.726549')),
#  ('Georgia', 2019, Decimal('3.720161')),
#  ('Georgia', 2020, Decimal('3.722716')),
#  ('Iraq', 2015, Decimal('37.757813')),
#  ('Iraq', 2016, Decimal('38.697943')),
#  ('Iraq', 2017, Decimal('39.621162')),
#  ('Iraq', 2018, Decimal('40.590700')),
#  ('Iraq', 2019, Decimal('41.563520')),
#  ('Iraq', 2020, Decimal('42.556984')),
#  ('Israel', 2015, Decimal('8.380100')),
#  ('Israel', 2016, Decimal('8.546000')),
#  ('Israel', 2017, Decimal('8.713300')),
#  ('Israel', 2018, Decimal('8.882800')),
#  ('Israel', 2019, Decimal('9.054000')),
#  ('Israel', 2020, Decimal('9.215100')),
#  ('Jordan', 2015, Decimal('9.494246')),
#  ('Jordan', 2016, Decimal('9.964656')),
#  ('Jordan', 2017, Decimal('10.215381')),
#  ('Jordan', 2018, Decimal('10.459865')),
#  ('Jordan', 2019, Decimal('10.698683')),
#  ('Jordan', 2020, Decimal('10.928721')),
#  ('Kuwait', 2015, Decimal('3.908743')),
#  ('Kuwait', 2016, Decimal('4.048085')),
#  ('Kuwait', 2017, Decimal('4.124904')),
#  ('Kuwait', 2018, Decimal('4.317185')),
#  ('Kuwait', 2019, Decimal('4.441100')),
#  ('Kuwait', 2020, Decimal('4.360444')),
#  ('Lebanon', 2015, Decimal('6.398940')),
#  ('Lebanon', 2016, Decimal('6.258619')),
#  ('Lebanon', 2017, Decimal('6.109252')),
#  ('Lebanon', 2018, Decimal('5.950839')),
#  ('Lebanon', 2019, Decimal('5.781907')),
#  ('Lebanon', 2020, Decimal('5.662923')),
#  ('Oman', 2015, Decimal('4.191776')),
#  ('Oman', 2016, Decimal('4.398070')),
#  ('Oman', 2017, Decimal('4.541854')),
#  ('Oman', 2018, Decimal('4.601157')),
#  ('Oman', 2019, Decimal('4.602768')),
#  ('Oman', 2020, Decimal('4.543399')),
#  ('Qatar', 2015, Decimal('2.414573')),
#  ('Qatar', 2016, Decimal('2.595166')),
#  ('Qatar', 2017, Decimal('2.711755')),
#  ('Qatar', 2018, Decimal('2.766732')),
#  ('Qatar', 2019, Decimal('2.807235')),
#  ('Qatar', 2020, Decimal('2.760385')),
#  ('Saudi Arabia', 2015, Decimal('32.749848')),
#  ('Saudi Arabia', 2016, Decimal('33.416270')),
#  ('Saudi Arabia', 2017, Decimal('34.193122')),
#  ('Saudi Arabia', 2018, Decimal('35.018133')),
#  ('Saudi Arabia', 2019, Decimal('35.827362')),
#  ('Saudi Arabia', 2020, Decimal('35.997107')),
#  ('State of Palestine', 2015, None),
#  ('State of Palestine', 2016, None),
#  ('State of Palestine', 2017, None),
#  ('State of Palestine', 2018, None),
#  ('State of Palestine', 2019, None),
#  ('State of Palestine', 2020, None),
#  ('Syrian Arab Republic', 2015, Decimal('19.205178')),
#  ('Syrian Arab Republic', 2016, Decimal('18.964252')),
#  ('Syrian Arab Republic', 2017, Decimal('18.983373')),
#  ('Syrian Arab Republic', 2018, Decimal('19.333463')),
#  ('Syrian Arab Republic', 2019, Decimal('20.098251')),
#  ('Syrian Arab Republic', 2020, Decimal('20.772595')),
#  ('Türkiye', 2015, None),
#  ('Türkiye', 2016, None),
#  ('Türkiye', 2017, None),
#  ('Türkiye', 2018, None),
#  ('Türkiye', 2019, None),
#  ('Türkiye', 2020, None),
#  ('United Arab Emirates', 2015, Decimal('8.916899')),
#  ('United Arab Emirates', 2016, Decimal('8.994263')),
#  ('United Arab Emirates', 2017, Decimal('9.068296')),
#  ('United Arab Emirates', 2018, Decimal('9.140169')),
#  ('United Arab Emirates', 2019, Decimal('9.211657')),
#  ('United Arab Emirates', 2020, Decimal('9.287289')),
#  ('Yemen', 2015, None),
#  ('Yemen', 2016, None),
#  ('Yemen', 2017, None),
#  ('Yemen', 2018, None),
#  ('Yemen', 2019, None),
#  ('Yemen', 2020, None),
#  ('Australia', 2015, Decimal('23.815995')),
#  ('Australia', 2016, Decimal('24.190907')),
#  ('Australia', 2017, Decimal('24.594202')),
#  ('Australia', 2018, Decimal('24.966643')),
#  ('Australia', 2019, Decimal('25.340217')),
#  ('Australia', 2020, Decimal('25.655289')),
#  ('New Zealand', 2015, Decimal('4.609400')),
#  ('New Zealand', 2016, Decimal('4.714100')),
#  ('New Zealand', 2017, Decimal('4.813600')),
#  ('New Zealand', 2018, Decimal('4.900600')),
#  ('New Zealand', 2019, Decimal('4.979200')),
#  ('New Zealand', 2020, Decimal('5.090200')),
#  ('Fiji', 2015, Decimal('0.917200')),
#  ('Fiji', 2016, Decimal('0.918371')),
#  ('Fiji', 2017, Decimal('0.919019')),
#  ('Fiji', 2018, Decimal('0.918996')),
#  ('Fiji', 2019, Decimal('0.918465')),
#  ('Fiji', 2020, Decimal('0.920422')),
#  ('New Caledonia', 2015, Decimal('0.269460')),
#  ('New Caledonia', 2016, Decimal('0.270220')),
#  ('New Caledonia', 2017, Decimal('0.270810')),
#  ('New Caledonia', 2018, Decimal('0.271170')),
#  ('New Caledonia', 2019, Decimal('0.271230')),
#  ('New Caledonia', 2020, Decimal('0.271130')),
#  ('Papua New Guinea', 2015, Decimal('8.682174')),
#  ('Papua New Guinea', 2016, Decimal('8.899169')),
#  ('Papua New Guinea', 2017, Decimal('9.114796')),
#  ('Papua New Guinea', 2018, Decimal('9.329227')),
#  ('Papua New Guinea', 2019, Decimal('9.542486')),
#  ('Papua New Guinea', 2020, Decimal('9.749640')),
#  ('Solomon Islands', 2015, Decimal('0.612660')),
#  ('Solomon Islands', 2016, Decimal('0.628102')),
#  ('Solomon Islands', 2017, Decimal('0.643634')),
#  ('Solomon Islands', 2018, Decimal('0.659249')),
#  ('Solomon Islands', 2019, Decimal('0.674993')),
#  ('Solomon Islands', 2020, Decimal('0.691191')),
#  ('Vanuatu', 2015, Decimal('0.276438')),
#  ('Vanuatu', 2016, Decimal('0.283218')),
#  ('Vanuatu', 2017, Decimal('0.290239')),
#  ('Vanuatu', 2018, Decimal('0.297298')),
#  ('Vanuatu', 2019, Decimal('0.304404')),
#  ('Vanuatu', 2020, Decimal('0.311685')),
#  ('Guam', 2015, Decimal('0.167978')),
#  ('Guam', 2016, Decimal('0.168346')),
#  ('Guam', 2017, Decimal('0.168606')),
#  ('Guam', 2018, Decimal('0.168678')),
#  ('Guam', 2019, Decimal('0.168624')),
#  ('Guam', 2020, Decimal('0.169231')),
#  ('Kiribati', 2015, Decimal('0.116707')),
#  ('Kiribati', 2016, Decimal('0.118513')),
#  ('Kiribati', 2017, Decimal('0.120362')),
#  ('Kiribati', 2018, Decimal('0.122261')),
#  ('Kiribati', 2019, Decimal('0.124241')),
#  ('Kiribati', 2020, Decimal('0.126463')),
#  ('Marshall Islands', 2015, Decimal('0.049410')),
#  ('Marshall Islands', 2016, Decimal('0.048329')),
#  ('Marshall Islands', 2017, Decimal('0.047187')),
#  ('Marshall Islands', 2018, Decimal('0.045989')),
#  ('Marshall Islands', 2019, Decimal('0.044728')),
#  ('Marshall Islands', 2020, Decimal('0.043413')),
#  ('Micronesia (Federated States of)', 2015, None),
#  ('Micronesia (Federated States of)', 2016, None),
#  ('Micronesia (Federated States of)', 2017, None),
#  ('Micronesia (Federated States of)', 2018, None),
#  ('Micronesia (Federated States of)', 2019, None),
#  ('Nauru', 2015, Decimal('0.011185')),
#  ('Nauru', 2016, Decimal('0.011437')),
#  ('Nauru', 2017, Decimal('0.011682')),
#  ('Nauru', 2018, Decimal('0.011924')),
#  ('Nauru', 2019, Decimal('0.012132')),
#  ('Nauru', 2020, Decimal('0.012315')),
#  ('Northern Mariana Islands', 2015, Decimal('0.051514')),
#  ('Northern Mariana Islands', 2016, Decimal('0.051133')),
#  ('Northern Mariana Islands', 2017, Decimal('0.050729')),
#  ('Northern Mariana Islands', 2018, Decimal('0.050304')),
#  ('Northern Mariana Islands', 2019, Decimal('0.049858')),
#  ('Northern Mariana Islands', 2020, Decimal('0.049587')),
#  ('Palau', 2015, Decimal('0.017794')),
#  ('Palau', 2016, Decimal('0.017816')),
#  ('Palau', 2017, Decimal('0.017837')),
#  ('Palau', 2018, Decimal('0.017864')),
#  ('Palau', 2019, Decimal('0.017916')),
#  ('Palau', 2020, Decimal('0.017972')),
#  ('American Samoa', 2015, Decimal('0.051368')),
#  ('American Samoa', 2016, Decimal('0.050448')),
#  ('American Samoa', 2017, Decimal('0.049463')),
#  ('American Samoa', 2018, Decimal('0.048424')),
#  ('American Samoa', 2019, Decimal('0.047321')),
#  ('American Samoa', 2020, Decimal('0.046189')),
#  ('Cook Islands', 2015, None),
#  ('Cook Islands', 2016, None),
#  ('Cook Islands', 2017, None),
#  ('Cook Islands', 2018, None),
#  ('Cook Islands', 2019, None),
#  ('Cook Islands', 2020, None),
#  ('French Polynesia', 2015, Decimal('0.291787')),
#  ('French Polynesia', 2016, Decimal('0.293541')),
#  ('French Polynesia', 2017, Decimal('0.295450')),
#  ('French Polynesia', 2018, Decimal('0.297606')),
#  ('French Polynesia', 2019, Decimal('0.299717')),
#  ('French Polynesia', 2020, Decimal('0.301920')),
#  ('Niue', 2015, None),
#  ('Niue', 2016, None),
#  ('Niue', 2017, None),
#  ('Niue', 2018, None),
#  ('Niue', 2019, None),
#  ('Niue', 2020, None),
#  ('Samoa', 2015, Decimal('0.203571')),
#  ('Samoa', 2016, Decimal('0.205544')),
#  ('Samoa', 2017, Decimal('0.207630')),
#  ('Samoa', 2018, Decimal('0.209701')),
#  ('Samoa', 2019, Decimal('0.211905')),
#  ('Samoa', 2020, Decimal('0.214929')),
#  ('Tokelau', 2015, None),
#  ('Tokelau', 2016, None),
#  ('Tokelau', 2017, None),
#  ('Tokelau', 2018, None),
#  ('Tokelau', 2019, None),
#  ('Tokelau', 2020, None),
#  ('Tonga', 2015, Decimal('0.106122')),
#  ('Tonga', 2016, Decimal('0.105707')),
#  ('Tonga', 2017, Decimal('0.105415')),
#  ('Tonga', 2018, Decimal('0.105150')),
#  ('Tonga', 2019, Decimal('0.104951')),
#  ('Tonga', 2020, Decimal('0.105254')),
#  ('Tuvalu', 2015, Decimal('0.010877')),
#  ('Tuvalu', 2016, Decimal('0.010852')),
#  ('Tuvalu', 2017, Decimal('0.010828')),
#  ('Tuvalu', 2018, Decimal('0.010865')),
#  ('Tuvalu', 2019, Decimal('0.010956')),
#  ('Tuvalu', 2020, Decimal('0.011069')),
#  ('Wallis and Futuna Islands', 2015, None),
#  ('Wallis and Futuna Islands', 2016, None),
#  ('Wallis and Futuna Islands', 2017, None),
#  ('Wallis and Futuna Islands', 2018, None),
#  ('Wallis and Futuna Islands', 2019, None),
#  ('Wallis and Futuna Islands', 2020, None),
#  ('Burundi', 2015, Decimal('10.727148')),
#  ('Burundi', 2016, Decimal('10.903327')),
#  ('Burundi', 2017, Decimal('11.155593')),
#  ('Burundi', 2018, Decimal('11.493472')),
#  ('Burundi', 2019, Decimal('11.874838')),
#  ('Burundi', 2020, Decimal('12.220227')),
#  ('Comoros', 2015, Decimal('0.730216')),
#  ('Comoros', 2016, Decimal('0.746232')),
#  ('Comoros', 2017, Decimal('0.761664')),
#  ('Comoros', 2018, Decimal('0.776313')),
#  ('Comoros', 2019, Decimal('0.790986')),
#  ('Djibouti', 2015, Decimal('1.006259')),
#  ('Djibouti', 2016, Decimal('1.023261')),
#  ('Djibouti', 2017, Decimal('1.040233')),
#  ('Djibouti', 2018, Decimal('1.057198')),
#  ('Djibouti', 2019, Decimal('1.073994')),
#  ('Djibouti', 2020, Decimal('1.090156')),
#  ('Eritrea', 2015, Decimal('3.340006')),
#  ('Eritrea', 2016, Decimal('3.365287')),
#  ('Ethiopia', 2015, Decimal('102.471895')),
#  ('Ethiopia', 2016, Decimal('105.293228')),
#  ('Ethiopia', 2017, Decimal('108.197950')),
#  ('Ethiopia', 2018, Decimal('111.129438')),
#  ('Ethiopia', 2019, Decimal('114.120594')),
#  ('Ethiopia', 2020, Decimal('117.190911')),
#  ('Kenya', 2015, Decimal('46.851488')),
#  ('Kenya', 2016, Decimal('47.894670')),
#  ('Kenya', 2017, Decimal('48.948137')),
#  ('Kenya', 2018, Decimal('49.953304')),
#  ('Kenya', 2019, Decimal('50.951450')),
#  ('Kenya', 2020, Decimal('51.985780')),
#  ('Madagascar', 2015, Decimal('24.850912')),
#  ('Madagascar', 2016, Decimal('25.501941')),
#  ('Madagascar', 2017, Decimal('26.169542')),
#  ('Madagascar', 2018, Decimal('26.846541')),
#  ('Madagascar', 2019, Decimal('27.533134')),
#  ('Madagascar', 2020, Decimal('28.225177')),
#  ('Malawi', 2015, Decimal('16.938942')),
#  ('Malawi', 2016, Decimal('17.405624')),
#  ('Malawi', 2017, Decimal('17.881167')),
#  ('Malawi', 2018, Decimal('18.367883')),
#  ('Malawi', 2019, Decimal('18.867337')),
#  ('Malawi', 2020, Decimal('19.377061')),
#  ('Mauritius', 2015, Decimal('1.262605')),
#  ('Mauritius', 2016, Decimal('1.263473')),
#  ('Mauritius', 2017, Decimal('1.264613')),
#  ('Mauritius', 2018, Decimal('1.265303')),
#  ('Mauritius', 2019, Decimal('1.265711')),
#  ('Mauritius', 2020, Decimal('1.265740')),
#  ('Mayotte', 2015, None),
#  ('Mayotte', 2016, None),
#  ('Mayotte', 2017, None),
#  ('Mayotte', 2018, None),
#  ('Mayotte', 2019, None),
#  ('Mayotte', 2020, None),
#  ('Mozambique', 2015, Decimal('26.843246')),
#  ('Mozambique', 2016, Decimal('27.696493')),
#  ('Mozambique', 2017, Decimal('28.569441')),
#  ('Mozambique', 2018, Decimal('29.423878')),
#  ('Mozambique', 2019, Decimal('30.285595')),
#  ('Mozambique', 2020, Decimal('31.178239')),
#  ('Rwanda', 2015, Decimal('11.642959')),
#  ('Rwanda', 2016, Decimal('11.930899')),
#  ('Rwanda', 2017, Decimal('12.230339')),
#  ('Rwanda', 2018, Decimal('12.531808')),
#  ('Rwanda', 2019, Decimal('12.835028')),
#  ('Rwanda', 2020, Decimal('13.146362')),
#  ('Réunion', 2015, None),
#  ('Réunion', 2016, None),
#  ('Réunion', 2017, None),
#  ('Réunion', 2018, None),
#  ('Réunion', 2019, None),
#  ('Réunion', 2020, None),
#  ('Seychelles', 2015, Decimal('0.093419')),
#  ('Seychelles', 2016, Decimal('0.094677')),
#  ('Seychelles', 2017, Decimal('0.095843')),
#  ('Seychelles', 2018, Decimal('0.096762')),
#  ('Seychelles', 2019, Decimal('0.097625')),
#  ('Somalia', 2015, Decimal('13.763906')),
#  ('Somalia', 2016, Decimal('14.292847')),
#  ('Somalia', 2017, Decimal('14.864221')),
#  ('Somalia', 2018, Decimal('15.411094')),
#  ('Somalia', 2019, Decimal('15.981300')),
#  ('Somalia', 2020, Decimal('16.537016')),
#  ('South Sudan', 2015, Decimal('11.194299')),
#  ('South Sudan', 2016, Decimal('11.066105')),
#  ('South Sudan', 2017, Decimal('10.658226')),
#  ('South Sudan', 2018, Decimal('10.395329')),
#  ('South Sudan', 2019, Decimal('10.447666')),
#  ('South Sudan', 2020, Decimal('10.606227')),
#  ('Uganda', 2015, Decimal('37.477356')),
#  ('Uganda', 2016, Decimal('38.748299')),
#  ('Uganda', 2017, Decimal('40.127085')),
#  ('Uganda', 2018, Decimal('41.515395')),
#  ('Uganda', 2019, Decimal('42.949080')),
#  ('Uganda', 2020, Decimal('44.404611')),
#  ('United Republic of Tanzania', 2015, None),
#  ('United Republic of Tanzania', 2016, None),
#  ('United Republic of Tanzania', 2017, None),
#  ('United Republic of Tanzania', 2018, None),
#  ('United Republic of Tanzania', 2019, None),
#  ('United Republic of Tanzania', 2020, None),
#  ('Zambia', 2015, Decimal('16.248230')),
#  ('Zambia', 2016, Decimal('16.767761')),
#  ('Zambia', 2017, Decimal('17.298054')),
#  ('Zambia', 2018, Decimal('17.835893')),
#  ('Zambia', 2019, Decimal('18.380477')),
#  ('Zambia', 2020, Decimal('18.927715')),
#  ('Zimbabwe', 2015, Decimal('14.154937')),
#  ('Zimbabwe', 2016, Decimal('14.452704')),
#  ('Zimbabwe', 2017, Decimal('14.751101')),
#  ('Zimbabwe', 2018, Decimal('15.052184')),
#  ('Zimbabwe', 2019, Decimal('15.354608')),
#  ('Zimbabwe', 2020, Decimal('15.669666')),
#  ('Angola', 2015, Decimal('28.127721')),
#  ('Angola', 2016, Decimal('29.154746')),
#  ('Angola', 2017, Decimal('30.208628')),
#  ('Angola', 2018, Decimal('31.273533')),
#  ('Angola', 2019, Decimal('32.353588')),
#  ('Angola', 2020, Decimal('33.428486')),
#  ('Cameroon', 2015, Decimal('23.012646')),
#  ('Cameroon', 2016, Decimal('23.711630')),
#  ('Cameroon', 2017, Decimal('24.393181')),
#  ('Cameroon', 2018, Decimal('25.076747')),
#  ('Cameroon', 2019, Decimal('25.782341')),
#  ('Cameroon', 2020, Decimal('26.491087')),
#  ('Central African Republic', 2015, Decimal('4.819333')),
#  ('Central African Republic', 2016, Decimal('4.904177')),
#  ('Central African Republic', 2017, Decimal('4.996741')),
#  ('Central African Republic', 2018, Decimal('5.094780')),
#  ('Central African Republic', 2019, Decimal('5.209324')),
#  ('Central African Republic', 2020, Decimal('5.343020')),
#  ('Chad', 2015, Decimal('14.140274')),
#  ('Chad', 2016, Decimal('14.592585')),
#  ('Chad', 2017, Decimal('15.085884')),
#  ('Chad', 2018, Decimal('15.604210')),
#  ('Chad', 2019, Decimal('16.126866')),
#  ('Chad', 2020, Decimal('16.644701')),
#  ('Congo', 2015, None),
#  ('Congo', 2016, None),
#  ('Congo', 2017, None),
#  ('Congo', 2018, None),
#  ('Congo', 2019, None),
#  ('Congo', 2020, None),
#  ('Democratic Republic of the Congo', 2015, None),
#  ('Democratic Republic of the Congo', 2016, None),
#  ('Democratic Republic of the Congo', 2017, None),
#  ('Democratic Republic of the Congo', 2018, None),
#  ('Democratic Republic of the Congo', 2019, None),
#  ('Democratic Republic of the Congo', 2020, None),
#  ('Equatorial Guinea', 2015, Decimal('1.346973')),
#  ('Equatorial Guinea', 2016, Decimal('1.398927')),
#  ('Equatorial Guinea', 2017, Decimal('1.450694')),
#  ('Gabon', 2015, Decimal('2.028517')),
#  ('Gabon', 2016, Decimal('2.086206')),
#  ('Gabon', 2017, Decimal('2.140215')),
#  ('Gabon', 2018, Decimal('2.192012')),
#  ('Gabon', 2019, Decimal('2.242785')),
#  ('Gabon', 2020, Decimal('2.292573')),
#  ('Sao Tome and Principe', 2015, Decimal('0.201124')),
#  ('Sao Tome and Principe', 2016, Decimal('0.204632')),
#  ('Sao Tome and Principe', 2017, Decimal('0.208036')),
#  ('Sao Tome and Principe', 2018, Decimal('0.211344')),
#  ('Sao Tome and Principe', 2019, Decimal('0.214599')),
#  ('Sao Tome and Principe', 2020, Decimal('0.218641')),
#  ('Botswana', 2015, Decimal('2.305171')),
#  ('Botswana', 2016, Decimal('2.352416')),
#  ('Botswana', 2017, Decimal('2.401840')),
#  ('Botswana', 2018, Decimal('2.451409')),
#  ('Botswana', 2019, Decimal('2.499702')),
#  ('Botswana', 2020, Decimal('2.546402')),
#  ('Eswatini', 2015, Decimal('1.133936')),
#  ('Eswatini', 2016, Decimal('1.142524')),
#  ('Eswatini', 2017, Decimal('1.151390')),
#  ('Eswatini', 2018, Decimal('1.160428')),
#  ('Eswatini', 2019, Decimal('1.169613')),
#  ('Eswatini', 2020, Decimal('1.180655')),
#  ('Lesotho', 2015, Decimal('2.118521')),
#  ('Lesotho', 2016, Decimal('2.143872')),
#  ('Lesotho', 2017, Decimal('2.170617')),
#  ('Lesotho', 2018, Decimal('2.198017')),
#  ('Lesotho', 2019, Decimal('2.225702')),
#  ('Lesotho', 2020, Decimal('2.254100')),
#  ('Namibia', 2015, Decimal('2.282704')),
#  ('Namibia', 2016, Decimal('2.323352')),
#  ('Namibia', 2017, Decimal('2.364534')),
#  ('Namibia', 2018, Decimal('2.405680')),
#  ('Namibia', 2019, Decimal('2.446644')),
#  ('Namibia', 2020, Decimal('2.489098')),
#  ('South Africa', 2015, Decimal('55.876504')),
#  ('South Africa', 2016, Decimal('56.422274')),
#  ('South Africa', 2017, Decimal('56.641209')),
#  ('South Africa', 2018, Decimal('57.339635')),
#  ('South Africa', 2019, Decimal('58.087055')),
#  ('South Africa', 2020, Decimal('58.801927')),
#  ('Benin', 2015, Decimal('10.932783')),
#  ('Benin', 2016, Decimal('11.260085')),
#  ('Benin', 2017, Decimal('11.596779')),
#  ('Benin', 2018, Decimal('11.940683')),
#  ('Benin', 2019, Decimal('12.290444')),
#  ('Benin', 2020, Decimal('12.643123')),
#  ('Burkina Faso', 2015, Decimal('18.718019')),
#  ('Burkina Faso', 2016, Decimal('19.275498')),
#  ('Burkina Faso', 2017, Decimal('19.835858')),
#  ('Burkina Faso', 2018, Decimal('20.392723')),
#  ('Burkina Faso', 2019, Decimal('20.951639')),
#  ('Burkina Faso', 2020, Decimal('21.522626')),
#  ('Cabo Verde', 2015, Decimal('0.552166')),
#  ('Cabo Verde', 2016, Decimal('0.558394')),
#  ('Cabo Verde', 2017, Decimal('0.564954')),
#  ('Cabo Verde', 2018, Decimal('0.571202')),
#  ('Cabo Verde', 2019, Decimal('0.577030')),
#  ('Cabo Verde', 2020, Decimal('0.582640')),
#  ("Côte d'Ivoire", 2015, None),
#  ("Côte d'Ivoire", 2016, None),
#  ("Côte d'Ivoire", 2017, None),
#  ("Côte d'Ivoire", 2018, None),
#  ("Côte d'Ivoire", 2019, None),
#  ("Côte d'Ivoire", 2020, None),
#  ('Gambia', 2015, None),
#  ('Gambia', 2016, None),
#  ('Gambia', 2017, None),
#  ('Gambia', 2018, None),
#  ('Gambia', 2019, None),
#  ('Gambia', 2020, None),
#  ('Ghana', 2015, Decimal('28.870939')),
#  ('Ghana', 2016, Decimal('29.554303')),
#  ('Ghana', 2017, Decimal('30.222262')),
#  ('Ghana', 2018, Decimal('30.870641')),
#  ('Ghana', 2019, Decimal('31.522290')),
#  ('Ghana', 2020, Decimal('32.180401')),
#  ('Guinea', 2015, Decimal('11.625998')),
#  ('Guinea', 2016, Decimal('11.930985')),
#  ('Guinea', 2017, Decimal('12.240789')),
#  ('Guinea', 2018, Decimal('12.554864')),
#  ('Guinea', 2019, Decimal('12.877539')),
#  ('Guinea', 2020, Decimal('13.205153')),
#  ('Guinea-Bissau', 2015, Decimal('1.788919')),
#  ('Guinea-Bissau', 2016, Decimal('1.834552')),
#  ('Guinea-Bissau', 2017, Decimal('1.879826')),
#  ('Guinea-Bissau', 2018, Decimal('1.924955')),
#  ('Guinea-Bissau', 2019, Decimal('1.970457')),
#  ('Guinea-Bissau', 2020, Decimal('2.015828')),
#  ('Liberia', 2015, Decimal('4.612329')),
#  ('Liberia', 2016, Decimal('4.706097')),
#  ('Liberia', 2017, Decimal('4.796631')),
#  ('Liberia', 2018, Decimal('4.889391')),
#  ('Liberia', 2019, Decimal('4.985289')),
#  ('Liberia', 2020, Decimal('5.087584')),
#  ...]

# %% [markdown]
# ### 1. Determine the appropriate precision

# %% [markdown]
# Looking at `Est_population_in_millions`, it has been given the `DECIMAL(11,6)` numeric data type, which has a **precision of 11** and a **scale of 6**. This means that the number can have a total of 11 digits, with 6 digits allowed after the decimal point.
#
# This makes the values too long and hard to read.
#
# Instead, we can alter its data type such that it is retrieved with **only 2 decimal values** to improve readability and efficiency.

# %% [markdown]
# We know we want to give a scale of 2, but what about the precision?
# We can find the maximum value in the estimated population column, which we can then use to help us determine the most appropriate precision for the column.

# %%
# %%sql
# SELECT
#     Country_name,
#     Time_period,
#     Est_population_in_millions,
#     CAST(Est_population_in_millions AS DECIMAL(6,2)) AS new_est_pop
# FROM
#     united_nations.Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1048 rows affected.
# [('Kazakhstan', 2015, Decimal('17.542806'), Decimal('17.54')),
#  ('Kazakhstan', 2016, Decimal('17.794055'), Decimal('17.79')),
#  ('Kazakhstan', 2017, Decimal('18.037776'), Decimal('18.04')),
#  ('Kazakhstan', 2018, Decimal('18.276452'), Decimal('18.28')),
#  ('Kazakhstan', 2019, Decimal('18.513673'), Decimal('18.51')),
#  ('Kazakhstan', 2020, Decimal('18.755666'), Decimal('18.76')),
#  ('Kyrgyzstan', 2015, None, None),
#  ('Kyrgyzstan', 2016, None, None),
#  ('Kyrgyzstan', 2017, None, None),
#  ('Kyrgyzstan', 2018, None, None),
#  ('Kyrgyzstan', 2019, None, None),
#  ('Kyrgyzstan', 2020, None, None),
#  ('Tajikistan', 2015, Decimal('8.524063'), Decimal('8.52')),
#  ('Tajikistan', 2016, Decimal('8.725318'), Decimal('8.73')),
#  ('Tajikistan', 2017, Decimal('8.925525'), Decimal('8.93')),
#  ('Tajikistan', 2018, Decimal('9.128132'), Decimal('9.13')),
#  ('Tajikistan', 2019, Decimal('9.337003'), Decimal('9.34')),
#  ('Tajikistan', 2020, Decimal('9.543207'), Decimal('9.54')),
#  ('Turkmenistan', 2015, Decimal('5.766431'), Decimal('5.77')),
#  ('Turkmenistan', 2016, Decimal('5.868561'), Decimal('5.87')),
#  ('Turkmenistan', 2017, Decimal('5.968383'), Decimal('5.97')),
#  ('Turkmenistan', 2018, Decimal('6.065066'), Decimal('6.07')),
#  ('Turkmenistan', 2019, Decimal('6.158420'), Decimal('6.16')),
#  ('Turkmenistan', 2020, Decimal('6.250438'), Decimal('6.25')),
#  ('Uzbekistan', 2015, Decimal('31.298900'), Decimal('31.30')),
#  ('Uzbekistan', 2016, Decimal('31.847900'), Decimal('31.85')),
#  ('Uzbekistan', 2017, Decimal('32.388600'), Decimal('32.39')),
#  ('Uzbekistan', 2018, Decimal('32.956100'), Decimal('32.96')),
#  ('Uzbekistan', 2019, Decimal('33.580350'), Decimal('33.58')),
#  ('Uzbekistan', 2020, Decimal('34.232050'), Decimal('34.23')),
#  ('Afghanistan', 2015, Decimal('33.753499'), Decimal('33.75')),
#  ('Afghanistan', 2016, Decimal('34.636207'), Decimal('34.64')),
#  ('Afghanistan', 2017, Decimal('35.643418'), Decimal('35.64')),
#  ('Afghanistan', 2018, Decimal('36.686784'), Decimal('36.69')),
#  ('Afghanistan', 2019, Decimal('37.769499'), Decimal('37.77')),
#  ('Afghanistan', 2020, Decimal('38.972230'), Decimal('38.97')),
#  ('Bangladesh', 2015, Decimal('157.830000'), Decimal('157.83')),
#  ('Bangladesh', 2016, Decimal('159.784568'), Decimal('159.78')),
#  ('Bangladesh', 2017, Decimal('161.793964'), Decimal('161.79')),
#  ('Bangladesh', 2018, Decimal('163.683958'), Decimal('163.68')),
#  ('Bangladesh', 2019, Decimal('165.516222'), Decimal('165.52')),
#  ('Bangladesh', 2020, Decimal('167.420951'), Decimal('167.42')),
#  ('Bhutan', 2015, Decimal('0.743274'), Decimal('0.74')),
#  ('Bhutan', 2016, Decimal('0.749761'), Decimal('0.75')),
#  ('Bhutan', 2017, Decimal('0.756121'), Decimal('0.76')),
#  ('Bhutan', 2018, Decimal('0.762096'), Decimal('0.76')),
#  ('Bhutan', 2019, Decimal('0.767459'), Decimal('0.77')),
#  ('Bhutan', 2020, Decimal('0.772506'), Decimal('0.77')),
#  ('India', 2015, Decimal('1322.866505'), Decimal('1322.87')),
#  ('India', 2016, Decimal('1338.636340'), Decimal('1338.64')),
#  ('India', 2017, Decimal('1354.195680'), Decimal('1354.20')),
#  ('India', 2018, Decimal('1369.003306'), Decimal('1369.00')),
#  ('India', 2019, Decimal('1383.112050'), Decimal('1383.11')),
#  ('India', 2020, Decimal('1396.387127'), Decimal('1396.39')),
#  ('Iran (Islamic Republic of)', 2015, None, None),
#  ('Iran (Islamic Republic of)', 2016, None, None),
#  ('Iran (Islamic Republic of)', 2017, None, None),
#  ('Iran (Islamic Republic of)', 2018, None, None),
#  ('Iran (Islamic Republic of)', 2019, None, None),
#  ('Iran (Islamic Republic of)', 2020, None, None),
#  ('Maldives', 2015, Decimal('0.435582'), Decimal('0.44')),
#  ('Maldives', 2016, Decimal('0.454252'), Decimal('0.45')),
#  ('Maldives', 2017, Decimal('0.472442'), Decimal('0.47')),
#  ('Maldives', 2018, Decimal('0.489758'), Decimal('0.49')),
#  ('Maldives', 2019, Decimal('0.504508'), Decimal('0.50')),
#  ('Maldives', 2020, Decimal('0.514438'), Decimal('0.51')),
#  ('Nepal', 2015, Decimal('27.610325'), Decimal('27.61')),
#  ('Nepal', 2016, Decimal('27.861186'), Decimal('27.86')),
#  ('Nepal', 2017, Decimal('28.183426'), Decimal('28.18')),
#  ('Nepal', 2018, Decimal('28.506712'), Decimal('28.51')),
#  ('Nepal', 2019, Decimal('28.832496'), Decimal('28.83')),
#  ('Nepal', 2020, Decimal('29.348627'), Decimal('29.35')),
#  ('Pakistan', 2015, Decimal('210.969298'), Decimal('210.97')),
#  ('Pakistan', 2016, Decimal('213.524840'), Decimal('213.52')),
#  ('Pakistan', 2017, Decimal('216.379655'), Decimal('216.38')),
#  ('Pakistan', 2018, Decimal('219.731479'), Decimal('219.73')),
#  ('Pakistan', 2019, Decimal('223.293280'), Decimal('223.29')),
#  ('Pakistan', 2020, Decimal('227.196741'), Decimal('227.20')),
#  ('Sri Lanka', 2015, Decimal('20.970000'), Decimal('20.97')),
#  ('Sri Lanka', 2016, Decimal('21.203000'), Decimal('21.20')),
#  ('Sri Lanka', 2017, Decimal('21.444000'), Decimal('21.44')),
#  ('Sri Lanka', 2018, Decimal('21.670000'), Decimal('21.67')),
#  ('Sri Lanka', 2019, Decimal('21.803000'), Decimal('21.80')),
#  ('Sri Lanka', 2020, Decimal('21.919000'), Decimal('21.92')),
#  ('China', 2015, Decimal('1379.860000'), Decimal('1379.86')),
#  ('China', 2016, Decimal('1387.790000'), Decimal('1387.79')),
#  ('China', 2017, Decimal('1396.215000'), Decimal('1396.22')),
#  ('China', 2018, Decimal('1402.760000'), Decimal('1402.76')),
#  ('China', 2019, Decimal('1407.745000'), Decimal('1407.75')),
#  ('China', 2020, Decimal('1411.100000'), Decimal('1411.10')),
#  ("Democratic People's Republic of Korea", 2015, None, None),
#  ("Democratic People's Republic of Korea", 2016, None, None),
#  ("Democratic People's Republic of Korea", 2017, None, None),
#  ("Democratic People's Republic of Korea", 2018, None, None),
#  ("Democratic People's Republic of Korea", 2019, None, None),
#  ("Democratic People's Republic of Korea", 2020, None, None),
#  ('Japan', 2015, Decimal('127.141000'), Decimal('127.14')),
#  ('Japan', 2016, Decimal('127.076000'), Decimal('127.08')),
#  ('Japan', 2017, Decimal('126.972000'), Decimal('126.97')),
#  ('Japan', 2018, Decimal('126.811000'), Decimal('126.81')),
#  ('Japan', 2019, Decimal('126.633000'), Decimal('126.63')),
#  ('Japan', 2020, Decimal('126.261000'), Decimal('126.26')),
#  ('Mongolia', 2015, Decimal('2.964749'), Decimal('2.96')),
#  ('Mongolia', 2016, Decimal('3.029555'), Decimal('3.03')),
#  ('Mongolia', 2017, Decimal('3.096030'), Decimal('3.10')),
#  ('Mongolia', 2018, Decimal('3.163991'), Decimal('3.16')),
#  ('Mongolia', 2019, Decimal('3.232430'), Decimal('3.23')),
#  ('Mongolia', 2020, Decimal('3.294335'), Decimal('3.29')),
#  ('Republic of Korea', 2015, None, None),
#  ('Republic of Korea', 2016, None, None),
#  ('Republic of Korea', 2017, None, None),
#  ('Republic of Korea', 2018, None, None),
#  ('Republic of Korea', 2019, None, None),
#  ('Republic of Korea', 2020, None, None),
#  ('Brunei Darussalam', 2015, Decimal('0.421437'), Decimal('0.42')),
#  ('Brunei Darussalam', 2016, Decimal('0.425994'), Decimal('0.43')),
#  ('Brunei Darussalam', 2017, Decimal('0.430276'), Decimal('0.43')),
#  ('Brunei Darussalam', 2018, Decimal('0.434274'), Decimal('0.43')),
#  ('Brunei Darussalam', 2019, Decimal('0.438048'), Decimal('0.44')),
#  ('Brunei Darussalam', 2020, Decimal('0.441725'), Decimal('0.44')),
#  ('Cambodia', 2015, Decimal('15.417523'), Decimal('15.42')),
#  ('Cambodia', 2016, Decimal('15.624584'), Decimal('15.62')),
#  ('Cambodia', 2017, Decimal('15.830689'), Decimal('15.83')),
#  ('Cambodia', 2018, Decimal('16.025238'), Decimal('16.03')),
#  ('Cambodia', 2019, Decimal('16.207746'), Decimal('16.21')),
#  ('Cambodia', 2020, Decimal('16.396860'), Decimal('16.40')),
#  ('Indonesia', 2015, Decimal('259.091970'), Decimal('259.09')),
#  ('Indonesia', 2016, Decimal('261.850182'), Decimal('261.85')),
#  ('Indonesia', 2017, Decimal('264.498852'), Decimal('264.50')),
#  ('Indonesia', 2018, Decimal('267.066843'), Decimal('267.07')),
#  ('Indonesia', 2019, Decimal('269.582878'), Decimal('269.58')),
#  ('Indonesia', 2020, Decimal('271.857970'), Decimal('271.86')),
#  ("Lao People's Democratic Republic", 2015, None, None),
#  ("Lao People's Democratic Republic", 2016, None, None),
#  ("Lao People's Democratic Republic", 2017, None, None),
#  ("Lao People's Democratic Republic", 2018, None, None),
#  ("Lao People's Democratic Republic", 2019, None, None),
#  ("Lao People's Democratic Republic", 2020, None, None),
#  ('Malaysia', 2015, Decimal('31.068833'), Decimal('31.07')),
#  ('Malaysia', 2016, Decimal('31.526418'), Decimal('31.53')),
#  ('Malaysia', 2017, Decimal('31.975806'), Decimal('31.98')),
#  ('Malaysia', 2018, Decimal('32.399271'), Decimal('32.40')),
#  ('Malaysia', 2019, Decimal('32.804020'), Decimal('32.80')),
#  ('Malaysia', 2020, Decimal('33.199993'), Decimal('33.20')),
#  ('Myanmar', 2015, Decimal('51.483949'), Decimal('51.48')),
#  ('Myanmar', 2016, Decimal('51.892349'), Decimal('51.89')),
#  ('Myanmar', 2017, Decimal('52.288341'), Decimal('52.29')),
#  ('Myanmar', 2018, Decimal('52.666014'), Decimal('52.67')),
#  ('Myanmar', 2019, Decimal('53.040212'), Decimal('53.04')),
#  ('Myanmar', 2020, Decimal('53.423198'), Decimal('53.42')),
#  ('Philippines', 2015, Decimal('103.031365'), Decimal('103.03')),
#  ('Philippines', 2016, Decimal('104.875266'), Decimal('104.88')),
#  ('Philippines', 2017, Decimal('106.738501'), Decimal('106.74')),
#  ('Philippines', 2018, Decimal('108.568836'), Decimal('108.57')),
#  ('Philippines', 2019, Decimal('110.380804'), Decimal('110.38')),
#  ('Philippines', 2020, Decimal('112.190977'), Decimal('112.19')),
#  ('Singapore', 2015, Decimal('5.535002'), Decimal('5.54')),
#  ('Singapore', 2016, Decimal('5.607283'), Decimal('5.61')),
#  ('Singapore', 2017, Decimal('5.612253'), Decimal('5.61')),
#  ('Singapore', 2018, Decimal('5.638676'), Decimal('5.64')),
#  ('Singapore', 2019, Decimal('5.703569'), Decimal('5.70')),
#  ('Singapore', 2020, Decimal('5.685807'), Decimal('5.69')),
#  ('Thailand', 2015, Decimal('70.294397'), Decimal('70.29')),
#  ('Thailand', 2016, Decimal('70.607037'), Decimal('70.61')),
#  ('Thailand', 2017, Decimal('70.898202'), Decimal('70.90')),
#  ('Thailand', 2018, Decimal('71.127802'), Decimal('71.13')),
#  ('Thailand', 2019, Decimal('71.307763'), Decimal('71.31')),
#  ('Thailand', 2020, Decimal('71.475664'), Decimal('71.48')),
#  ('Timor-Leste', 2015, Decimal('1.205813'), Decimal('1.21')),
#  ('Timor-Leste', 2016, Decimal('1.224562'), Decimal('1.22')),
#  ('Timor-Leste', 2017, Decimal('1.243235'), Decimal('1.24')),
#  ('Timor-Leste', 2018, Decimal('1.261845'), Decimal('1.26')),
#  ('Timor-Leste', 2019, Decimal('1.280438'), Decimal('1.28')),
#  ('Timor-Leste', 2020, Decimal('1.299995'), Decimal('1.30')),
#  ('Viet Nam', 2015, None, None),
#  ('Viet Nam', 2016, None, None),
#  ('Viet Nam', 2017, None, None),
#  ('Viet Nam', 2018, None, None),
#  ('Viet Nam', 2019, None, None),
#  ('Viet Nam', 2020, None, None),
#  ('Bermuda', 2015, Decimal('0.065237'), Decimal('0.07')),
#  ('Bermuda', 2016, Decimal('0.064554'), Decimal('0.06')),
#  ('Bermuda', 2017, Decimal('0.063873'), Decimal('0.06')),
#  ('Bermuda', 2018, Decimal('0.063918'), Decimal('0.06')),
#  ('Bermuda', 2019, Decimal('0.063911'), Decimal('0.06')),
#  ('Bermuda', 2020, Decimal('0.063893'), Decimal('0.06')),
#  ('Canada', 2015, Decimal('35.702908'), Decimal('35.70')),
#  ('Canada', 2016, Decimal('36.109487'), Decimal('36.11')),
#  ('Canada', 2017, Decimal('36.545236'), Decimal('36.55')),
#  ('Canada', 2018, Decimal('37.065084'), Decimal('37.07')),
#  ('Canada', 2019, Decimal('37.601230'), Decimal('37.60')),
#  ('Canada', 2020, Decimal('38.037204'), Decimal('38.04')),
#  ('Greenland', 2015, Decimal('0.056114'), Decimal('0.06')),
#  ('Greenland', 2016, Decimal('0.056186'), Decimal('0.06')),
#  ('Greenland', 2017, Decimal('0.056171'), Decimal('0.06')),
#  ('Greenland', 2018, Decimal('0.056023'), Decimal('0.06')),
#  ('Greenland', 2019, Decimal('0.056225'), Decimal('0.06')),
#  ('Greenland', 2020, Decimal('0.056367'), Decimal('0.06')),
#  ('Saint Pierre and Miquelon', 2015, None, None),
#  ('Saint Pierre and Miquelon', 2016, None, None),
#  ('Saint Pierre and Miquelon', 2017, None, None),
#  ('Saint Pierre and Miquelon', 2018, None, None),
#  ('Saint Pierre and Miquelon', 2019, None, None),
#  ('Saint Pierre and Miquelon', 2020, None, None),
#  ('United States of America', 2015, None, None),
#  ('United States of America', 2016, None, None),
#  ('United States of America', 2017, None, None),
#  ('United States of America', 2018, None, None),
#  ('United States of America', 2019, None, None),
#  ('United States of America', 2020, None, None),
#  ('Anguilla', 2015, None, None),
#  ('Anguilla', 2016, None, None),
#  ('Anguilla', 2017, None, None),
#  ('Antigua and Barbuda', 2015, Decimal('0.089941'), Decimal('0.09')),
#  ('Antigua and Barbuda', 2016, Decimal('0.090564'), Decimal('0.09')),
#  ('Antigua and Barbuda', 2017, Decimal('0.091119'), Decimal('0.09')),
#  ('Aruba', 2015, Decimal('0.104257'), Decimal('0.10')),
#  ('Aruba', 2016, Decimal('0.104874'), Decimal('0.10')),
#  ('Bahamas', 2015, None, None),
#  ('Bahamas', 2016, None, None),
#  ('Bahamas', 2017, None, None),
#  ('Bahamas', 2018, None, None),
#  ('Bahamas', 2019, None, None),
#  ('Barbados', 2015, Decimal('0.278083'), Decimal('0.28')),
#  ('Barbados', 2016, Decimal('0.278649'), Decimal('0.28')),
#  ('Barbados', 2017, Decimal('0.279187'), Decimal('0.28')),
#  ('Barbados', 2018, Decimal('0.279688'), Decimal('0.28')),
#  ('Barbados', 2019, Decimal('0.280180'), Decimal('0.28')),
#  ('Barbados', 2020, Decimal('0.280693'), Decimal('0.28')),
#  ('British Virgin Islands', 2015, Decimal('0.029366'), Decimal('0.03')),
#  ('British Virgin Islands', 2016, Decimal('0.029739'), Decimal('0.03')),
#  ('British Virgin Islands', 2017, Decimal('0.030060'), Decimal('0.03')),
#  ('British Virgin Islands', 2018, Decimal('0.030335'), Decimal('0.03')),
#  ('British Virgin Islands', 2019, Decimal('0.030610'), Decimal('0.03')),
#  ('British Virgin Islands', 2020, Decimal('0.030910'), Decimal('0.03')),
#  ('Cayman Islands', 2015, Decimal('0.060911'), Decimal('0.06')),
#  ('Cayman Islands', 2016, Decimal('0.062255'), Decimal('0.06')),
#  ('Cuba', 2015, Decimal('11.339894'), Decimal('11.34')),
#  ('Cuba', 2016, Decimal('11.342012'), Decimal('11.34')),
#  ('Cuba', 2017, Decimal('11.336405'), Decimal('11.34')),
#  ('Cuba', 2018, Decimal('11.328244'), Decimal('11.33')),
#  ('Cuba', 2019, Decimal('11.316697'), Decimal('11.32')),
#  ('Cuba', 2020, Decimal('11.300698'), Decimal('11.30')),
#  ('Curaçao', 2015, None, None),
#  ('Curaçao', 2016, None, None),
#  ('Curaçao', 2017, None, None),
#  ('Dominica', 2015, Decimal('0.070007'), Decimal('0.07')),
#  ('Dominica', 2016, Decimal('0.070075'), Decimal('0.07')),
#  ('Dominica', 2017, Decimal('0.070403'), Decimal('0.07')),
#  ('Dominican Republic', 2015, Decimal('10.405832'), Decimal('10.41')),
#  ('Dominican Republic', 2016, Decimal('10.527592'), Decimal('10.53')),
#  ('Dominican Republic', 2017, Decimal('10.647244'), Decimal('10.65')),
#  ('Dominican Republic', 2018, Decimal('10.765531'), Decimal('10.77')),
#  ('Dominican Republic', 2019, Decimal('10.881882'), Decimal('10.88')),
#  ('Dominican Republic', 2020, Decimal('10.999664'), Decimal('11.00')),
#  ('Grenada', 2015, Decimal('0.118980'), Decimal('0.12')),
#  ('Grenada', 2016, Decimal('0.119966'), Decimal('0.12')),
#  ('Grenada', 2017, Decimal('0.120921'), Decimal('0.12')),
#  ('Guadeloupe', 2015, None, None),
#  ('Guadeloupe', 2016, None, None),
#  ('Guadeloupe', 2017, None, None),
#  ('Guadeloupe', 2018, None, None),
#  ('Guadeloupe', 2019, None, None),
#  ('Guadeloupe', 2020, None, None),
#  ('Haiti', 2015, Decimal('10.563757'), Decimal('10.56')),
#  ('Haiti', 2016, Decimal('10.713849'), Decimal('10.71')),
#  ('Haiti', 2017, Decimal('10.863543'), Decimal('10.86')),
#  ('Haiti', 2018, Decimal('11.012421'), Decimal('11.01')),
#  ('Haiti', 2019, Decimal('11.160438'), Decimal('11.16')),
#  ('Haiti', 2020, Decimal('11.306801'), Decimal('11.31')),
#  ('Jamaica', 2015, Decimal('2.794445'), Decimal('2.79')),
#  ('Jamaica', 2016, Decimal('2.802695'), Decimal('2.80')),
#  ('Jamaica', 2017, Decimal('2.808376'), Decimal('2.81')),
#  ('Jamaica', 2018, Decimal('2.811835'), Decimal('2.81')),
#  ('Jamaica', 2019, Decimal('2.813773'), Decimal('2.81')),
#  ('Jamaica', 2020, Decimal('2.820436'), Decimal('2.82')),
#  ('Martinique', 2015, None, None),
#  ('Martinique', 2016, None, None),
#  ('Martinique', 2017, None, None),
#  ('Martinique', 2018, None, None),
#  ('Martinique', 2019, None, None),
#  ('Martinique', 2020, None, None),
#  ('Montserrat', 2015, None, None),
#  ('Montserrat', 2016, None, None),
#  ('Montserrat', 2017, None, None),
#  ('Montserrat', 2018, None, None),
#  ('Montserrat', 2019, None, None),
#  ('Montserrat', 2020, None, None),
#  ('Puerto Rico', 2015, Decimal('3.473232'), Decimal('3.47')),
#  ('Puerto Rico', 2016, Decimal('3.406672'), Decimal('3.41')),
#  ('Puerto Rico', 2017, Decimal('3.325286'), Decimal('3.33')),
#  ('Puerto Rico', 2018, Decimal('3.193354'), Decimal('3.19')),
#  ('Puerto Rico', 2019, Decimal('3.193694'), Decimal('3.19')),
#  ('Puerto Rico', 2020, Decimal('3.281538'), Decimal('3.28')),
#  ('Saint Barthélemy', 2015, None, None),
#  ('Saint Barthélemy', 2016, None, None),
#  ('Saint Barthélemy', 2017, None, None),
#  ('Saint Barthélemy', 2018, None, None),
#  ('Saint Barthélemy', 2019, None, None),
#  ('Saint Barthélemy', 2020, None, None),
#  ('Saint Kitts and Nevis', 2015, None, None),
#  ('Saint Kitts and Nevis', 2016, None, None),
#  ('Saint Kitts and Nevis', 2017, None, None),
#  ('Saint Lucia', 2015, None, None),
#  ('Saint Lucia', 2016, None, None),
#  ('Saint Lucia', 2017, None, None),
#  ('Saint Lucia', 2018, None, None),
#  ('Saint Lucia', 2019, None, None),
#  ('Saint Lucia', 2020, None, None),
#  ('Saint Martin (French Part)', 2015, None, None),
#  ('Saint Martin (French Part)', 2016, None, None),
#  ('Saint Martin (French Part)', 2017, None, None),
#  ('Saint Martin (French Part)', 2018, None, None),
#  ('Saint Martin (French Part)', 2019, None, None),
#  ('Saint Martin (French Part)', 2020, None, None),
#  ('Saint Vincent and the Grenadines', 2015, None, None),
#  ('Saint Vincent and the Grenadines', 2016, None, None),
#  ('Saint Vincent and the Grenadines', 2017, None, None),
#  ('Saint Vincent and the Grenadines', 2018, None, None),
#  ('Sint Maarten (Dutch part)', 2015, Decimal('0.038825'), Decimal('0.04')),
#  ('Sint Maarten (Dutch part)', 2016, Decimal('0.039969'), Decimal('0.04')),
#  ('Sint Maarten (Dutch part)', 2017, Decimal('0.040574'), Decimal('0.04')),
#  ('Trinidad and Tobago', 2015, Decimal('1.460177'), Decimal('1.46')),
#  ('Trinidad and Tobago', 2016, Decimal('1.469330'), Decimal('1.47')),
#  ('Trinidad and Tobago', 2017, Decimal('1.478607'), Decimal('1.48')),
#  ('Trinidad and Tobago', 2018, Decimal('1.504709'), Decimal('1.50')),
#  ('Trinidad and Tobago', 2019, Decimal('1.519955'), Decimal('1.52')),
#  ('Trinidad and Tobago', 2020, Decimal('1.518147'), Decimal('1.52')),
#  ('Turks and Caicos Islands', 2015, Decimal('0.036538'), Decimal('0.04')),
#  ('Turks and Caicos Islands', 2016, Decimal('0.038246'), Decimal('0.04')),
#  ('Turks and Caicos Islands', 2017, Decimal('0.039844'), Decimal('0.04')),
#  ('Turks and Caicos Islands', 2018, Decimal('0.041487'), Decimal('0.04')),
#  ('United States Virgin Islands', 2015, None, None),
#  ('United States Virgin Islands', 2016, None, None),
#  ('United States Virgin Islands', 2017, None, None),
#  ('United States Virgin Islands', 2018, None, None),
#  ('United States Virgin Islands', 2019, None, None),
#  ('United States Virgin Islands', 2020, None, None),
#  ('Belize', 2015, Decimal('0.359871'), Decimal('0.36')),
#  ('Belize', 2016, Decimal('0.367313'), Decimal('0.37')),
#  ('Belize', 2017, Decimal('0.374693'), Decimal('0.37')),
#  ('Belize', 2018, Decimal('0.382066'), Decimal('0.38')),
#  ('Belize', 2019, Decimal('0.389095'), Decimal('0.39')),
#  ('Belize', 2020, Decimal('0.394921'), Decimal('0.39')),
#  ('Costa Rica', 2015, Decimal('4.895242'), Decimal('4.90')),
#  ('Costa Rica', 2016, Decimal('4.945205'), Decimal('4.95')),
#  ('Costa Rica', 2017, Decimal('4.993842'), Decimal('4.99')),
#  ('Costa Rica', 2018, Decimal('5.040734'), Decimal('5.04')),
#  ('Costa Rica', 2019, Decimal('5.084532'), Decimal('5.08')),
#  ('Costa Rica', 2020, Decimal('5.123105'), Decimal('5.12')),
#  ('El Salvador', 2015, Decimal('6.231066'), Decimal('6.23')),
#  ('El Salvador', 2016, Decimal('6.250510'), Decimal('6.25')),
#  ('El Salvador', 2017, Decimal('6.266654'), Decimal('6.27')),
#  ('El Salvador', 2018, Decimal('6.276342'), Decimal('6.28')),
#  ('El Salvador', 2019, Decimal('6.280217'), Decimal('6.28')),
#  ('El Salvador', 2020, Decimal('6.292731'), Decimal('6.29')),
#  ('Guatemala', 2015, Decimal('15.567419'), Decimal('15.57')),
#  ('Guatemala', 2016, Decimal('15.827690'), Decimal('15.83')),
#  ('Guatemala', 2017, Decimal('16.087418'), Decimal('16.09')),
#  ('Guatemala', 2018, Decimal('16.346950'), Decimal('16.35')),
#  ('Guatemala', 2019, Decimal('16.604026'), Decimal('16.60')),
#  ('Guatemala', 2020, Decimal('16.858333'), Decimal('16.86')),
#  ('Honduras', 2015, Decimal('9.294505'), Decimal('9.29')),
#  ('Honduras', 2016, Decimal('9.460798'), Decimal('9.46')),
#  ('Honduras', 2017, Decimal('9.626842'), Decimal('9.63')),
#  ('Honduras', 2018, Decimal('9.792850'), Decimal('9.79')),
#  ('Honduras', 2019, Decimal('9.958829'), Decimal('9.96')),
#  ('Honduras', 2020, Decimal('10.121763'), Decimal('10.12')),
#  ('Mexico', 2015, Decimal('120.149897'), Decimal('120.15')),
#  ('Mexico', 2016, Decimal('121.519221'), Decimal('121.52')),
#  ('Mexico', 2017, Decimal('122.839258'), Decimal('122.84')),
#  ('Mexico', 2018, Decimal('124.013861'), Decimal('124.01')),
#  ('Mexico', 2019, Decimal('125.085311'), Decimal('125.09')),
#  ('Mexico', 2020, Decimal('125.998302'), Decimal('126.00')),
#  ('Nicaragua', 2015, Decimal('6.298598'), Decimal('6.30')),
#  ('Nicaragua', 2016, Decimal('6.389235'), Decimal('6.39')),
#  ('Nicaragua', 2017, Decimal('6.480532'), Decimal('6.48')),
#  ('Nicaragua', 2018, Decimal('6.572233'), Decimal('6.57')),
#  ('Nicaragua', 2019, Decimal('6.663924'), Decimal('6.66')),
#  ('Nicaragua', 2020, Decimal('6.755895'), Decimal('6.76')),
#  ('Panama', 2015, Decimal('3.957099'), Decimal('3.96')),
#  ('Panama', 2016, Decimal('4.026336'), Decimal('4.03')),
#  ('Panama', 2017, Decimal('4.096063'), Decimal('4.10')),
#  ('Panama', 2018, Decimal('4.165255'), Decimal('4.17')),
#  ('Panama', 2019, Decimal('4.232532'), Decimal('4.23')),
#  ('Panama', 2020, Decimal('4.294396'), Decimal('4.29')),
#  ('Argentina', 2015, Decimal('43.131966'), Decimal('43.13')),
#  ('Argentina', 2016, Decimal('43.590368'), Decimal('43.59')),
#  ('Argentina', 2017, Decimal('44.044811'), Decimal('44.04')),
#  ('Argentina', 2018, Decimal('44.494502'), Decimal('44.49')),
#  ('Argentina', 2019, Decimal('44.938712'), Decimal('44.94')),
#  ('Argentina', 2020, Decimal('45.376763'), Decimal('45.38')),
#  ('Bolivia (Plurinational State of)', 2015, None, None),
#  ('Bolivia (Plurinational State of)', 2016, None, None),
#  ('Bolivia (Plurinational State of)', 2017, None, None),
#  ('Bolivia (Plurinational State of)', 2018, None, None),
#  ('Bolivia (Plurinational State of)', 2019, None, None),
#  ('Bolivia (Plurinational State of)', 2020, None, None),
#  ('Brazil', 2015, Decimal('205.188205'), Decimal('205.19')),
#  ('Brazil', 2016, Decimal('206.859578'), Decimal('206.86')),
#  ('Brazil', 2017, Decimal('208.504960'), Decimal('208.50')),
#  ('Brazil', 2018, Decimal('210.166592'), Decimal('210.17')),
#  ('Brazil', 2019, Decimal('211.782878'), Decimal('211.78')),
#  ('Brazil', 2020, Decimal('213.196304'), Decimal('213.20')),
#  ('Chile', 2015, Decimal('17.870124'), Decimal('17.87')),
#  ('Chile', 2016, Decimal('18.083879'), Decimal('18.08')),
#  ('Chile', 2017, Decimal('18.368577'), Decimal('18.37')),
#  ('Chile', 2018, Decimal('18.701450'), Decimal('18.70')),
#  ('Chile', 2019, Decimal('19.039485'), Decimal('19.04')),
#  ('Chile', 2020, Decimal('19.300315'), Decimal('19.30')),
#  ('Colombia', 2015, Decimal('47.119728'), Decimal('47.12')),
#  ('Colombia', 2016, Decimal('47.625955'), Decimal('47.63')),
#  ('Colombia', 2017, Decimal('48.351671'), Decimal('48.35')),
#  ('Colombia', 2018, Decimal('49.276961'), Decimal('49.28')),
#  ('Colombia', 2019, Decimal('50.187406'), Decimal('50.19')),
#  ('Colombia', 2020, Decimal('50.930662'), Decimal('50.93')),
#  ('Ecuador', 2015, Decimal('16.195902'), Decimal('16.20')),
#  ('Ecuador', 2016, Decimal('16.439585'), Decimal('16.44')),
#  ('Ecuador', 2017, Decimal('16.696944'), Decimal('16.70')),
#  ('Ecuador', 2018, Decimal('17.015672'), Decimal('17.02')),
#  ('Ecuador', 2019, Decimal('17.343740'), Decimal('17.34')),
#  ('Ecuador', 2020, Decimal('17.588595'), Decimal('17.59')),
#  ('Falkland Islands (Malvinas)', 2015, None, None),
#  ('Falkland Islands (Malvinas)', 2016, None, None),
#  ('Falkland Islands (Malvinas)', 2017, None, None),
#  ('Falkland Islands (Malvinas)', 2018, None, None),
#  ('Falkland Islands (Malvinas)', 2019, None, None),
#  ('Falkland Islands (Malvinas)', 2020, None, None),
#  ('French Guiana', 2015, None, None),
#  ('French Guiana', 2016, None, None),
#  ('French Guiana', 2017, None, None),
#  ('French Guiana', 2018, None, None),
#  ('French Guiana', 2019, None, None),
#  ('French Guiana', 2020, None, None),
#  ('Guyana', 2015, Decimal('0.755031'), Decimal('0.76')),
#  ('Guyana', 2016, Decimal('0.759087'), Decimal('0.76')),
#  ('Guyana', 2017, Decimal('0.763252'), Decimal('0.76')),
#  ('Guyana', 2018, Decimal('0.785514'), Decimal('0.79')),
#  ('Guyana', 2019, Decimal('0.798753'), Decimal('0.80')),
#  ('Guyana', 2020, Decimal('0.797202'), Decimal('0.80')),
#  ('Paraguay', 2015, Decimal('6.177950'), Decimal('6.18')),
#  ('Paraguay', 2016, Decimal('6.266615'), Decimal('6.27')),
#  ('Paraguay', 2017, Decimal('6.355404'), Decimal('6.36')),
#  ('Paraguay', 2018, Decimal('6.443328'), Decimal('6.44')),
#  ('Paraguay', 2019, Decimal('6.530026'), Decimal('6.53')),
#  ('Paraguay', 2020, Decimal('6.618695'), Decimal('6.62')),
#  ('Peru', 2015, Decimal('30.711863'), Decimal('30.71')),
#  ('Peru', 2016, Decimal('31.132779'), Decimal('31.13')),
#  ('Peru', 2017, Decimal('31.605486'), Decimal('31.61')),
#  ('Peru', 2018, Decimal('32.203944'), Decimal('32.20')),
#  ('Peru', 2019, Decimal('32.824861'), Decimal('32.82')),
#  ('Peru', 2020, Decimal('33.304756'), Decimal('33.30')),
#  ('Suriname', 2015, Decimal('0.575475'), Decimal('0.58')),
#  ('Suriname', 2016, Decimal('0.581453'), Decimal('0.58')),
#  ('Suriname', 2017, Decimal('0.587559'), Decimal('0.59')),
#  ('Suriname', 2018, Decimal('0.593715'), Decimal('0.59')),
#  ('Suriname', 2019, Decimal('0.600301'), Decimal('0.60')),
#  ('Suriname', 2020, Decimal('0.607065'), Decimal('0.61')),
#  ('Uruguay', 2015, Decimal('3.402818'), Decimal('3.40')),
#  ('Uruguay', 2016, Decimal('3.413766'), Decimal('3.41')),
#  ('Uruguay', 2017, Decimal('3.422200'), Decimal('3.42')),
#  ('Uruguay', 2018, Decimal('3.427042'), Decimal('3.43')),
#  ('Uruguay', 2019, Decimal('3.428409'), Decimal('3.43')),
#  ('Uruguay', 2020, Decimal('3.429086'), Decimal('3.43')),
#  ('Venezuela (Bolivarian Republic of)', 2015, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2016, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2017, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2018, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2019, None, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, None, None),
#  ('Algeria', 2015, Decimal('39.543154'), Decimal('39.54')),
#  ('Algeria', 2016, Decimal('40.339329'), Decimal('40.34')),
#  ('Algeria', 2017, Decimal('41.136546'), Decimal('41.14')),
#  ('Algeria', 2018, Decimal('41.927007'), Decimal('41.93')),
#  ('Algeria', 2019, Decimal('42.705368'), Decimal('42.71')),
#  ('Algeria', 2020, Decimal('43.451666'), Decimal('43.45')),
#  ('Egypt', 2015, None, None),
#  ('Egypt', 2016, None, None),
#  ('Egypt', 2017, None, None),
#  ('Egypt', 2018, None, None),
#  ('Egypt', 2019, None, None),
#  ('Egypt', 2020, None, None),
#  ('Libya', 2015, Decimal('6.192235'), Decimal('6.19')),
#  ('Libya', 2016, Decimal('6.282196'), Decimal('6.28')),
#  ('Libya', 2017, Decimal('6.378261'), Decimal('6.38')),
#  ('Libya', 2018, Decimal('6.477793'), Decimal('6.48')),
#  ('Libya', 2019, Decimal('6.569088'), Decimal('6.57')),
#  ('Libya', 2020, Decimal('6.653942'), Decimal('6.65')),
#  ('Morocco', 2015, Decimal('34.680458'), Decimal('34.68')),
#  ('Morocco', 2016, Decimal('35.107264'), Decimal('35.11')),
#  ('Morocco', 2017, Decimal('35.528115'), Decimal('35.53')),
#  ('Morocco', 2018, Decimal('35.927511'), Decimal('35.93')),
#  ('Morocco', 2019, Decimal('36.304408'), Decimal('36.30')),
#  ('Morocco', 2020, Decimal('36.688772'), Decimal('36.69')),
#  ('Sudan', 2015, Decimal('38.171178'), Decimal('38.17')),
#  ('Sudan', 2016, Decimal('39.377169'), Decimal('39.38')),
#  ('Sudan', 2017, Decimal('40.679828'), Decimal('40.68')),
#  ('Sudan', 2018, Decimal('41.999059'), Decimal('42.00')),
#  ('Sudan', 2019, Decimal('43.232093'), Decimal('43.23')),
#  ('Sudan', 2020, Decimal('44.440486'), Decimal('44.44')),
#  ('Tunisia', 2015, Decimal('11.557779'), Decimal('11.56')),
#  ('Tunisia', 2016, Decimal('11.685667'), Decimal('11.69')),
#  ('Tunisia', 2017, Decimal('11.811443'), Decimal('11.81')),
#  ('Tunisia', 2018, Decimal('11.933041'), Decimal('11.93')),
#  ('Tunisia', 2019, Decimal('12.049314'), Decimal('12.05')),
#  ('Tunisia', 2020, Decimal('12.161723'), Decimal('12.16')),
#  ('Armenia', 2015, Decimal('2.878595'), Decimal('2.88')),
#  ('Armenia', 2016, Decimal('2.865835'), Decimal('2.87')),
#  ('Armenia', 2017, Decimal('2.851923'), Decimal('2.85')),
#  ('Armenia', 2018, Decimal('2.836557'), Decimal('2.84')),
#  ('Armenia', 2019, Decimal('2.820602'), Decimal('2.82')),
#  ('Armenia', 2020, Decimal('2.805608'), Decimal('2.81')),
#  ('Azerbaijan', 2015, Decimal('9.649341'), Decimal('9.65')),
#  ('Azerbaijan', 2016, Decimal('9.757812'), Decimal('9.76')),
#  ('Azerbaijan', 2017, Decimal('9.854033'), Decimal('9.85')),
#  ('Azerbaijan', 2018, Decimal('9.939771'), Decimal('9.94')),
#  ('Azerbaijan', 2019, Decimal('10.024283'), Decimal('10.02')),
#  ('Azerbaijan', 2020, Decimal('10.093121'), Decimal('10.09')),
#  ('Bahrain', 2015, Decimal('1.362142'), Decimal('1.36')),
#  ('Bahrain', 2016, Decimal('1.409661'), Decimal('1.41')),
#  ('Bahrain', 2017, Decimal('1.456834'), Decimal('1.46')),
#  ('Bahrain', 2018, Decimal('1.487340'), Decimal('1.49')),
#  ('Bahrain', 2019, Decimal('1.494188'), Decimal('1.49')),
#  ('Bahrain', 2020, Decimal('1.477469'), Decimal('1.48')),
#  ('Cyprus', 2015, Decimal('1.187280'), Decimal('1.19')),
#  ('Cyprus', 2016, Decimal('1.197881'), Decimal('1.20')),
#  ('Cyprus', 2017, Decimal('1.208523'), Decimal('1.21')),
#  ('Cyprus', 2018, Decimal('1.218831'), Decimal('1.22')),
#  ('Cyprus', 2019, Decimal('1.228836'), Decimal('1.23')),
#  ('Cyprus', 2020, Decimal('1.237537'), Decimal('1.24')),
#  ('Georgia', 2015, Decimal('3.725276'), Decimal('3.73')),
#  ('Georgia', 2016, Decimal('3.727505'), Decimal('3.73')),
#  ('Georgia', 2017, Decimal('3.728004'), Decimal('3.73')),
#  ('Georgia', 2018, Decimal('3.726549'), Decimal('3.73')),
#  ('Georgia', 2019, Decimal('3.720161'), Decimal('3.72')),
#  ('Georgia', 2020, Decimal('3.722716'), Decimal('3.72')),
#  ('Iraq', 2015, Decimal('37.757813'), Decimal('37.76')),
#  ('Iraq', 2016, Decimal('38.697943'), Decimal('38.70')),
#  ('Iraq', 2017, Decimal('39.621162'), Decimal('39.62')),
#  ('Iraq', 2018, Decimal('40.590700'), Decimal('40.59')),
#  ('Iraq', 2019, Decimal('41.563520'), Decimal('41.56')),
#  ('Iraq', 2020, Decimal('42.556984'), Decimal('42.56')),
#  ('Israel', 2015, Decimal('8.380100'), Decimal('8.38')),
#  ('Israel', 2016, Decimal('8.546000'), Decimal('8.55')),
#  ('Israel', 2017, Decimal('8.713300'), Decimal('8.71')),
#  ('Israel', 2018, Decimal('8.882800'), Decimal('8.88')),
#  ('Israel', 2019, Decimal('9.054000'), Decimal('9.05')),
#  ('Israel', 2020, Decimal('9.215100'), Decimal('9.22')),
#  ('Jordan', 2015, Decimal('9.494246'), Decimal('9.49')),
#  ('Jordan', 2016, Decimal('9.964656'), Decimal('9.96')),
#  ('Jordan', 2017, Decimal('10.215381'), Decimal('10.22')),
#  ('Jordan', 2018, Decimal('10.459865'), Decimal('10.46')),
#  ('Jordan', 2019, Decimal('10.698683'), Decimal('10.70')),
#  ('Jordan', 2020, Decimal('10.928721'), Decimal('10.93')),
#  ('Kuwait', 2015, Decimal('3.908743'), Decimal('3.91')),
#  ('Kuwait', 2016, Decimal('4.048085'), Decimal('4.05')),
#  ('Kuwait', 2017, Decimal('4.124904'), Decimal('4.12')),
#  ('Kuwait', 2018, Decimal('4.317185'), Decimal('4.32')),
#  ('Kuwait', 2019, Decimal('4.441100'), Decimal('4.44')),
#  ('Kuwait', 2020, Decimal('4.360444'), Decimal('4.36')),
#  ('Lebanon', 2015, Decimal('6.398940'), Decimal('6.40')),
#  ('Lebanon', 2016, Decimal('6.258619'), Decimal('6.26')),
#  ('Lebanon', 2017, Decimal('6.109252'), Decimal('6.11')),
#  ('Lebanon', 2018, Decimal('5.950839'), Decimal('5.95')),
#  ('Lebanon', 2019, Decimal('5.781907'), Decimal('5.78')),
#  ('Lebanon', 2020, Decimal('5.662923'), Decimal('5.66')),
#  ('Oman', 2015, Decimal('4.191776'), Decimal('4.19')),
#  ('Oman', 2016, Decimal('4.398070'), Decimal('4.40')),
#  ('Oman', 2017, Decimal('4.541854'), Decimal('4.54')),
#  ('Oman', 2018, Decimal('4.601157'), Decimal('4.60')),
#  ('Oman', 2019, Decimal('4.602768'), Decimal('4.60')),
#  ('Oman', 2020, Decimal('4.543399'), Decimal('4.54')),
#  ('Qatar', 2015, Decimal('2.414573'), Decimal('2.41')),
#  ('Qatar', 2016, Decimal('2.595166'), Decimal('2.60')),
#  ('Qatar', 2017, Decimal('2.711755'), Decimal('2.71')),
#  ('Qatar', 2018, Decimal('2.766732'), Decimal('2.77')),
#  ('Qatar', 2019, Decimal('2.807235'), Decimal('2.81')),
#  ('Qatar', 2020, Decimal('2.760385'), Decimal('2.76')),
#  ('Saudi Arabia', 2015, Decimal('32.749848'), Decimal('32.75')),
#  ('Saudi Arabia', 2016, Decimal('33.416270'), Decimal('33.42')),
#  ('Saudi Arabia', 2017, Decimal('34.193122'), Decimal('34.19')),
#  ('Saudi Arabia', 2018, Decimal('35.018133'), Decimal('35.02')),
#  ('Saudi Arabia', 2019, Decimal('35.827362'), Decimal('35.83')),
#  ('Saudi Arabia', 2020, Decimal('35.997107'), Decimal('36.00')),
#  ('State of Palestine', 2015, None, None),
#  ('State of Palestine', 2016, None, None),
#  ('State of Palestine', 2017, None, None),
#  ('State of Palestine', 2018, None, None),
#  ('State of Palestine', 2019, None, None),
#  ('State of Palestine', 2020, None, None),
#  ('Syrian Arab Republic', 2015, Decimal('19.205178'), Decimal('19.21')),
#  ('Syrian Arab Republic', 2016, Decimal('18.964252'), Decimal('18.96')),
#  ('Syrian Arab Republic', 2017, Decimal('18.983373'), Decimal('18.98')),
#  ('Syrian Arab Republic', 2018, Decimal('19.333463'), Decimal('19.33')),
#  ('Syrian Arab Republic', 2019, Decimal('20.098251'), Decimal('20.10')),
#  ('Syrian Arab Republic', 2020, Decimal('20.772595'), Decimal('20.77')),
#  ('Türkiye', 2015, None, None),
#  ('Türkiye', 2016, None, None),
#  ('Türkiye', 2017, None, None),
#  ('Türkiye', 2018, None, None),
#  ('Türkiye', 2019, None, None),
#  ('Türkiye', 2020, None, None),
#  ('United Arab Emirates', 2015, Decimal('8.916899'), Decimal('8.92')),
#  ('United Arab Emirates', 2016, Decimal('8.994263'), Decimal('8.99')),
#  ('United Arab Emirates', 2017, Decimal('9.068296'), Decimal('9.07')),
#  ('United Arab Emirates', 2018, Decimal('9.140169'), Decimal('9.14')),
#  ('United Arab Emirates', 2019, Decimal('9.211657'), Decimal('9.21')),
#  ('United Arab Emirates', 2020, Decimal('9.287289'), Decimal('9.29')),
#  ('Yemen', 2015, None, None),
#  ('Yemen', 2016, None, None),
#  ('Yemen', 2017, None, None),
#  ('Yemen', 2018, None, None),
#  ('Yemen', 2019, None, None),
#  ('Yemen', 2020, None, None),
#  ('Australia', 2015, Decimal('23.815995'), Decimal('23.82')),
#  ('Australia', 2016, Decimal('24.190907'), Decimal('24.19')),
#  ('Australia', 2017, Decimal('24.594202'), Decimal('24.59')),
#  ('Australia', 2018, Decimal('24.966643'), Decimal('24.97')),
#  ('Australia', 2019, Decimal('25.340217'), Decimal('25.34')),
#  ('Australia', 2020, Decimal('25.655289'), Decimal('25.66')),
#  ('New Zealand', 2015, Decimal('4.609400'), Decimal('4.61')),
#  ('New Zealand', 2016, Decimal('4.714100'), Decimal('4.71')),
#  ('New Zealand', 2017, Decimal('4.813600'), Decimal('4.81')),
#  ('New Zealand', 2018, Decimal('4.900600'), Decimal('4.90')),
#  ('New Zealand', 2019, Decimal('4.979200'), Decimal('4.98')),
#  ('New Zealand', 2020, Decimal('5.090200'), Decimal('5.09')),
#  ('Fiji', 2015, Decimal('0.917200'), Decimal('0.92')),
#  ('Fiji', 2016, Decimal('0.918371'), Decimal('0.92')),
#  ('Fiji', 2017, Decimal('0.919019'), Decimal('0.92')),
#  ('Fiji', 2018, Decimal('0.918996'), Decimal('0.92')),
#  ('Fiji', 2019, Decimal('0.918465'), Decimal('0.92')),
#  ('Fiji', 2020, Decimal('0.920422'), Decimal('0.92')),
#  ('New Caledonia', 2015, Decimal('0.269460'), Decimal('0.27')),
#  ('New Caledonia', 2016, Decimal('0.270220'), Decimal('0.27')),
#  ('New Caledonia', 2017, Decimal('0.270810'), Decimal('0.27')),
#  ('New Caledonia', 2018, Decimal('0.271170'), Decimal('0.27')),
#  ('New Caledonia', 2019, Decimal('0.271230'), Decimal('0.27')),
#  ('New Caledonia', 2020, Decimal('0.271130'), Decimal('0.27')),
#  ('Papua New Guinea', 2015, Decimal('8.682174'), Decimal('8.68')),
#  ('Papua New Guinea', 2016, Decimal('8.899169'), Decimal('8.90')),
#  ('Papua New Guinea', 2017, Decimal('9.114796'), Decimal('9.11')),
#  ('Papua New Guinea', 2018, Decimal('9.329227'), Decimal('9.33')),
#  ('Papua New Guinea', 2019, Decimal('9.542486'), Decimal('9.54')),
#  ('Papua New Guinea', 2020, Decimal('9.749640'), Decimal('9.75')),
#  ('Solomon Islands', 2015, Decimal('0.612660'), Decimal('0.61')),
#  ('Solomon Islands', 2016, Decimal('0.628102'), Decimal('0.63')),
#  ('Solomon Islands', 2017, Decimal('0.643634'), Decimal('0.64')),
#  ('Solomon Islands', 2018, Decimal('0.659249'), Decimal('0.66')),
#  ('Solomon Islands', 2019, Decimal('0.674993'), Decimal('0.67')),
#  ('Solomon Islands', 2020, Decimal('0.691191'), Decimal('0.69')),
#  ('Vanuatu', 2015, Decimal('0.276438'), Decimal('0.28')),
#  ('Vanuatu', 2016, Decimal('0.283218'), Decimal('0.28')),
#  ('Vanuatu', 2017, Decimal('0.290239'), Decimal('0.29')),
#  ('Vanuatu', 2018, Decimal('0.297298'), Decimal('0.30')),
#  ('Vanuatu', 2019, Decimal('0.304404'), Decimal('0.30')),
#  ('Vanuatu', 2020, Decimal('0.311685'), Decimal('0.31')),
#  ('Guam', 2015, Decimal('0.167978'), Decimal('0.17')),
#  ('Guam', 2016, Decimal('0.168346'), Decimal('0.17')),
#  ('Guam', 2017, Decimal('0.168606'), Decimal('0.17')),
#  ('Guam', 2018, Decimal('0.168678'), Decimal('0.17')),
#  ('Guam', 2019, Decimal('0.168624'), Decimal('0.17')),
#  ('Guam', 2020, Decimal('0.169231'), Decimal('0.17')),
#  ('Kiribati', 2015, Decimal('0.116707'), Decimal('0.12')),
#  ('Kiribati', 2016, Decimal('0.118513'), Decimal('0.12')),
#  ('Kiribati', 2017, Decimal('0.120362'), Decimal('0.12')),
#  ('Kiribati', 2018, Decimal('0.122261'), Decimal('0.12')),
#  ('Kiribati', 2019, Decimal('0.124241'), Decimal('0.12')),
#  ('Kiribati', 2020, Decimal('0.126463'), Decimal('0.13')),
#  ('Marshall Islands', 2015, Decimal('0.049410'), Decimal('0.05')),
#  ('Marshall Islands', 2016, Decimal('0.048329'), Decimal('0.05')),
#  ('Marshall Islands', 2017, Decimal('0.047187'), Decimal('0.05')),
#  ('Marshall Islands', 2018, Decimal('0.045989'), Decimal('0.05')),
#  ('Marshall Islands', 2019, Decimal('0.044728'), Decimal('0.04')),
#  ('Marshall Islands', 2020, Decimal('0.043413'), Decimal('0.04')),
#  ('Micronesia (Federated States of)', 2015, None, None),
#  ('Micronesia (Federated States of)', 2016, None, None),
#  ('Micronesia (Federated States of)', 2017, None, None),
#  ('Micronesia (Federated States of)', 2018, None, None),
#  ('Micronesia (Federated States of)', 2019, None, None),
#  ('Nauru', 2015, Decimal('0.011185'), Decimal('0.01')),
#  ('Nauru', 2016, Decimal('0.011437'), Decimal('0.01')),
#  ('Nauru', 2017, Decimal('0.011682'), Decimal('0.01')),
#  ('Nauru', 2018, Decimal('0.011924'), Decimal('0.01')),
#  ('Nauru', 2019, Decimal('0.012132'), Decimal('0.01')),
#  ('Nauru', 2020, Decimal('0.012315'), Decimal('0.01')),
#  ('Northern Mariana Islands', 2015, Decimal('0.051514'), Decimal('0.05')),
#  ('Northern Mariana Islands', 2016, Decimal('0.051133'), Decimal('0.05')),
#  ('Northern Mariana Islands', 2017, Decimal('0.050729'), Decimal('0.05')),
#  ('Northern Mariana Islands', 2018, Decimal('0.050304'), Decimal('0.05')),
#  ('Northern Mariana Islands', 2019, Decimal('0.049858'), Decimal('0.05')),
#  ('Northern Mariana Islands', 2020, Decimal('0.049587'), Decimal('0.05')),
#  ('Palau', 2015, Decimal('0.017794'), Decimal('0.02')),
#  ('Palau', 2016, Decimal('0.017816'), Decimal('0.02')),
#  ('Palau', 2017, Decimal('0.017837'), Decimal('0.02')),
#  ('Palau', 2018, Decimal('0.017864'), Decimal('0.02')),
#  ('Palau', 2019, Decimal('0.017916'), Decimal('0.02')),
#  ('Palau', 2020, Decimal('0.017972'), Decimal('0.02')),
#  ('American Samoa', 2015, Decimal('0.051368'), Decimal('0.05')),
#  ('American Samoa', 2016, Decimal('0.050448'), Decimal('0.05')),
#  ('American Samoa', 2017, Decimal('0.049463'), Decimal('0.05')),
#  ('American Samoa', 2018, Decimal('0.048424'), Decimal('0.05')),
#  ('American Samoa', 2019, Decimal('0.047321'), Decimal('0.05')),
#  ('American Samoa', 2020, Decimal('0.046189'), Decimal('0.05')),
#  ('Cook Islands', 2015, None, None),
#  ('Cook Islands', 2016, None, None),
#  ('Cook Islands', 2017, None, None),
#  ('Cook Islands', 2018, None, None),
#  ('Cook Islands', 2019, None, None),
#  ('Cook Islands', 2020, None, None),
#  ('French Polynesia', 2015, Decimal('0.291787'), Decimal('0.29')),
#  ('French Polynesia', 2016, Decimal('0.293541'), Decimal('0.29')),
#  ('French Polynesia', 2017, Decimal('0.295450'), Decimal('0.30')),
#  ('French Polynesia', 2018, Decimal('0.297606'), Decimal('0.30')),
#  ('French Polynesia', 2019, Decimal('0.299717'), Decimal('0.30')),
#  ('French Polynesia', 2020, Decimal('0.301920'), Decimal('0.30')),
#  ('Niue', 2015, None, None),
#  ('Niue', 2016, None, None),
#  ('Niue', 2017, None, None),
#  ('Niue', 2018, None, None),
#  ('Niue', 2019, None, None),
#  ('Niue', 2020, None, None),
#  ('Samoa', 2015, Decimal('0.203571'), Decimal('0.20')),
#  ('Samoa', 2016, Decimal('0.205544'), Decimal('0.21')),
#  ('Samoa', 2017, Decimal('0.207630'), Decimal('0.21')),
#  ('Samoa', 2018, Decimal('0.209701'), Decimal('0.21')),
#  ('Samoa', 2019, Decimal('0.211905'), Decimal('0.21')),
#  ('Samoa', 2020, Decimal('0.214929'), Decimal('0.21')),
#  ('Tokelau', 2015, None, None),
#  ('Tokelau', 2016, None, None),
#  ('Tokelau', 2017, None, None),
#  ('Tokelau', 2018, None, None),
#  ('Tokelau', 2019, None, None),
#  ('Tokelau', 2020, None, None),
#  ('Tonga', 2015, Decimal('0.106122'), Decimal('0.11')),
#  ('Tonga', 2016, Decimal('0.105707'), Decimal('0.11')),
#  ('Tonga', 2017, Decimal('0.105415'), Decimal('0.11')),
#  ('Tonga', 2018, Decimal('0.105150'), Decimal('0.11')),
#  ('Tonga', 2019, Decimal('0.104951'), Decimal('0.10')),
#  ('Tonga', 2020, Decimal('0.105254'), Decimal('0.11')),
#  ('Tuvalu', 2015, Decimal('0.010877'), Decimal('0.01')),
#  ('Tuvalu', 2016, Decimal('0.010852'), Decimal('0.01')),
#  ('Tuvalu', 2017, Decimal('0.010828'), Decimal('0.01')),
#  ('Tuvalu', 2018, Decimal('0.010865'), Decimal('0.01')),
#  ('Tuvalu', 2019, Decimal('0.010956'), Decimal('0.01')),
#  ('Tuvalu', 2020, Decimal('0.011069'), Decimal('0.01')),
#  ('Wallis and Futuna Islands', 2015, None, None),
#  ('Wallis and Futuna Islands', 2016, None, None),
#  ('Wallis and Futuna Islands', 2017, None, None),
#  ('Wallis and Futuna Islands', 2018, None, None),
#  ('Wallis and Futuna Islands', 2019, None, None),
#  ('Wallis and Futuna Islands', 2020, None, None),
#  ('Burundi', 2015, Decimal('10.727148'), Decimal('10.73')),
#  ('Burundi', 2016, Decimal('10.903327'), Decimal('10.90')),
#  ('Burundi', 2017, Decimal('11.155593'), Decimal('11.16')),
#  ('Burundi', 2018, Decimal('11.493472'), Decimal('11.49')),
#  ('Burundi', 2019, Decimal('11.874838'), Decimal('11.87')),
#  ('Burundi', 2020, Decimal('12.220227'), Decimal('12.22')),
#  ('Comoros', 2015, Decimal('0.730216'), Decimal('0.73')),
#  ('Comoros', 2016, Decimal('0.746232'), Decimal('0.75')),
#  ('Comoros', 2017, Decimal('0.761664'), Decimal('0.76')),
#  ('Comoros', 2018, Decimal('0.776313'), Decimal('0.78')),
#  ('Comoros', 2019, Decimal('0.790986'), Decimal('0.79')),
#  ('Djibouti', 2015, Decimal('1.006259'), Decimal('1.01')),
#  ('Djibouti', 2016, Decimal('1.023261'), Decimal('1.02')),
#  ('Djibouti', 2017, Decimal('1.040233'), Decimal('1.04')),
#  ('Djibouti', 2018, Decimal('1.057198'), Decimal('1.06')),
#  ('Djibouti', 2019, Decimal('1.073994'), Decimal('1.07')),
#  ('Djibouti', 2020, Decimal('1.090156'), Decimal('1.09')),
#  ('Eritrea', 2015, Decimal('3.340006'), Decimal('3.34')),
#  ('Eritrea', 2016, Decimal('3.365287'), Decimal('3.37')),
#  ('Ethiopia', 2015, Decimal('102.471895'), Decimal('102.47')),
#  ('Ethiopia', 2016, Decimal('105.293228'), Decimal('105.29')),
#  ('Ethiopia', 2017, Decimal('108.197950'), Decimal('108.20')),
#  ('Ethiopia', 2018, Decimal('111.129438'), Decimal('111.13')),
#  ('Ethiopia', 2019, Decimal('114.120594'), Decimal('114.12')),
#  ('Ethiopia', 2020, Decimal('117.190911'), Decimal('117.19')),
#  ('Kenya', 2015, Decimal('46.851488'), Decimal('46.85')),
#  ('Kenya', 2016, Decimal('47.894670'), Decimal('47.89')),
#  ('Kenya', 2017, Decimal('48.948137'), Decimal('48.95')),
#  ('Kenya', 2018, Decimal('49.953304'), Decimal('49.95')),
#  ('Kenya', 2019, Decimal('50.951450'), Decimal('50.95')),
#  ('Kenya', 2020, Decimal('51.985780'), Decimal('51.99')),
#  ('Madagascar', 2015, Decimal('24.850912'), Decimal('24.85')),
#  ('Madagascar', 2016, Decimal('25.501941'), Decimal('25.50')),
#  ('Madagascar', 2017, Decimal('26.169542'), Decimal('26.17')),
#  ('Madagascar', 2018, Decimal('26.846541'), Decimal('26.85')),
#  ('Madagascar', 2019, Decimal('27.533134'), Decimal('27.53')),
#  ('Madagascar', 2020, Decimal('28.225177'), Decimal('28.23')),
#  ('Malawi', 2015, Decimal('16.938942'), Decimal('16.94')),
#  ('Malawi', 2016, Decimal('17.405624'), Decimal('17.41')),
#  ('Malawi', 2017, Decimal('17.881167'), Decimal('17.88')),
#  ('Malawi', 2018, Decimal('18.367883'), Decimal('18.37')),
#  ('Malawi', 2019, Decimal('18.867337'), Decimal('18.87')),
#  ('Malawi', 2020, Decimal('19.377061'), Decimal('19.38')),
#  ('Mauritius', 2015, Decimal('1.262605'), Decimal('1.26')),
#  ('Mauritius', 2016, Decimal('1.263473'), Decimal('1.26')),
#  ('Mauritius', 2017, Decimal('1.264613'), Decimal('1.26')),
#  ('Mauritius', 2018, Decimal('1.265303'), Decimal('1.27')),
#  ('Mauritius', 2019, Decimal('1.265711'), Decimal('1.27')),
#  ('Mauritius', 2020, Decimal('1.265740'), Decimal('1.27')),
#  ('Mayotte', 2015, None, None),
#  ('Mayotte', 2016, None, None),
#  ('Mayotte', 2017, None, None),
#  ('Mayotte', 2018, None, None),
#  ('Mayotte', 2019, None, None),
#  ('Mayotte', 2020, None, None),
#  ('Mozambique', 2015, Decimal('26.843246'), Decimal('26.84')),
#  ('Mozambique', 2016, Decimal('27.696493'), Decimal('27.70')),
#  ('Mozambique', 2017, Decimal('28.569441'), Decimal('28.57')),
#  ('Mozambique', 2018, Decimal('29.423878'), Decimal('29.42')),
#  ('Mozambique', 2019, Decimal('30.285595'), Decimal('30.29')),
#  ('Mozambique', 2020, Decimal('31.178239'), Decimal('31.18')),
#  ('Rwanda', 2015, Decimal('11.642959'), Decimal('11.64')),
#  ('Rwanda', 2016, Decimal('11.930899'), Decimal('11.93')),
#  ('Rwanda', 2017, Decimal('12.230339'), Decimal('12.23')),
#  ('Rwanda', 2018, Decimal('12.531808'), Decimal('12.53')),
#  ('Rwanda', 2019, Decimal('12.835028'), Decimal('12.84')),
#  ('Rwanda', 2020, Decimal('13.146362'), Decimal('13.15')),
#  ('Réunion', 2015, None, None),
#  ('Réunion', 2016, None, None),
#  ('Réunion', 2017, None, None),
#  ('Réunion', 2018, None, None),
#  ('Réunion', 2019, None, None),
#  ('Réunion', 2020, None, None),
#  ('Seychelles', 2015, Decimal('0.093419'), Decimal('0.09')),
#  ('Seychelles', 2016, Decimal('0.094677'), Decimal('0.09')),
#  ('Seychelles', 2017, Decimal('0.095843'), Decimal('0.10')),
#  ('Seychelles', 2018, Decimal('0.096762'), Decimal('0.10')),
#  ('Seychelles', 2019, Decimal('0.097625'), Decimal('0.10')),
#  ('Somalia', 2015, Decimal('13.763906'), Decimal('13.76')),
#  ('Somalia', 2016, Decimal('14.292847'), Decimal('14.29')),
#  ('Somalia', 2017, Decimal('14.864221'), Decimal('14.86')),
#  ('Somalia', 2018, Decimal('15.411094'), Decimal('15.41')),
#  ('Somalia', 2019, Decimal('15.981300'), Decimal('15.98')),
#  ('Somalia', 2020, Decimal('16.537016'), Decimal('16.54')),
#  ('South Sudan', 2015, Decimal('11.194299'), Decimal('11.19')),
#  ('South Sudan', 2016, Decimal('11.066105'), Decimal('11.07')),
#  ('South Sudan', 2017, Decimal('10.658226'), Decimal('10.66')),
#  ('South Sudan', 2018, Decimal('10.395329'), Decimal('10.40')),
#  ('South Sudan', 2019, Decimal('10.447666'), Decimal('10.45')),
#  ('South Sudan', 2020, Decimal('10.606227'), Decimal('10.61')),
#  ('Uganda', 2015, Decimal('37.477356'), Decimal('37.48')),
#  ('Uganda', 2016, Decimal('38.748299'), Decimal('38.75')),
#  ('Uganda', 2017, Decimal('40.127085'), Decimal('40.13')),
#  ('Uganda', 2018, Decimal('41.515395'), Decimal('41.52')),
#  ('Uganda', 2019, Decimal('42.949080'), Decimal('42.95')),
#  ('Uganda', 2020, Decimal('44.404611'), Decimal('44.40')),
#  ('United Republic of Tanzania', 2015, None, None),
#  ('United Republic of Tanzania', 2016, None, None),
#  ('United Republic of Tanzania', 2017, None, None),
#  ('United Republic of Tanzania', 2018, None, None),
#  ('United Republic of Tanzania', 2019, None, None),
#  ('United Republic of Tanzania', 2020, None, None),
#  ('Zambia', 2015, Decimal('16.248230'), Decimal('16.25')),
#  ('Zambia', 2016, Decimal('16.767761'), Decimal('16.77')),
#  ('Zambia', 2017, Decimal('17.298054'), Decimal('17.30')),
#  ('Zambia', 2018, Decimal('17.835893'), Decimal('17.84')),
#  ('Zambia', 2019, Decimal('18.380477'), Decimal('18.38')),
#  ('Zambia', 2020, Decimal('18.927715'), Decimal('18.93')),
#  ('Zimbabwe', 2015, Decimal('14.154937'), Decimal('14.15')),
#  ('Zimbabwe', 2016, Decimal('14.452704'), Decimal('14.45')),
#  ('Zimbabwe', 2017, Decimal('14.751101'), Decimal('14.75')),
#  ('Zimbabwe', 2018, Decimal('15.052184'), Decimal('15.05')),
#  ('Zimbabwe', 2019, Decimal('15.354608'), Decimal('15.35')),
#  ('Zimbabwe', 2020, Decimal('15.669666'), Decimal('15.67')),
#  ('Angola', 2015, Decimal('28.127721'), Decimal('28.13')),
#  ('Angola', 2016, Decimal('29.154746'), Decimal('29.15')),
#  ('Angola', 2017, Decimal('30.208628'), Decimal('30.21')),
#  ('Angola', 2018, Decimal('31.273533'), Decimal('31.27')),
#  ('Angola', 2019, Decimal('32.353588'), Decimal('32.35')),
#  ('Angola', 2020, Decimal('33.428486'), Decimal('33.43')),
#  ('Cameroon', 2015, Decimal('23.012646'), Decimal('23.01')),
#  ('Cameroon', 2016, Decimal('23.711630'), Decimal('23.71')),
#  ('Cameroon', 2017, Decimal('24.393181'), Decimal('24.39')),
#  ('Cameroon', 2018, Decimal('25.076747'), Decimal('25.08')),
#  ('Cameroon', 2019, Decimal('25.782341'), Decimal('25.78')),
#  ('Cameroon', 2020, Decimal('26.491087'), Decimal('26.49')),
#  ('Central African Republic', 2015, Decimal('4.819333'), Decimal('4.82')),
#  ('Central African Republic', 2016, Decimal('4.904177'), Decimal('4.90')),
#  ('Central African Republic', 2017, Decimal('4.996741'), Decimal('5.00')),
#  ('Central African Republic', 2018, Decimal('5.094780'), Decimal('5.09')),
#  ('Central African Republic', 2019, Decimal('5.209324'), Decimal('5.21')),
#  ('Central African Republic', 2020, Decimal('5.343020'), Decimal('5.34')),
#  ('Chad', 2015, Decimal('14.140274'), Decimal('14.14')),
#  ('Chad', 2016, Decimal('14.592585'), Decimal('14.59')),
#  ('Chad', 2017, Decimal('15.085884'), Decimal('15.09')),
#  ('Chad', 2018, Decimal('15.604210'), Decimal('15.60')),
#  ('Chad', 2019, Decimal('16.126866'), Decimal('16.13')),
#  ('Chad', 2020, Decimal('16.644701'), Decimal('16.64')),
#  ('Congo', 2015, None, None),
#  ('Congo', 2016, None, None),
#  ('Congo', 2017, None, None),
#  ('Congo', 2018, None, None),
#  ('Congo', 2019, None, None),
#  ('Congo', 2020, None, None),
#  ('Democratic Republic of the Congo', 2015, None, None),
#  ('Democratic Republic of the Congo', 2016, None, None),
#  ('Democratic Republic of the Congo', 2017, None, None),
#  ('Democratic Republic of the Congo', 2018, None, None),
#  ('Democratic Republic of the Congo', 2019, None, None),
#  ('Democratic Republic of the Congo', 2020, None, None),
#  ('Equatorial Guinea', 2015, Decimal('1.346973'), Decimal('1.35')),
#  ('Equatorial Guinea', 2016, Decimal('1.398927'), Decimal('1.40')),
#  ('Equatorial Guinea', 2017, Decimal('1.450694'), Decimal('1.45')),
#  ('Gabon', 2015, Decimal('2.028517'), Decimal('2.03')),
#  ('Gabon', 2016, Decimal('2.086206'), Decimal('2.09')),
#  ('Gabon', 2017, Decimal('2.140215'), Decimal('2.14')),
#  ('Gabon', 2018, Decimal('2.192012'), Decimal('2.19')),
#  ('Gabon', 2019, Decimal('2.242785'), Decimal('2.24')),
#  ('Gabon', 2020, Decimal('2.292573'), Decimal('2.29')),
#  ('Sao Tome and Principe', 2015, Decimal('0.201124'), Decimal('0.20')),
#  ('Sao Tome and Principe', 2016, Decimal('0.204632'), Decimal('0.20')),
#  ('Sao Tome and Principe', 2017, Decimal('0.208036'), Decimal('0.21')),
#  ('Sao Tome and Principe', 2018, Decimal('0.211344'), Decimal('0.21')),
#  ('Sao Tome and Principe', 2019, Decimal('0.214599'), Decimal('0.21')),
#  ('Sao Tome and Principe', 2020, Decimal('0.218641'), Decimal('0.22')),
#  ('Botswana', 2015, Decimal('2.305171'), Decimal('2.31')),
#  ('Botswana', 2016, Decimal('2.352416'), Decimal('2.35')),
#  ('Botswana', 2017, Decimal('2.401840'), Decimal('2.40')),
#  ('Botswana', 2018, Decimal('2.451409'), Decimal('2.45')),
#  ('Botswana', 2019, Decimal('2.499702'), Decimal('2.50')),
#  ('Botswana', 2020, Decimal('2.546402'), Decimal('2.55')),
#  ('Eswatini', 2015, Decimal('1.133936'), Decimal('1.13')),
#  ('Eswatini', 2016, Decimal('1.142524'), Decimal('1.14')),
#  ('Eswatini', 2017, Decimal('1.151390'), Decimal('1.15')),
#  ('Eswatini', 2018, Decimal('1.160428'), Decimal('1.16')),
#  ('Eswatini', 2019, Decimal('1.169613'), Decimal('1.17')),
#  ('Eswatini', 2020, Decimal('1.180655'), Decimal('1.18')),
#  ('Lesotho', 2015, Decimal('2.118521'), Decimal('2.12')),
#  ('Lesotho', 2016, Decimal('2.143872'), Decimal('2.14')),
#  ('Lesotho', 2017, Decimal('2.170617'), Decimal('2.17')),
#  ('Lesotho', 2018, Decimal('2.198017'), Decimal('2.20')),
#  ('Lesotho', 2019, Decimal('2.225702'), Decimal('2.23')),
#  ('Lesotho', 2020, Decimal('2.254100'), Decimal('2.25')),
#  ('Namibia', 2015, Decimal('2.282704'), Decimal('2.28')),
#  ('Namibia', 2016, Decimal('2.323352'), Decimal('2.32')),
#  ('Namibia', 2017, Decimal('2.364534'), Decimal('2.36')),
#  ('Namibia', 2018, Decimal('2.405680'), Decimal('2.41')),
#  ('Namibia', 2019, Decimal('2.446644'), Decimal('2.45')),
#  ('Namibia', 2020, Decimal('2.489098'), Decimal('2.49')),
#  ('South Africa', 2015, Decimal('55.876504'), Decimal('55.88')),
#  ('South Africa', 2016, Decimal('56.422274'), Decimal('56.42')),
#  ('South Africa', 2017, Decimal('56.641209'), Decimal('56.64')),
#  ('South Africa', 2018, Decimal('57.339635'), Decimal('57.34')),
#  ('South Africa', 2019, Decimal('58.087055'), Decimal('58.09')),
#  ('South Africa', 2020, Decimal('58.801927'), Decimal('58.80')),
#  ('Benin', 2015, Decimal('10.932783'), Decimal('10.93')),
#  ('Benin', 2016, Decimal('11.260085'), Decimal('11.26')),
#  ('Benin', 2017, Decimal('11.596779'), Decimal('11.60')),
#  ('Benin', 2018, Decimal('11.940683'), Decimal('11.94')),
#  ('Benin', 2019, Decimal('12.290444'), Decimal('12.29')),
#  ('Benin', 2020, Decimal('12.643123'), Decimal('12.64')),
#  ('Burkina Faso', 2015, Decimal('18.718019'), Decimal('18.72')),
#  ('Burkina Faso', 2016, Decimal('19.275498'), Decimal('19.28')),
#  ('Burkina Faso', 2017, Decimal('19.835858'), Decimal('19.84')),
#  ('Burkina Faso', 2018, Decimal('20.392723'), Decimal('20.39')),
#  ('Burkina Faso', 2019, Decimal('20.951639'), Decimal('20.95')),
#  ('Burkina Faso', 2020, Decimal('21.522626'), Decimal('21.52')),
#  ('Cabo Verde', 2015, Decimal('0.552166'), Decimal('0.55')),
#  ('Cabo Verde', 2016, Decimal('0.558394'), Decimal('0.56')),
#  ('Cabo Verde', 2017, Decimal('0.564954'), Decimal('0.56')),
#  ('Cabo Verde', 2018, Decimal('0.571202'), Decimal('0.57')),
#  ('Cabo Verde', 2019, Decimal('0.577030'), Decimal('0.58')),
#  ('Cabo Verde', 2020, Decimal('0.582640'), Decimal('0.58')),
#  ("Côte d'Ivoire", 2015, None, None),
#  ("Côte d'Ivoire", 2016, None, None),
#  ("Côte d'Ivoire", 2017, None, None),
#  ("Côte d'Ivoire", 2018, None, None),
#  ("Côte d'Ivoire", 2019, None, None),
#  ("Côte d'Ivoire", 2020, None, None),
#  ('Gambia', 2015, None, None),
#  ('Gambia', 2016, None, None),
#  ('Gambia', 2017, None, None),
#  ('Gambia', 2018, None, None),
#  ('Gambia', 2019, None, None),
#  ('Gambia', 2020, None, None),
#  ('Ghana', 2015, Decimal('28.870939'), Decimal('28.87')),
#  ('Ghana', 2016, Decimal('29.554303'), Decimal('29.55')),
#  ('Ghana', 2017, Decimal('30.222262'), Decimal('30.22')),
#  ('Ghana', 2018, Decimal('30.870641'), Decimal('30.87')),
#  ('Ghana', 2019, Decimal('31.522290'), Decimal('31.52')),
#  ('Ghana', 2020, Decimal('32.180401'), Decimal('32.18')),
#  ('Guinea', 2015, Decimal('11.625998'), Decimal('11.63')),
#  ('Guinea', 2016, Decimal('11.930985'), Decimal('11.93')),
#  ('Guinea', 2017, Decimal('12.240789'), Decimal('12.24')),
#  ('Guinea', 2018, Decimal('12.554864'), Decimal('12.55')),
#  ('Guinea', 2019, Decimal('12.877539'), Decimal('12.88')),
#  ('Guinea', 2020, Decimal('13.205153'), Decimal('13.21')),
#  ('Guinea-Bissau', 2015, Decimal('1.788919'), Decimal('1.79')),
#  ('Guinea-Bissau', 2016, Decimal('1.834552'), Decimal('1.83')),
#  ('Guinea-Bissau', 2017, Decimal('1.879826'), Decimal('1.88')),
#  ('Guinea-Bissau', 2018, Decimal('1.924955'), Decimal('1.92')),
#  ('Guinea-Bissau', 2019, Decimal('1.970457'), Decimal('1.97')),
#  ('Guinea-Bissau', 2020, Decimal('2.015828'), Decimal('2.02')),
#  ('Liberia', 2015, Decimal('4.612329'), Decimal('4.61')),
#  ('Liberia', 2016, Decimal('4.706097'), Decimal('4.71')),
#  ('Liberia', 2017, Decimal('4.796631'), Decimal('4.80')),
#  ('Liberia', 2018, Decimal('4.889391'), Decimal('4.89')),
#  ('Liberia', 2019, Decimal('4.985289'), Decimal('4.99')),
#  ('Liberia', 2020, Decimal('5.087584'), Decimal('5.09')),
#  ...]

# %% [markdown]
# ### 2. Convert to the DECIMAL data type with the preferred scale and precision
#
# Once we have determined the appropriate precision to give to the `Est_population_in_millions` column values, we can then convert to the preferred data type.

# %%
# %%sql
# # Add your code here

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### 1. Determine the appropriate precision
# We use the `MAX` function to help us find the maximum value in the `Est_population_in_millions` column.

# %%
# %%sql
#
# SELECT DISTINCT
#     MAX(Est_population_in_millions)
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# Since the highest value in the column has 4 digits before the decimal point, we can safely assign a precision of 6, with a scale of 2 to the column.

# %% [markdown]
# ### 2.  Convert to the DECIMAL data type with the preferred scale and precision
#
# We use the `CAST` function to convert the `Estimated population in millions` column to the new data type and the results are returned in a new column, `Est_population_in_millions_2dp`.

# %%
# %%sql
#
# SELECT DISTINCT
#     Country_name,
#     Time_period,
#     CAST(Est_population_in_millions AS DECIMAL(6,2)) AS Est_population_in_millions_2dp
# FROM
#     united_nations.Access_to_Basic_Services;

# %% [markdown]
# ## Summary
#
# We have successfully performed the conversion and our values now have only two decimal places.
#
# **NOTE:** The `CAST()` function will only change the data type of the expression in the results set. It does not alter the actual data type specified in the database schema.
#
# To permanently change the data type of a column, the `ALTER TABLE` statement is used.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
